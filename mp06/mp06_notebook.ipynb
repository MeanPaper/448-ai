# %% [markdown]
# <p align="center">
#     <img width="400" src="images/assignment5_splash.png"/>
# </p>

# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP06: Two-Player Games

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp06.zip">mp06.zip</a>.  It has the following content:
#
# * `main.py`. This file plays the game (python3 main.py).
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp06_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `grading_examples/`. This directory contains the JSON answer keys on which your grade is based (the visible ones). You are strongly encouraged to read these, to see what format your code should produce.
# * `chess/`, `res/`, `tools/`. These directories contain code and resources from PyChess that are necessary to run the assignment.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp06_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Getting Started</a>
# 1. <a href="#section2">the PyChess API</a>
# 1. <a href="#section3">Assignment</a>
# 1. <a href="#section4">Extra Credit</a>
# 1. <a href="#section5">Submitted to Gradescope</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## I. Getting Started

# %% [markdown]
# The `main.py` file will be the primary entry point for this assignment. Let’s start by running it as follows:

# %%
# !python3 main.py --help
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# usage: main.py [-h] [--player0 {random,human,minimax,alphabeta,stochastic}]
#                [--player1 {random,human,minimax,alphabeta,stochastic}]
#                [--depth0 DEPTH0] [--depth1 DEPTH1] [--breadth0 BREADTH0]
#                [--breadth1 BREADTH1] [--loadgame LOADGAME]
#
# CS440 MP5 Chess
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --player0 {random,human,minimax,alphabeta,stochastic}
#                         Is player 0 a human, a random player, or some type of
#                         AI? (default: human)
#   --player1 {random,human,minimax,alphabeta,stochastic}
#                         Is player 1 a human, a random player, or some type of
#                         AI? (default: random)
#   --depth0 DEPTH0       Depth to which player 0 should search, if player 0 is
#                         an AI. (default: 2)
#   --depth1 DEPTH1       Depth to which player 1 should search, if player 1 is
#                         an AI. (default: 2)
#   --breadth0 BREADTH0   Breadth to which player 0 should search, if player 0
#                         is stochastic. (default: 2)
#   --breadth1 BREADTH1   Breadth to which player 1 should search, if player 1
#                         is stochastic. (default: 2)
#   --loadgame LOADGAME   Load a saved game from res/savedGames (default: None)

# %% [markdown]
# This will list the available options.  You will see that both player0  and player1 can  be human, or one of four types  of AI: random, minimax, alphabeta, or stochastic. The default is `--player0 human --player1 random`, because the random player is the only one already implemented.  In order to play against an "AI" that makes moves at random, type

# %%
# !python3 main.py
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# You should see a chess board pop up.  When you click on any white piece (you may need to double-click), you should see bright neon green dots centered in all of the squares to which that piece can legally move, like this:
#
# <p align="center">
#     <img width="400" src="images/assignment5_human.png"/>
# </p>
#
# When you click (or double-click) on one of those green dots, your piece will move there.  Then the computer will move one of the black pieces, and it will be your turn again.
#
# If you have trouble using the mouse to play, you can debug your code by watching the computer play against itself.  For example,
# ```bash
# python3 main.py --player0 random --player1 random
# ```
#
# If you want to start from one of the stored game positions, you can load them as, for example:
# ```bash
# python3 main.py --loadgame game1.txt
# ```
#
# We will grade your submissions using `grade.py`. This file is available to you, so that you can understand how this assignment will be graded.
#
# Let’s see what happens when we run this script:

# %%
# !python3 grade.py
# Out:
# .......
# ----------------------------------------------------------------------
# Ran 7 tests in 139.055s
#
# OK

# %% [markdown]
# As you can see, all of the tests raise `NotImplementedError`, because we have not yet implemented the functions `minimax` or `alphabeta` in `submitted.py`. We will do this in the next few sections.

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## II. the PyChess API

# %% [markdown]
# The chess-playing interface that we're using is based on [**PyChess**](https://github.com/pychess/pychess).  All the components of PyChess that you need are included in the assignment5.zip file, but if you want to learn more about PyChess, you are welcome to download and install it.  The standard distribution of PyChess includes a game-playing AI using the alphabeta search algorithm.  You are welcome to read their implementation to get hints for how to write your own, but note that we have changed the function signature so that if you simply cut and paste their code into your own, it will not work.
#
# You do not need to know how to play chess in order to do this assignment.  You need to know that chess is a game between two players, one with white pieces, one with black pieces.  White goes first.  Players alternate making moves until white wins, black wins, or there is a tie.  You don't need to know anything else about chess to do the assignment, though you may have more fun if you learn just a little (e.g., by playing against the computer).
#
# Though you don't need to know anything about chess, you do need to understand a few key concepts, and a few key functions, from the PyChess API.  The most important concepts are:
#
# 1. **player**.  There are two players: Player 0, and Player 1.
# Player 0 plays white pieces, Player 1 black. Player 0 goes first.
#     - **side**. PyChess keeps track of whose turn it is by using a boolean called **side**:
#     `side==False` if Player 0 should play next.
# 2. **move**.  A move is a 3-list: `move==[fro,to,promote]`.
# `fro` is a 2-list: `fro==[from_x,from_y]`, where `from_x` and `from_y` are each numbers between 1 and 8, specifying the starting x and y positions.  `to` is also a 2-list: `to==[to_x,to_y]`.
# `promote` is either `None` or `"q"`, where `q` means that you are trying to promote your piece to a queen.
# 3. **board**.  A board is a 2-tuple of lists of pieces: `board==([white_piece0, white_piece1, ...], [black_piece0, black_piece1, ...])`.
# Each piece is a 3-list: `piece=[x,y,type]`.
# `x` is the x position of the piece (left-to-right, 1 to 8).
# `y` is the y  position of the piece (top-to-bottom, 1 to 8).
# `type` is a letter indicating the type of piece, which can be (`p`=pawn, `r`=rook, `n`=knight, `b`=bishop, `q`=queen, or `k`=king).
#
# To get some better understanding, let's look at the way the board is initialized at the start of the game.  The function `chess.lib.convertMoves` starts with an initialized board, then runs forward through a series of specified moves, and gives us the resulting board.  If the series of specified moves is the empty string, then `chess.lib.convertMoves` gives us the opening board position:

# %%
import chess.lib.utils, pprint

side, board, flags = chess.lib.convertMoves("")

print("Should we start with the White player?", side)

print("")

print("The starting board position is:")

pprint.PrettyPrinter(compact=True,width=40).pprint(board)
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Should we start with the White player? False
#
# The starting board position is:
# [[[1, 7, 'p'], [2, 7, 'p'], [3, 7, 'p'],
#   [4, 7, 'p'], [5, 7, 'p'], [6, 7, 'p'],
#   [7, 7, 'p'], [8, 7, 'p'], [1, 8, 'r'],
#   [2, 8, 'n'], [3, 8, 'b'], [4, 8, 'q'],
#   [5, 8, 'k'], [6, 8, 'b'], [7, 8, 'n'],
#   [8, 8, 'r']],
#  [[1, 2, 'p'], [2, 2, 'p'], [3, 2, 'p'],
#   [4, 2, 'p'], [5, 2, 'p'], [6, 2, 'p'],
#   [7, 2, 'p'], [8, 2, 'p'], [1, 1, 'r'],
#   [2, 1, 'n'], [3, 1, 'b'], [4, 1, 'q'],
#   [5, 1, 'k'], [6, 1, 'b'], [7, 1, 'n'],
#   [8, 1, 'r']]]

# %% [markdown]
# ### II.A evaluate
#
# The function `value=evaluate(board)` returns the heuristic value of the board for the white player (thus, in the textbook's terminology, the white player is Max, the black player is Min).
#
# For example, you can find the numerical value of a board by typing:

# %%
import chess.lib.heuristics

# Try the default board
value = chess.lib.heuristics.evaluate(board)
print("The value of the default board is",value)

# Try a board where Black is missing a rook
board2 = [ board[0], board[1][:-1] ]
value = chess.lib.heuristics.evaluate(board2)
print("If we eliminate one of black's rooks, the value is ",value)

# Try a board where White is missing a rook
board3 = [ board[0][:-1], board[1] ]
value = chess.lib.heuristics.evaluate(board3)
print("If we eliminate one of white's rooks, the value is ",value)

# Eliminate one piece from each player
board4 = [ board[0][:-1], board[1][:-1] ]
value = chess.lib.heuristics.evaluate(board4)
print("If the players are each missing a rook, the value is ",value)
# Out:
# The value of the default board is 0.0
# If we eliminate one of black's rooks, the value is  14.0
# If we eliminate one of white's rooks, the value is  -14.0
# If the players are each missing a rook, the value is  0.0

# %% [markdown]
# ### II.B encode and decode
#
# Lists cannot be used as keys in a dict, therefore, in order to give your `moveTree` to the autograder, you will need some way to encode the moves.  `encoded=encode(*move)` converts a `move` into a string representing its standard chess encoding.  The **decode** function reverses the processing of `encode`.  For example:

# %%
from chess.lib.utils import encode, decode

# This statement evaluates to True
move1 = encode([7,2],[7,4],None)
print("The move [7,2]->[7,4] encodes as",move1)

# This statement also evaluates to True
move2=encode([5,7],[5,8],"q")
print("The move [5,7]->[5,8] with promotion to queen is encoded as",move2)

# This statement evaluates to True
move3 = decode("g7g5")
print("The move g7g5 is decoded to",move3)
# Out:
# The move [7,2]->[7,4] encodes as g7g5
# The move [5,7]->[5,8] with promotion to queen is encoded as e2e1q
# The move g7g5 is decoded to [[7, 2], [7, 4], None]

# %% [markdown]
# ### II.C generateMoves, convertMoves, makeMove
#
# The function **generateMoves** is a [generator](https://docs.python.org/3/glossary.html#term-generator) that generates all moves that are legal on the current board.  The function **convertMoves** generates a starting board.  The function **makeMove**  implements a move, and returns the resulting board (and side and flags).  For example, the following code prints all of the moves that white can legally make, starting from the beginning board:

# %%
import submitted, importlib
import chess.lib

# Create an initial board
side, board, flags = chess.lib.convertMoves("")

# Iterate over all moves that are legal from the current  board position.  
for move in submitted.generateMoves(side,board,flags):
    newside, newboard, newflags = chess.lib.makeMove(side, board, move[0], move[1], flags, move[2])
    print("This move is legal now:",move, newflags)
# Out:
# This move is legal now: [[1, 7], [1, 5], None] ([True, True, True, True], [1, 6])
# This move is legal now: [[1, 7], [1, 6], None] ([True, True, True, True], None)
# This move is legal now: [[2, 7], [2, 5], None] ([True, True, True, True], [2, 6])
# This move is legal now: [[2, 7], [2, 6], None] ([True, True, True, True], None)
# This move is legal now: [[3, 7], [3, 5], None] ([True, True, True, True], [3, 6])
# This move is legal now: [[3, 7], [3, 6], None] ([True, True, True, True], None)
# This move is legal now: [[4, 7], [4, 5], None] ([True, True, True, True], [4, 6])
# This move is legal now: [[4, 7], [4, 6], None] ([True, True, True, True], None)
# This move is legal now: [[5, 7], [5, 5], None] ([True, True, True, True], [5, 6])
# This move is legal now: [[5, 7], [5, 6], None] ([True, True, True, True], None)
# This move is legal now: [[6, 7], [6, 5], None] ([True, True, True, True], [6, 6])
# This move is legal now: [[6, 7], [6, 6], None] ([True, True, True, True], None)
# This move is legal now: [[7, 7], [7, 5], None] ([True, True, True, True], [7, 6])
# This move is legal now: [[7, 7], [7, 6], None] ([True, True, True, True], None)
# This move is legal now: [[8, 7], [8, 5], None] ([True, True, True, True], [8, 6])
# This move is legal now: [[8, 7], [8, 6], None] ([True, True, True, True], None)
# This move is legal now: [[2, 8], [3, 6], None] ([True, True, True, True], None)
# This move is legal now: [[2, 8], [1, 6], None] ([True, True, True, True], None)
# This move is legal now: [[7, 8], [8, 6], None] ([True, True, True, True], None)
# This move is legal now: [[7, 8], [6, 6], None] ([True, True, True, True], None)

# %% [markdown]
# The **flags** and **newflags** variables specify whether or not it has become legal for black to make certain specialized types of moves.  For more information, see `chess/docs.txt`.

# %% [markdown]
# ### II.D random
#
# In order to help you understand the API, the file `submitted.py` contains a function from which you can copy any useful code.  The function `moveList, moveTree, value  = random(side, board, flags, chooser)` takes  the same input as the functions you  will write, and generates the same type of output, but instead of choosing a smart move, it chooses a move at random.
#
# Here, the input parameter `chooser` is set to `chooser=`<a href="https://docs.python.org/3/library/random.html#functions-for-sequences">random.choice</a> during normal game play, but during grading, it will be set to some other function that selects a move in a non-random fashion.  Use this function as if it were equivalent to `random.choice`.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.random)
# Out:
# Help on function random in module submitted:
#
# random(side, board, flags, chooser)
#     Return a random move, resulting board, and value of the resulting board.
#     Return: (value, moveList, boardList)
#       value (int or float): value of the board after making the chosen move
#       moveList (list): list with one element, the chosen move
#       moveTree (dict: encode(*move)->dict): a tree of moves that were evaluated in the search process
#     Input:
#       side (boolean): True if player1 (Min) plays next, otherwise False
#       board (2-tuple of lists): current board layout, used by generateMoves and makeMove
#       flags (list of flags): list of flags, used by generateMoves and makeMove
#       chooser: a function similar to random.choice, but during autograding, might not be random.

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## III. Assignment

# %% [markdown]
# For this assignment, you will need to write three functions: `minimax` and `alphabeta`.  The content of these functions is described in the sections that follow.

# %% [markdown]
# ### III.A minimax search
#
# For Part 1 of this assignment, you will implement minimax search. Specifically, you will implement a function `minimax(side, board, flags, depth)` in `search.py` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.minimax)
# Out:
# Help on function minimax in module submitted:
#
# minimax(side, board, flags, depth)
#     Return a minimax-optimal move sequence, tree of all boards evaluated, and value of best path.
#     Return: (value, moveList, moveTree)
#       value (float): value of the final board in the minimax-optimal move sequence
#       moveList (list): the minimax-optimal move sequence, as a list of moves
#       moveTree (dict: encode(*move)->dict): a tree of moves that were evaluated in the search process
#     Input:
#       side (boolean): True if player1 (Min) plays next, otherwise False
#       board (2-tuple of lists): current board layout, used by generateMoves and makeMove
#       flags (list of flags): list of flags, used by generateMoves and makeMove
#       depth (int >=0): depth of the search (number of moves)

# %% [markdown]
# As you  can see, the function accepts `side`, `board`, and `flags` variables, and a non-negative integer, `depth`.  It should perform minimax search over all possible move sequences of length `depth`, and return the complete tree of evaluated moves as `moveTree`.  If `side==True`, you should choose a path through this tree that minimizes the heuristic value of the final board, knowing that your opponent will be trying to maximize value; conversely if `side==False`.  Return the resulting optimal list of moves (including moves by both white and black) as `moveList`, and the numerical value of the final board as `value`.
#
# A note about `depth`: The `depth` parameter specifies the total number of moves, including moves by both white and black.  If `depth==1` and `side==False`, then you should just find one move, from the current board, that maximizes the value of the resulting board.  If `depth==2` and `side==False`, then you should find a white move, and the immediate following black move.  If `depth==3` and `side==False`, then you should find a white, black, white sequence of moves.  For example, see [wikipedia's page on minimax](https://en.wikipedia.org/wiki/Minimax#Minimax_algorithm_with_alternate_moves) for examples and pseudo-code.
#
# You are strongly encouraged to look at the grading examples in the `grading_examples` folder, to get a better understanding of what the `minimax` function outputs should look like.  For example, the board game in `more grading_examples/minimax_game0_depth2.json` contains `value` on the first line, `moveList` on the second line, and `moveTree` on the third line:

# %%
import json, pprint
with open("grading_examples/minimax_game0_depth2.json","r") as f:
    value=json.loads(f.readline())
    print("value is",value,"\n")
    moveList=json.loads(f.readline())
    print("moveList is",moveList,"\n")
    moveTree=json.loads(f.readline())
    print("moveTree is:",moveTree,"\n")
# Out:
# value is 10.0
#
# moveList is [[[2, 1], [3, 3], None], [[4, 7], [4, 5], None]]
#
# moveTree is: {'a7a5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'a7a6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'b7b5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'b7b6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'c7c5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'c7c6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'd7d5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'd7d6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'e7e5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'e7e6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'f7f5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'f7f6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'g5g4': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'h7h5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': ...

# %%
# import json, pprint
# with open("grading_examples/minimax_game0_depth2.json","r") as f:
#     value=json.loads(f.readline())
#     print("value is",value,"\n")
#     moveList=json.loads(f.readline())
#     print("moveList is",moveList,"\n")
#     moveTree=json.loads(f.readline())
#     print("moveTree is:",moveTree,"\n")
# Out:
# value is 10.0
#
# moveList is [[[2, 1], [3, 3], None], [[4, 7], [4, 5], None]]
#
# moveTree is: {'a7a5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'a7a6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'b7b5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'b7b6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'c7c5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'c7c6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'd7d5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'd7d6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'e7e5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'e7e6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'f7f5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'f7f6': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'g5g4': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g3': {}, 'h2h4': {}, 'h2h3': {}, 'a1b1': {}, 'c3d5': {}, 'c3b1': {}, 'c3b5': {}, 'c3e4': {}, 'c3a4': {}, 'f3g1': {}, 'f3g5': {}, 'f3e5': {}, 'f3h4': {}, 'f3d4': {}, 'h1g1': {}}, 'h7h5': {'a2a4': {}, 'a2a3': {}, 'b2b4': {}, 'b2b3': {}, 'd2d4': {}, 'd2d3': {}, 'e2e4': {}, 'e2e3': {}, 'g2g4': {}, 'g2g3': ...

# %% [markdown]
# You will certainly want to implement `minimax` as a recursive function.  You will certainly want to use the function `generateMoves` to generate all moves that are legal in the current game state, and you will certainly want to use `makeMove` to find the newside, newboard, and newflags that result from making each move.  When you  get to `depth==0`, you will certainly want to use `evaluate(board)` in order to compute the heuristic value of the resulting board.
#
# Once  you  have implemented minimax, you can test it by playing against it.  If you have pygame installed, the following line should pop up a board on which you can play against your own minimax player.  If you have not yet written `minimax`, the game will throw a `NotImplementedError` when it is white's turn to move.

# %%
# !python3 main.py --player1 minimax
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Test that it is working correctly by moving one of your knights forward.  The computer should respond by moving one of its knights foward, as shown here:
#
# <p align="center">
#     <img width="400" src="images/assignment5_figure1.png"/>
# </p>
#
# If you want to watch a minimax agent win against a random-move agent, you can type

# %%
# !python3 main.py --player0 minimax --player1 random
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### III.B alphabeta search
#
# For Part 2 of this assignment, you will implement alphabeta search. Specifically, you will implement a function `alphabeta(side, board, flags, depth)` in `search.py` with the following docstring:

# %%
import submitted
help(submitted.alphabeta)
# Out:
# Help on function alphabeta in module submitted:
#
# alphabeta(side, board, flags, depth, alpha=-inf, beta=inf)
#     Return minimax-optimal move sequence, and a tree that exhibits alphabeta pruning.
#     Return: (value, moveList, moveTree)
#       value (float): value of the final board in the minimax-optimal move sequence
#       moveList (list): the minimax-optimal move sequence, as a list of moves
#       moveTree (dict: encode(*move)->dict): a tree of moves that were evaluated in the search process
#     Input:
#       side (boolean): True if player1 (Min) plays next, otherwise False
#       board (2-tuple of lists): current board layout, used by generateMoves and makeMove
#       flags (list of flags): list of flags, used by generateMoves and makeMove
#       depth (int >=0): depth of the search (number of moves)

# %% [markdown]
# For any given input board, this function should return exactly the same value and moveList as `minimax`; the only difference between the two functions will be the returned `moveTree`.  The tree returned by `alphabeta` should have fewer leaf nodes than the one returned by `minimax`, because alphabeta pruning should make it unnecessary to evaluate some of the leaf nodes.
#
# You can test this using:

# %%
# !python3 main.py --player1 alphabeta
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Traceback (most recent call last):
#   File "/Users/dongmingsbrick/Desktop/ece448/mp06/main.py", line 182, in <module>
#     application.run()
#   File "/Users/dongmingsbrick/Desktop/ece448/mp06/main.py", line 118, in run
#     self.makemove(moveList[0][0], moveList[0][1])
# IndexError: list index out of range

# %%
# !python3 main.py --player0 random --player1 alphabeta
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## IV. Extra Credit
#
# The heuristic we've been using, until now, is the default PyChess heuristic: it assigns a value to each piece, with extra points added or subtracted depending on the piece's location. For extra credit, if you wish, you can try to train a neural network to compute a better heuristic.

# %% [markdown]
# ### IV.A. The Game
#
# The extra credit assignment will be graded based on how  often  your heuristic beats the default PhChess heuristic in a two-player game.
#
# Ideally, the game would be chess.  Unfortunately, grading your heuristic based on complete chess games would take too much time.  Instead, the function `extracredit_grade.py` plays a very simple game:
#
# 1. Each of the two players is given the same chess board.  Each of you assigns a numerical value to the board.
# 2. Then, the scoring program finds the depth-two minimax value of the same board.  This value is provided in the lists called "values" in the data files `extracredit_train.txt` and `extracredit_validation.txt`; but if you have already completed the main assignment, it should be the same value that you'd get by running your  `minimax` or `alphabeta` search with `depth=2`.
# 3. The winner of the game is the player whose computed value is closest to the reference value.
#
# Notice that what we're asking you to do, basically, is to create a neural network that can guess the value of the PyChess heuristic two steps ahead.
#
# Notice that, if you can design a funny neural net architecture that, instead of being trained to solve this problem, solves it without training by exactly computing a two-step minimax operation, then  you're done.  This is explicitly allowed, because we think it would be a very effective and very interesting solution.
#
# Most of you, we guess, will choose a more general neural net architecture, and train it so that it imitates the results of two-step minimax.

# %% [markdown]
# ### IV.B. Distributed Code: Exactly Reproduce the PyChess Heuristic
#
# Dowload the [extra credit package](mp06_extracredit.zip), and unpack it.   You will find the following files:
# - extracredit.py: Trains the model.  This is the code you will edit and submit.
# - extracredit_embedding.py: Embeds a chess board into a (15x8x8) binary pytorch tensor.
# - extracredit_train.txt: Training data: sequences of moves, and corresponding values.
# - extracredit_validation.txt: Validation data: sequences of moves, and corresponding values.
# - extracredit_grade.py: The grading script.
#
# Try the following:

# %%
# !python3 extracredit.py
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# /Users/dongmingsbrick/Desktop/ece448/mp06/extracredit_embedding.py:107: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1670525473998/work/torch/csrc/utils/tensor_new.cpp:233.)
#   self.embeddings = torch.tensor(embeddings,dtype=DTYPE,device=DEVICE)
# epoch:  0 loss:  tensor(1193.9086, grad_fn=<MseLossBackward0>)
# epoch:  1 loss:  tensor(1114.4131, grad_fn=<MseLossBackward0>)
# epoch:  2 loss:  tensor(1555.2301, grad_fn=<MseLossBackward0>)
# epoch:  3 loss:  tensor(1111.1344, grad_fn=<MseLossBackward0>)
# epoch:  4 loss:  tensor(1041.4644, grad_fn=<MseLossBackward0>)
# epoch:  5 loss:  tensor(944.8100, grad_fn=<MseLossBackward0>)
# epoch:  6 loss:  tensor(781.5192, grad_fn=<MseLossBackward0>)
# epoch:  7 loss:  tensor(709.7291, grad_fn=<MseLossBackward0>)
# epoch:  8 loss:  tensor(561.8831, grad_fn=<MseLossBackward0>)
# epoch:  9 loss:  tensor(520.9765, grad_fn=<MseLossBackward0>)
# epoch:  10 loss:  tensor(480.1424, grad_fn=<MseLossBackward0>)
# epoch:  11 loss:  tensor(408.8333, grad_fn=<MseLossBackward0>)
# epoch:  12 loss:  tensor(362.0358, grad_fn=<MseLossBackward0>)
# epoch:  13 loss:  tensor(297.7564, grad_fn=<MseLossBackward0>)
# epoch:  14 loss:  tensor(289.8150, grad_fn=<MseLossBackward0>)
# epoch:  15 loss:  tensor(275.1573, grad_fn=<MseLossBackward0>)
# epoch:  16 loss:  tensor(278.9669, grad_fn=<MseLossBackward0>)
# epoch:  17 loss:  tensor(258.0420, grad_fn=<MseLossBackward0>)
# epoch:  18 loss:  tensor(213.3130, grad_fn=<MseLossBackward0>)
# epoch:  19 loss:  tensor(201.4473, grad_fn=<MseLossBackward0>)
# epoch:  20 loss:  tensor(179.9279, grad_fn=<MseLossBackward0>)
# epoch:  21 loss:  tensor(175.9930, grad_fn=<MseLossBackward0>)
# epoch:  22 loss:  tensor(172.0964, grad_fn=<MseLossBackward0>)
# epoch:  23 loss:  tensor(150.6474, grad_fn=<MseLossBackward0>)
# epoch:  24 loss:  tensor(147.6431, grad_fn=<MseLossBackward0>)
# epoch:  25 loss:  tensor(129.1877, grad_fn=<MseLossBackward0>)
# epoch:  26 loss:  tensor(119.9706, grad_fn=<MseLossBackward0>)
# epoch:  27 loss:  tensor(120.1697, grad_fn=<MseLossBackward0>)
# epoch:  28 loss:  tensor(106.4705, grad_fn=<MseLossBackward0>)
# epoch:  29 loss:  tensor(102.5226, grad_fn=<MseLossBackward0>)
# epoch:  30 loss:  tensor(100.6748, grad_fn=<MseLossBackward0>)
# epoch:  31 loss:  tensor(87.3631, grad_fn=<MseLossBackward0>)
# epoch:  32 loss:  tensor(84.4309, grad_fn=<MseLossBackward0>)
# epoch:  33 loss:  tensor(80.7167, grad_fn=<MseLossBackward0>)
# epoch:  34 loss:  tensor(71.9116, grad_fn=<MseLossBackward0>)
# epoch:  35 loss:  tensor(72.0512, grad_fn=<MseLossBackward0>)
# epoch:  36 loss:  tensor(66.2704, grad_fn=<MseLossBackward0>)
# epoch:  37 loss:  tensor(59.6720, grad_fn=<MseLossBackward0>)
# epoch:  38 loss:  tensor(59.2804, grad_fn=<MseLossBackward0>)
# epoch:  39 loss:  tensor(53.0415, grad_fn=<MseLossBackward0>)
# epoch:  40 loss:  tensor(48.3565, grad_fn=<MseLossBackward0>)
# epoch:  41 loss:  tensor(48.4480, grad_fn=<MseLossBackward0>)
# epoch:  42 loss:  tensor(43.6020, grad_fn=<MseLossBackward0>)
# epoch:  43 loss:  tensor(38.8941, grad_fn=<MseLossBackward0>)
# epoch:  44 loss:  tensor(38.9035, grad_fn=<MseLossBackward0>)
# epoch:  45 loss:  tensor(35.4449, grad_fn=<MseLossBackward0>)
# epoch:  46 loss:  tensor(31.6638, grad_fn=<MseLossBackward0>)
# epoch:  47 loss:  tensor(32.0731, grad_fn=<MseLossBackward0>)
# epoch:  48 loss:  tensor(28.9769, grad_fn=<MseLossBackward0>)
# epoch:  49 loss:  tensor(26.3300, grad_fn=<MseLossBackward0>)
# epoch:  50 loss:  tensor(26.8396, grad_fn=<MseLossBackward0>)
# epoch:  51 loss:  tensor(24.1943, grad_fn=<MseLossBackward0>)
# epoch:  52 loss:  tensor(22.0474, grad_fn=<MseLossBackward0>)
# epoch:  53 loss:  tensor(22.4078, grad_fn=<MseLossBackward0>)
# epoch:  54 loss:  tensor(20.6936, grad_fn=<MseLossBackward0>)
# epoch:  55 loss:  tensor(18.9050, grad_fn=<MseLossBackward0>)
# epoch:  56 loss:  tensor(19.4649, grad_fn=<MseLossBackward0>)
# epoch:  57 loss:  tensor(18.3506, grad_fn=<MseLossBackward0>)
# epoch:  58 loss:  tensor(16.4637, grad_fn=<MseLossBackward0>)
# epoch:  59 loss:  tensor(16.8604, grad_fn=<MseLossBackward0>)
# epoch:  60 loss:  tensor(16.2202, grad_fn=<MseLossBackward0>)
# epoch:  61 loss:  tensor(14.5666, grad_fn=<MseLossBackward0>)
# epoch:  62 loss:  tensor(14.6326, grad_fn=<MseLossBackward0>)
# epoch:  63 loss:  tensor(14.4795, grad_fn=<MseLossBackward0>)
# epoch:  64 loss:  tensor(12.9176, grad_fn=<MseLossBackward0>)
# epoch:  65 loss:  tensor(12.5726, grad_fn=<MseLossBackward0>)
# epoch:  66 loss:  tensor(12.7742, grad_fn=<MseLossBackward0>)
# epoch:  67 loss:  tensor(11.7612, grad_fn=<MseLossBackward0>)
# epoch:  68 loss:  tensor(10.9161, grad_fn=<MseLossBackward0>)
# epoch:  69 loss:  tensor(10.9928, grad_fn=<MseLossBackward0>)
# epoch:  70 loss:  tensor(10.7795, grad_fn=<MseLossBackward0>)
# epoch:  71 loss:  tensor(9.9998, grad_fn=<MseLossBackward0>)
# epoch:  72 loss:  tensor(9.3606, grad_fn=<MseLossBackward0>)
# epoch:  73 loss:  tensor(9.3391, grad_fn=<MseLossBackward0>)
# epoch:  74 loss:  tensor(9.2571, grad_fn=<MseLossBackward0>)
# epoch:  75 loss:  tensor(8.7015, grad_fn=<MseLossBackward0>)
# epoch:  76 loss:  tensor(8.0413, grad_fn=<MseLossBackward0>)
# epoch:  77 loss:  tensor(7.7399, grad_fn=<MseLossBackward0>)
# epoch:  78 loss:  tensor(7.6917, grad_fn=<MseLossBackward0>)
# epoch:  79 loss:  tensor(7.6323, grad_fn=<MseLossBackward0>)
# epoch:  80 loss:  tensor(7.2269, grad_fn=<MseLossBackward0>)
# epoch:  81 loss:  tensor(6.7510, grad_fn=<MseLossBackward0>)
# epoch:  82 loss:  tensor(6.3147, grad_fn=<MseLossBackward0>)
# epoch:  83 loss:  tensor(6.0970, grad_fn=<MseLossBackward0>)
# epoch:  84 loss:  tensor(5.9725, grad_fn=<MseLossBackward0>)
# epoch:  85 loss:  tensor(5.9152, grad_fn=<MseLossBackward0>)
# epoch:  86 loss:  tensor(5.9124, grad_fn=<MseLossBackward0>)
# epoch:  87 loss:  tensor(5.8024, grad_fn=<MseLossBackward0>)
# epoch:  88 loss:  tensor(5.7318, grad_fn=<MseLossBackward0>)
# epoch:  89 loss:  tensor(5.4698, grad_fn=<MseLossBackward0>)
# epoch:  90 loss:  tensor(5.2246, grad_fn=<MseLossBackward0>)
# epoch:  91 loss:  tensor(4.8073, grad_fn=<MseLossBackward0>)
# epoch:  92 loss:  tensor(4.4735, grad_fn=<MseLossBackward0>)
# epoch:  93 loss:  tensor(4.1677, grad_fn=<MseLossBackward0>)
# epoch:  94 loss:  tensor(3.9044, grad_fn=<MseLossBackward0>)
# epoch:  95 loss:  tensor(3.6937, grad_fn=<MseLossBackward0>)
# epoch:  96 loss:  tensor(3.5137, grad_fn=<MseLossBackward0>)
# epoch:  97 loss:  tensor(3.3552, grad_fn=<MseLossBackward0>)
# epoch:  98 loss:  tensor(3.2015, grad_fn=<MseLossBackward0>)
# epoch:  99 loss:  tensor(3.0566, grad_fn=<MseLossBackward0>)
# epoch:  100 loss:  tensor(2.9297, grad_fn=<MseLossBackward0>)
# epoch:  101 loss:  tensor(2.8193, grad_fn=<MseLossBackward0>)
# epoch:  102 loss:  tensor(2.7697, grad_fn=<MseLossBackward0>)
# epoch:  103 loss:  tensor(2.9100, grad_fn=<MseLossBackward0>)
# epoch:  104 loss:  tensor(3.7235, grad_fn=<MseLossBackward0>)
# epoch:  105 loss:  tensor(6.4905, grad_fn=<MseLossBackward0>)
# epoch:  106 loss:  tensor(15.3124, grad_fn=<MseLossBackward0>)
# epoch:  107 loss:  tensor(24.4412, grad_fn=<MseLossBackward0>)
# epoch:  108 loss:  tensor(32.5808, grad_fn=<MseLossBackward0>)
# epoch:  109 loss:  tensor(6.0020, grad_fn=<MseLossBackward0>)
# epoch:  110 loss:  tensor(12.1707, grad_fn=<MseLossBackward0>)
# epoch:  111 loss:  tensor(33.1100, grad_fn=<MseLossBackward0>)
# epoch:  112 loss:  tensor(7.8559, grad_fn=<MseLossBackward0>)
# epoch:  113 loss:  tensor(16.0765, grad_fn=<MseLossBackward0>)
# epoch:  114 loss:  tensor(22.1428, grad_fn=<MseLossBackward0>)
# epoch:  115 loss:  tensor(4.9893, grad_fn=<MseLossBackward0>)
# epoch:  116 loss:  tensor(25.1139, grad_fn=<MseLossBackward0>)
# epoch:  117 loss:  tensor(17.3241, grad_fn=<MseLossBackward0>)
# epoch:  118 loss:  tensor(11.9956, grad_fn=<MseLossBackward0>)
# epoch:  119 loss:  tensor(19.3568, grad_fn=<MseLossBackward0>)
# epoch:  120 loss:  tensor(3.4768, grad_fn=<MseLossBackward0>)
# epoch:  121 loss:  tensor(17.8144, grad_fn=<MseLossBackward0>)
# epoch:  122 loss:  tensor(3.0117, grad_fn=<MseLossBackward0>)
# epoch:  123 loss:  tensor(13.6678, grad_fn=<MseLossBackward0>)
# epoch:  124 loss:  tensor(4.9215, grad_fn=<MseLossBackward0>)
# epoch:  125 loss:  tensor(10.2296, grad_fn=<MseLossBackward0>)
# epoch:  126 loss:  tensor(4.1049, grad_fn=<MseLossBackward0>)
# epoch:  127 loss:  tensor(7.7925, grad_fn=<MseLossBackward0>)
# epoch:  128 loss:  tensor(5.2376, grad_fn=<MseLossBackward0>)
# epoch:  129 loss:  tensor(5.9321, grad_fn=<MseLossBackward0>)
# epoch:  130 loss:  tensor(4.5912, grad_fn=<MseLossBackward0>)
# epoch:  131 loss:  tensor(4.5119, grad_fn=<MseLossBackward0>)
# epoch:  132 loss:  tensor(4.3790, grad_fn=<MseLossBackward0>)
# epoch:  133 loss:  tensor(3.6796, grad_fn=<MseLossBackward0>)
# epoch:  134 loss:  tensor(3.9786, grad_fn=<MseLossBackward0>)
# epoch:  135 loss:  tensor(2.7681, grad_fn=<MseLossBackward0>)
# epoch:  136 loss:  tensor(3.4092, grad_fn=<MseLossBackward0>)
# epoch:  137 loss:  tensor(2.6068, grad_fn=<MseLossBackward0>)
# epoch:  138 loss:  tensor(3.0686, grad_fn=<MseLossBackward0>)
# epoch:  139 loss:  tensor(1.8458, grad_fn=<MseLossBackward0>)
# epoch:  140 loss:  tensor(2.8356, grad_fn=<MseLossBackward0>)
# epoch:  141 loss:  tensor(1.7813, grad_fn=<MseLossBackward0>)
# epoch:  142 loss:  tensor(2.3622, grad_fn=<MseLossBackward0>)
# epoch:  143 loss:  tensor(1.4996, grad_fn=<MseLossBackward0>)
# epoch:  144 loss:  tensor(2.1684, grad_fn=<MseLossBackward0>)
# epoch:  145 loss:  tensor(1.2368, grad_fn=<MseLossBackward0>)
# epoch:  146 loss:  tensor(1.9942, grad_fn=<MseLossBackward0>)
# epoch:  147 loss:  tensor(1.0954, grad_fn=<MseLossBackward0>)
# epoch:  148 loss:  tensor(1.6997, grad_fn=<MseLossBackward0>)
# epoch:  149 loss:  tensor(1.0213, grad_fn=<MseLossBackward0>)
# epoch:  150 loss:  tensor(1.5344, grad_fn=<MseLossBackward0>)
# epoch:  151 loss:  tensor(0.9016, grad_fn=<MseLossBackward0>)
# epoch:  152 loss:  tensor(1.3687, grad_fn=<MseLossBackward0>)
# epoch:  153 loss:  tensor(0.8588, grad_fn=<MseLossBackward0>)
# epoch:  154 loss:  tensor(1.1646, grad_fn=<MseLossBackward0>)
# epoch:  155 loss:  tensor(0.8434, grad_fn=<MseLossBackward0>)
# epoch:  156 loss:  tensor(1.0123, grad_fn=<MseLossBackward0>)
# epoch:  157 loss:  tensor(0.8169, grad_fn=<MseLossBackward0>)
# epoch:  158 loss:  tensor(0.8485, grad_fn=<MseLossBackward0>)
# epoch:  159 loss:  tensor(0.8203, grad_fn=<MseLossBackward0>)
# epoch:  160 loss:  tensor(0.7229, grad_fn=<MseLossBackward0>)
# epoch:  161 loss:  tensor(0.7938, grad_fn=<MseLossBackward0>)
# epoch:  162 loss:  tensor(0.6411, grad_fn=<MseLossBackward0>)
# epoch:  163 loss:  tensor(0.7356, grad_fn=<MseLossBackward0>)
# epoch:  164 loss:  tensor(0.5823, grad_fn=<MseLossBackward0>)
# epoch:  165 loss:  tensor(0.6995, grad_fn=<MseLossBackward0>)
# epoch:  166 loss:  tensor(0.5341, grad_fn=<MseLossBackward0>)
# epoch:  167 loss:  tensor(0.6249, grad_fn=<MseLossBackward0>)
# epoch:  168 loss:  tensor(0.5295, grad_fn=<MseLossBackward0>)
# epoch:  169 loss:  tensor(0.5469, grad_fn=<MseLossBackward0>)
# epoch:  170 loss:  tensor(0.5226, grad_fn=<MseLossBackward0>)
# epoch:  171 loss:  tensor(0.4848, grad_fn=<MseLossBackward0>)
# epoch:  172 loss:  tensor(0.5035, grad_fn=<MseLossBackward0>)
# epoch:  173 loss:  tensor(0.4398, grad_fn=<MseLossBackward0>)
# epoch:  174 loss:  tensor(0.4761, grad_fn=<MseLossBackward0>)
# epoch:  175 loss:  tensor(0.4099, grad_fn=<MseLossBackward0>)
# epoch:  176 loss:  tensor(0.4390, grad_fn=<MseLossBackward0>)
# epoch:  177 loss:  tensor(0.3990, grad_fn=<MseLossBackward0>)
# epoch:  178 loss:  tensor(0.3927, grad_fn=<MseLossBackward0>)
# epoch:  179 loss:  tensor(0.3888, grad_fn=<MseLossBackward0>)
# epoch:  180 loss:  tensor(0.3591, grad_fn=<MseLossBackward0>)
# epoch:  181 loss:  tensor(0.3697, grad_fn=<MseLossBackward0>)
# epoch:  182 loss:  tensor(0.3375, grad_fn=<MseLossBackward0>)
# epoch:  183 loss:  tensor(0.3439, grad_fn=<MseLossBackward0>)
# epoch:  184 loss:  tensor(0.3240, grad_fn=<MseLossBackward0>)
# epoch:  185 loss:  tensor(0.3162, grad_fn=<MseLossBackward0>)
# epoch:  186 loss:  tensor(0.3124, grad_fn=<MseLossBackward0>)
# epoch:  187 loss:  tensor(0.2921, grad_fn=<MseLossBackward0>)
# epoch:  188 loss:  tensor(0.2968, grad_fn=<MseLossBackward0>)
# epoch:  189 loss:  tensor(0.2774, grad_fn=<MseLossBackward0>)
# epoch:  190 loss:  tensor(0.2753, grad_fn=<MseLossBackward0>)
# epoch:  191 loss:  tensor(0.2682, grad_fn=<MseLossBackward0>)
# epoch:  192 loss:  tensor(0.2547, grad_fn=<MseLossBackward0>)
# epoch:  193 loss:  tensor(0.2559, grad_fn=<MseLossBackward0>)
# epoch:  194 loss:  tensor(0.2412, grad_fn=<MseLossBackward0>)
# epoch:  195 loss:  tensor(0.2387, grad_fn=<MseLossBackward0>)
# epoch:  196 loss:  tensor(0.2322, grad_fn=<MseLossBackward0>)
# epoch:  197 loss:  tensor(0.2222, grad_fn=<MseLossBackward0>)
# epoch:  198 loss:  tensor(0.2212, grad_fn=<MseLossBackward0>)
# epoch:  199 loss:  tensor(0.2110, grad_fn=<MseLossBackward0>)
# epoch:  200 loss:  tensor(0.2073, grad_fn=<MseLossBackward0>)
# epoch:  201 loss:  tensor(0.2023, grad_fn=<MseLossBackward0>)
# epoch:  202 loss:  tensor(0.1944, grad_fn=<MseLossBackward0>)
# epoch:  203 loss:  tensor(0.1924, grad_fn=<MseLossBackward0>)
# epoch:  204 loss:  tensor(0.1849, grad_fn=<MseLossBackward0>)
# epoch:  205 loss:  tensor(0.1804, grad_fn=<MseLossBackward0>)
# epoch:  206 loss:  tensor(0.1766, grad_fn=<MseLossBackward0>)
# epoch:  207 loss:  tensor(0.1704, grad_fn=<MseLossBackward0>)
# epoch:  208 loss:  tensor(0.1670, grad_fn=<MseLossBackward0>)
# epoch:  209 loss:  tensor(0.1623, grad_fn=<MseLossBackward0>)
# epoch:  210 loss:  tensor(0.1574, grad_fn=<MseLossBackward0>)
# epoch:  211 loss:  tensor(0.1545, grad_fn=<MseLossBackward0>)
# epoch:  212 loss:  tensor(0.1495, grad_fn=<MseLossBackward0>)
# epoch:  213 loss:  tensor(0.1458, grad_fn=<MseLossBackward0>)
# epoch:  214 loss:  tensor(0.1424, grad_fn=<MseLossBackward0>)
# epoch:  215 loss:  tensor(0.1379, grad_fn=<MseLossBackward0>)
# epoch:  216 loss:  tensor(0.1349, grad_fn=<MseLossBackward0>)
# epoch:  217 loss:  tensor(0.1312, grad_fn=<MseLossBackward0>)
# epoch:  218 loss:  tensor(0.1274, grad_fn=<MseLossBackward0>)
# epoch:  219 loss:  tensor(0.1246, grad_fn=<MseLossBackward0>)
# epoch:  220 loss:  tensor(0.1211, grad_fn=<MseLossBackward0>)
# epoch:  221 loss:  tensor(0.1178, grad_fn=<MseLossBackward0>)
# epoch:  222 loss:  tensor(0.1150, grad_fn=<MseLossBackward0>)
# epoch:  223 loss:  tensor(0.1117, grad_fn=<MseLossBackward0>)
# epoch:  224 loss:  tensor(0.1088, grad_fn=<MseLossBackward0>)
# epoch:  225 loss:  tensor(0.1061, grad_fn=<MseLossBackward0>)
# epoch:  226 loss:  tensor(0.1031, grad_fn=<MseLossBackward0>)
# epoch:  227 loss:  tensor(0.1004, grad_fn=<MseLossBackward0>)
# epoch:  228 loss:  tensor(0.0980, grad_fn=<MseLossBackward0>)
# epoch:  229 loss:  tensor(0.0953, grad_fn=<MseLossBackward0>)
# epoch:  230 loss:  tensor(0.0928, grad_fn=<MseLossBackward0>)
# epoch:  231 loss:  tensor(0.0905, grad_fn=<MseLossBackward0>)
# epoch:  232 loss:  tensor(0.0881, grad_fn=<MseLossBackward0>)
# epoch:  233 loss:  tensor(0.0858, grad_fn=<MseLossBackward0>)
# epoch:  234 loss:  tensor(0.0836, grad_fn=<MseLossBackward0>)
# epoch:  235 loss:  tensor(0.0815, grad_fn=<MseLossBackward0>)
# epoch:  236 loss:  tensor(0.0794, grad_fn=<MseLossBackward0>)
# epoch:  237 loss:  tensor(0.0774, grad_fn=<MseLossBackward0>)
# epoch:  238 loss:  tensor(0.0755, grad_fn=<MseLossBackward0>)
# epoch:  239 loss:  tensor(0.0735, grad_fn=<MseLossBackward0>)
# epoch:  240 loss:  tensor(0.0717, grad_fn=<MseLossBackward0>)
# epoch:  241 loss:  tensor(0.0699, grad_fn=<MseLossBackward0>)
# epoch:  242 loss:  tensor(0.0682, grad_fn=<MseLossBackward0>)
# epoch:  243 loss:  tensor(0.0664, grad_fn=<MseLossBackward0>)
# epoch:  244 loss:  tensor(0.0649, grad_fn=<MseLossBackward0>)
# epoch:  245 loss:  tensor(0.0632, grad_fn=<MseLossBackward0>)
# epoch:  246 loss:  tensor(0.0616, grad_fn=<MseLossBackward0>)
# epoch:  247 loss:  tensor(0.0602, grad_fn=<MseLossBackward0>)
# epoch:  248 loss:  tensor(0.0586, grad_fn=<MseLossBackward0>)
# epoch:  249 loss:  tensor(0.0572, grad_fn=<MseLossBackward0>)
# epoch:  250 loss:  tensor(0.0558, grad_fn=<MseLossBackward0>)
# epoch:  251 loss:  tensor(0.0544, grad_fn=<MseLossBackward0>)
# epoch:  252 loss:  tensor(0.0530, grad_fn=<MseLossBackward0>)
# epoch:  253 loss:  tensor(0.0517, grad_fn=<MseLossBackward0>)
# epoch:  254 loss:  tensor(0.0505, grad_fn=<MseLossBackward0>)
# epoch:  255 loss:  tensor(0.0492, grad_fn=<MseLossBackward0>)
# epoch:  256 loss:  tensor(0.0480, grad_fn=<MseLossBackward0>)
# epoch:  257 loss:  tensor(0.0468, grad_fn=<MseLossBackward0>)
# epoch:  258 loss:  tensor(0.0457, grad_fn=<MseLossBackward0>)
# epoch:  259 loss:  tensor(0.0446, grad_fn=<MseLossBackward0>)
# epoch:  260 loss:  tensor(0.0435, grad_fn=<MseLossBackward0>)
# epoch:  261 loss:  tensor(0.0424, grad_fn=<MseLossBackward0>)
# epoch:  262 loss:  tensor(0.0414, grad_fn=<MseLossBackward0>)
# epoch:  263 loss:  tensor(0.0405, grad_fn=<MseLossBackward0>)
# epoch:  264 loss:  tensor(0.0395, grad_fn=<MseLossBackward0>)
# epoch:  265 loss:  tensor(0.0386, grad_fn=<MseLossBackward0>)
# epoch:  266 loss:  tensor(0.0377, grad_fn=<MseLossBackward0>)
# epoch:  267 loss:  tensor(0.0368, grad_fn=<MseLossBackward0>)
# epoch:  268 loss:  tensor(0.0359, grad_fn=<MseLossBackward0>)
# epoch:  269 loss:  tensor(0.0351, grad_fn=<MseLossBackward0>)
# epoch:  270 loss:  tensor(0.0343, grad_fn=<MseLossBackward0>)
# epoch:  271 loss:  tensor(0.0335, grad_fn=<MseLossBackward0>)
# epoch:  272 loss:  tensor(0.0327, grad_fn=<MseLossBackward0>)
# epoch:  273 loss:  tensor(0.0319, grad_fn=<MseLossBackward0>)
# epoch:  274 loss:  tensor(0.0311, grad_fn=<MseLossBackward0>)
# epoch:  275 loss:  tensor(0.0304, grad_fn=<MseLossBackward0>)
# epoch:  276 loss:  tensor(0.0297, grad_fn=<MseLossBackward0>)
# epoch:  277 loss:  tensor(0.0289, grad_fn=<MseLossBackward0>)
# epoch:  278 loss:  tensor(0.0281, grad_fn=<MseLossBackward0>)
# epoch:  279 loss:  tensor(0.0274, grad_fn=<MseLossBackward0>)
# epoch:  280 loss:  tensor(0.0266, grad_fn=<MseLossBackward0>)
# epoch:  281 loss:  tensor(0.0259, grad_fn=<MseLossBackward0>)
# epoch:  282 loss:  tensor(0.0252, grad_fn=<MseLossBackward0>)
# epoch:  283 loss:  tensor(0.0244, grad_fn=<MseLossBackward0>)
# epoch:  284 loss:  tensor(0.0238, grad_fn=<MseLossBackward0>)
# epoch:  285 loss:  tensor(0.0232, grad_fn=<MseLossBackward0>)
# epoch:  286 loss:  tensor(0.0226, grad_fn=<MseLossBackward0>)
# epoch:  287 loss:  tensor(0.0219, grad_fn=<MseLossBackward0>)
# epoch:  288 loss:  tensor(0.0213, grad_fn=<MseLossBackward0>)
# epoch:  289 loss:  tensor(0.0207, grad_fn=<MseLossBackward0>)
# epoch:  290 loss:  tensor(0.0202, grad_fn=<MseLossBackward0>)
# epoch:  291 loss:  tensor(0.0196, grad_fn=<MseLossBackward0>)
# epoch:  292 loss:  tensor(0.0191, grad_fn=<MseLossBackward0>)
# epoch:  293 loss:  tensor(0.0186, grad_fn=<MseLossBackward0>)
# epoch:  294 loss:  tensor(0.0181, grad_fn=<MseLossBackward0>)
# epoch:  295 loss:  tensor(0.0176, grad_fn=<MseLossBackward0>)
# epoch:  296 loss:  tensor(0.0171, grad_fn=<MseLossBackward0>)
# epoch:  297 loss:  tensor(0.0166, grad_fn=<MseLossBackward0>)
# epoch:  298 loss:  tensor(0.0162, grad_fn=<MseLossBackward0>)
# epoch:  299 loss:  tensor(0.0158, grad_fn=<MseLossBackward0>)
# epoch:  300 loss:  tensor(0.0153, grad_fn=<MseLossBackward0>)
# epoch:  301 loss:  tensor(0.0149, grad_fn=<MseLossBackward0>)
# epoch:  302 loss:  tensor(0.0145, grad_fn=<MseLossBackward0>)
# epoch:  303 loss:  tensor(0.0141, grad_fn=<MseLossBackward0>)
# epoch:  304 loss:  tensor(0.0137, grad_fn=<MseLossBackward0>)
# epoch:  305 loss:  tensor(0.0134, grad_fn=<MseLossBackward0>)
# epoch:  306 loss:  tensor(0.0130, grad_fn=<MseLossBackward0>)
# epoch:  307 loss:  tensor(0.0127, grad_fn=<MseLossBackward0>)
# epoch:  308 loss:  tensor(0.0123, grad_fn=<MseLossBackward0>)
# epoch:  309 loss:  tensor(0.0120, grad_fn=<MseLossBackward0>)
# epoch:  310 loss:  tensor(0.0117, grad_fn=<MseLossBackward0>)
# epoch:  311 loss:  tensor(0.0113, grad_fn=<MseLossBackward0>)
# epoch:  312 loss:  tensor(0.0110, grad_fn=<MseLossBackward0>)
# epoch:  313 loss:  tensor(0.0107, grad_fn=<MseLossBackward0>)
# epoch:  314 loss:  tensor(0.0105, grad_fn=<MseLossBackward0>)
# epoch:  315 loss:  tensor(0.0102, grad_fn=<MseLossBackward0>)
# epoch:  316 loss:  tensor(0.0099, grad_fn=<MseLossBackward0>)
# epoch:  317 loss:  tensor(0.0096, grad_fn=<MseLossBackward0>)
# epoch:  318 loss:  tensor(0.0094, grad_fn=<MseLossBackward0>)
# epoch:  319 loss:  tensor(0.0091, grad_fn=<MseLossBackward0>)
# epoch:  320 loss:  tensor(0.0089, grad_fn=<MseLossBackward0>)
# epoch:  321 loss:  tensor(0.0087, grad_fn=<MseLossBackward0>)
# epoch:  322 loss:  tensor(0.0084, grad_fn=<MseLossBackward0>)
# epoch:  323 loss:  tensor(0.0082, grad_fn=<MseLossBackward0>)
# epoch:  324 loss:  tensor(0.0080, grad_fn=<MseLossBackward0>)
# epoch:  325 loss:  tensor(0.0078, grad_fn=<MseLossBackward0>)
# epoch:  326 loss:  tensor(0.0076, grad_fn=<MseLossBackward0>)
# epoch:  327 loss:  tensor(0.0074, grad_fn=<MseLossBackward0>)
# epoch:  328 loss:  tensor(0.0072, grad_fn=<MseLossBackward0>)
# epoch:  329 loss:  tensor(0.0070, grad_fn=<MseLossBackward0>)
# epoch:  330 loss:  tensor(0.0068, grad_fn=<MseLossBackward0>)
# epoch:  331 loss:  tensor(0.0066, grad_fn=<MseLossBackward0>)
# epoch:  332 loss:  tensor(0.0064, grad_fn=<MseLossBackward0>)
# epoch:  333 loss:  tensor(0.0063, grad_fn=<MseLossBackward0>)
# epoch:  334 loss:  tensor(0.0061, grad_fn=<MseLossBackward0>)
# epoch:  335 loss:  tensor(0.0059, grad_fn=<MseLossBackward0>)
# epoch:  336 loss:  tensor(0.0058, grad_fn=<MseLossBackward0>)
# epoch:  337 loss:  tensor(0.0056, grad_fn=<MseLossBackward0>)
# epoch:  338 loss:  tensor(0.0055, grad_fn=<MseLossBackward0>)
# epoch:  339 loss:  tensor(0.0053, grad_fn=<MseLossBackward0>)
# epoch:  340 loss:  tensor(0.0052, grad_fn=<MseLossBackward0>)
# epoch:  341 loss:  tensor(0.0051, grad_fn=<MseLossBackward0>)
# epoch:  342 loss:  tensor(0.0049, grad_fn=<MseLossBackward0>)
# epoch:  343 loss:  tensor(0.0048, grad_fn=<MseLossBackward0>)
# epoch:  344 loss:  tensor(0.0047, grad_fn=<MseLossBackward0>)
# epoch:  345 loss:  tensor(0.0046, grad_fn=<MseLossBackward0>)
# epoch:  346 loss:  tensor(0.0044, grad_fn=<MseLossBackward0>)
# epoch:  347 loss:  tensor(0.0043, grad_fn=<MseLossBackward0>)
# epoch:  348 loss:  tensor(0.0042, grad_fn=<MseLossBackward0>)
# epoch:  349 loss:  tensor(0.0041, grad_fn=<MseLossBackward0>)
# epoch:  350 loss:  tensor(0.0040, grad_fn=<MseLossBackward0>)
# epoch:  351 loss:  tensor(0.0039, grad_fn=<MseLossBackward0>)
# epoch:  352 loss:  tensor(0.0038, grad_fn=<MseLossBackward0>)
# epoch:  353 loss:  tensor(0.0037, grad_fn=<MseLossBackward0>)
# epoch:  354 loss:  tensor(0.0036, grad_fn=<MseLossBackward0>)
# epoch:  355 loss:  tensor(0.0035, grad_fn=<MseLossBackward0>)
# epoch:  356 loss:  tensor(0.0034, grad_fn=<MseLossBackward0>)
# epoch:  357 loss:  tensor(0.0033, grad_fn=<MseLossBackward0>)
# epoch:  358 loss:  tensor(0.0032, grad_fn=<MseLossBackward0>)
# epoch:  359 loss:  tensor(0.0032, grad_fn=<MseLossBackward0>)
# epoch:  360 loss:  tensor(0.0031, grad_fn=<MseLossBackward0>)
# epoch:  361 loss:  tensor(0.0030, grad_fn=<MseLossBackward0>)
# epoch:  362 loss:  tensor(0.0029, grad_fn=<MseLossBackward0>)
# epoch:  363 loss:  tensor(0.0029, grad_fn=<MseLossBackward0>)
# epoch:  364 loss:  tensor(0.0028, grad_fn=<MseLossBackward0>)
# epoch:  365 loss:  tensor(0.0027, grad_fn=<MseLossBackward0>)
# epoch:  366 loss:  tensor(0.0026, grad_fn=<MseLossBackward0>)
# epoch:  367 loss:  tensor(0.0026, grad_fn=<MseLossBackward0>)
# epoch:  368 loss:  tensor(0.0025, grad_fn=<MseLossBackward0>)
# epoch:  369 loss:  tensor(0.0024, grad_fn=<MseLossBackward0>)
# epoch:  370 loss:  tensor(0.0024, grad_fn=<MseLossBackward0>)
# epoch:  371 loss:  tensor(0.0023, grad_fn=<MseLossBackward0>)
# epoch:  372 loss:  tensor(0.0023, grad_fn=<MseLossBackward0>)
# epoch:  373 loss:  tensor(0.0022, grad_fn=<MseLossBackward0>)
# epoch:  374 loss:  tensor(0.0022, grad_fn=<MseLossBackward0>)
# epoch:  375 loss:  tensor(0.0021, grad_fn=<MseLossBackward0>)
# epoch:  376 loss:  tensor(0.0020, grad_fn=<MseLossBackward0>)
# epoch:  377 loss:  tensor(0.0020, grad_fn=<MseLossBackward0>)
# epoch:  378 loss:  tensor(0.0020, grad_fn=<MseLossBackward0>)
# epoch:  379 loss:  tensor(0.0019, grad_fn=<MseLossBackward0>)
# epoch:  380 loss:  tensor(0.0019, grad_fn=<MseLossBackward0>)
# epoch:  381 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  382 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  383 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  384 loss:  tensor(0.0017, grad_fn=<MseLossBackward0>)
# epoch:  385 loss:  tensor(0.0017, grad_fn=<MseLossBackward0>)
# epoch:  386 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  387 loss:  tensor(0.0019, grad_fn=<MseLossBackward0>)
# epoch:  388 loss:  tensor(0.0020, grad_fn=<MseLossBackward0>)
# epoch:  389 loss:  tensor(0.0024, grad_fn=<MseLossBackward0>)
# epoch:  390 loss:  tensor(0.0029, grad_fn=<MseLossBackward0>)
# epoch:  391 loss:  tensor(0.0040, grad_fn=<MseLossBackward0>)
# epoch:  392 loss:  tensor(0.0057, grad_fn=<MseLossBackward0>)
# epoch:  393 loss:  tensor(0.0088, grad_fn=<MseLossBackward0>)
# epoch:  394 loss:  tensor(0.0143, grad_fn=<MseLossBackward0>)
# epoch:  395 loss:  tensor(0.0238, grad_fn=<MseLossBackward0>)
# epoch:  396 loss:  tensor(0.0409, grad_fn=<MseLossBackward0>)
# epoch:  397 loss:  tensor(0.0710, grad_fn=<MseLossBackward0>)
# epoch:  398 loss:  tensor(0.1273, grad_fn=<MseLossBackward0>)
# epoch:  399 loss:  tensor(0.2250, grad_fn=<MseLossBackward0>)
# epoch:  400 loss:  tensor(0.4124, grad_fn=<MseLossBackward0>)
# epoch:  401 loss:  tensor(0.7329, grad_fn=<MseLossBackward0>)
# epoch:  402 loss:  tensor(1.3646, grad_fn=<MseLossBackward0>)
# epoch:  403 loss:  tensor(2.2706, grad_fn=<MseLossBackward0>)
# epoch:  404 loss:  tensor(3.9753, grad_fn=<MseLossBackward0>)
# epoch:  405 loss:  tensor(5.1893, grad_fn=<MseLossBackward0>)
# epoch:  406 loss:  tensor(6.8303, grad_fn=<MseLossBackward0>)
# epoch:  407 loss:  tensor(5.3007, grad_fn=<MseLossBackward0>)
# epoch:  408 loss:  tensor(3.1378, grad_fn=<MseLossBackward0>)
# epoch:  409 loss:  tensor(0.5030, grad_fn=<MseLossBackward0>)
# epoch:  410 loss:  tensor(0.3685, grad_fn=<MseLossBackward0>)
# epoch:  411 loss:  tensor(2.0631, grad_fn=<MseLossBackward0>)
# epoch:  412 loss:  tensor(2.5694, grad_fn=<MseLossBackward0>)
# epoch:  413 loss:  tensor(1.5389, grad_fn=<MseLossBackward0>)
# epoch:  414 loss:  tensor(0.1753, grad_fn=<MseLossBackward0>)
# epoch:  415 loss:  tensor(0.4667, grad_fn=<MseLossBackward0>)
# epoch:  416 loss:  tensor(1.5203, grad_fn=<MseLossBackward0>)
# epoch:  417 loss:  tensor(1.3361, grad_fn=<MseLossBackward0>)
# epoch:  418 loss:  tensor(0.3994, grad_fn=<MseLossBackward0>)
# epoch:  419 loss:  tensor(0.0893, grad_fn=<MseLossBackward0>)
# epoch:  420 loss:  tensor(0.6843, grad_fn=<MseLossBackward0>)
# epoch:  421 loss:  tensor(1.0277, grad_fn=<MseLossBackward0>)
# epoch:  422 loss:  tensor(0.4741, grad_fn=<MseLossBackward0>)
# epoch:  423 loss:  tensor(0.0405, grad_fn=<MseLossBackward0>)
# epoch:  424 loss:  tensor(0.3051, grad_fn=<MseLossBackward0>)
# epoch:  425 loss:  tensor(0.6162, grad_fn=<MseLossBackward0>)
# epoch:  426 loss:  tensor(0.4526, grad_fn=<MseLossBackward0>)
# epoch:  427 loss:  tensor(0.0698, grad_fn=<MseLossBackward0>)
# epoch:  428 loss:  tensor(0.1163, grad_fn=<MseLossBackward0>)
# epoch:  429 loss:  tensor(0.3944, grad_fn=<MseLossBackward0>)
# epoch:  430 loss:  tensor(0.3541, grad_fn=<MseLossBackward0>)
# epoch:  431 loss:  tensor(0.1025, grad_fn=<MseLossBackward0>)
# epoch:  432 loss:  tensor(0.0327, grad_fn=<MseLossBackward0>)
# epoch:  433 loss:  tensor(0.2020, grad_fn=<MseLossBackward0>)
# epoch:  434 loss:  tensor(0.2747, grad_fn=<MseLossBackward0>)
# epoch:  435 loss:  tensor(0.1241, grad_fn=<MseLossBackward0>)
# epoch:  436 loss:  tensor(0.0139, grad_fn=<MseLossBackward0>)
# epoch:  437 loss:  tensor(0.0917, grad_fn=<MseLossBackward0>)
# epoch:  438 loss:  tensor(0.1769, grad_fn=<MseLossBackward0>)
# epoch:  439 loss:  tensor(0.1291, grad_fn=<MseLossBackward0>)
# epoch:  440 loss:  tensor(0.0260, grad_fn=<MseLossBackward0>)
# epoch:  441 loss:  tensor(0.0275, grad_fn=<MseLossBackward0>)
# epoch:  442 loss:  tensor(0.1016, grad_fn=<MseLossBackward0>)
# epoch:  443 loss:  tensor(0.1081, grad_fn=<MseLossBackward0>)
# epoch:  444 loss:  tensor(0.0463, grad_fn=<MseLossBackward0>)
# epoch:  445 loss:  tensor(0.0074, grad_fn=<MseLossBackward0>)
# epoch:  446 loss:  tensor(0.0412, grad_fn=<MseLossBackward0>)
# epoch:  447 loss:  tensor(0.0760, grad_fn=<MseLossBackward0>)
# epoch:  448 loss:  tensor(0.0558, grad_fn=<MseLossBackward0>)
# epoch:  449 loss:  tensor(0.0141, grad_fn=<MseLossBackward0>)
# epoch:  450 loss:  tensor(0.0103, grad_fn=<MseLossBackward0>)
# epoch:  451 loss:  tensor(0.0381, grad_fn=<MseLossBackward0>)
# epoch:  452 loss:  tensor(0.0486, grad_fn=<MseLossBackward0>)
# epoch:  453 loss:  tensor(0.0266, grad_fn=<MseLossBackward0>)
# epoch:  454 loss:  tensor(0.0052, grad_fn=<MseLossBackward0>)
# epoch:  455 loss:  tensor(0.0115, grad_fn=<MseLossBackward0>)
# epoch:  456 loss:  tensor(0.0279, grad_fn=<MseLossBackward0>)
# epoch:  457 loss:  tensor(0.0297, grad_fn=<MseLossBackward0>)
# epoch:  458 loss:  tensor(0.0137, grad_fn=<MseLossBackward0>)
# epoch:  459 loss:  tensor(0.0035, grad_fn=<MseLossBackward0>)
# epoch:  460 loss:  tensor(0.0088, grad_fn=<MseLossBackward0>)
# epoch:  461 loss:  tensor(0.0187, grad_fn=<MseLossBackward0>)
# epoch:  462 loss:  tensor(0.0184, grad_fn=<MseLossBackward0>)
# epoch:  463 loss:  tensor(0.0087, grad_fn=<MseLossBackward0>)
# epoch:  464 loss:  tensor(0.0026, grad_fn=<MseLossBackward0>)
# epoch:  465 loss:  tensor(0.0055, grad_fn=<MseLossBackward0>)
# epoch:  466 loss:  tensor(0.0116, grad_fn=<MseLossBackward0>)
# epoch:  467 loss:  tensor(0.0119, grad_fn=<MseLossBackward0>)
# epoch:  468 loss:  tensor(0.0066, grad_fn=<MseLossBackward0>)
# epoch:  469 loss:  tensor(0.0021, grad_fn=<MseLossBackward0>)
# epoch:  470 loss:  tensor(0.0030, grad_fn=<MseLossBackward0>)
# epoch:  471 loss:  tensor(0.0064, grad_fn=<MseLossBackward0>)
# epoch:  472 loss:  tensor(0.0079, grad_fn=<MseLossBackward0>)
# epoch:  473 loss:  tensor(0.0055, grad_fn=<MseLossBackward0>)
# epoch:  474 loss:  tensor(0.0023, grad_fn=<MseLossBackward0>)
# epoch:  475 loss:  tensor(0.0015, grad_fn=<MseLossBackward0>)
# epoch:  476 loss:  tensor(0.0031, grad_fn=<MseLossBackward0>)
# epoch:  477 loss:  tensor(0.0048, grad_fn=<MseLossBackward0>)
# epoch:  478 loss:  tensor(0.0045, grad_fn=<MseLossBackward0>)
# epoch:  479 loss:  tensor(0.0028, grad_fn=<MseLossBackward0>)
# epoch:  480 loss:  tensor(0.0012, grad_fn=<MseLossBackward0>)
# epoch:  481 loss:  tensor(0.0013, grad_fn=<MseLossBackward0>)
# epoch:  482 loss:  tensor(0.0022, grad_fn=<MseLossBackward0>)
# epoch:  483 loss:  tensor(0.0030, grad_fn=<MseLossBackward0>)
# epoch:  484 loss:  tensor(0.0027, grad_fn=<MseLossBackward0>)
# epoch:  485 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  486 loss:  tensor(0.0009, grad_fn=<MseLossBackward0>)
# epoch:  487 loss:  tensor(0.0009, grad_fn=<MseLossBackward0>)
# epoch:  488 loss:  tensor(0.0014, grad_fn=<MseLossBackward0>)
# epoch:  489 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  490 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  491 loss:  tensor(0.0014, grad_fn=<MseLossBackward0>)
# epoch:  492 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  493 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  494 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  495 loss:  tensor(0.0010, grad_fn=<MseLossBackward0>)
# epoch:  496 loss:  tensor(0.0012, grad_fn=<MseLossBackward0>)
# epoch:  497 loss:  tensor(0.0011, grad_fn=<MseLossBackward0>)
# epoch:  498 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  499 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  500 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  501 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  502 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  503 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  504 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  505 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  506 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  507 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  508 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  509 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  510 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  511 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  512 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  513 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  514 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  515 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  516 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  517 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  518 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  519 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  520 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  521 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  522 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  523 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  524 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  525 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  526 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  527 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  528 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  529 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  530 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  531 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  532 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  533 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  534 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  535 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  536 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  537 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  538 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  539 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  540 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  541 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  542 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  543 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  544 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  545 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  546 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  547 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  548 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  549 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  550 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  551 loss:  tensor(0.0012, grad_fn=<MseLossBackward0>)
# epoch:  552 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  553 loss:  tensor(0.0027, grad_fn=<MseLossBackward0>)
# epoch:  554 loss:  tensor(0.0043, grad_fn=<MseLossBackward0>)
# epoch:  555 loss:  tensor(0.0069, grad_fn=<MseLossBackward0>)
# epoch:  556 loss:  tensor(0.0113, grad_fn=<MseLossBackward0>)
# epoch:  557 loss:  tensor(0.0188, grad_fn=<MseLossBackward0>)
# epoch:  558 loss:  tensor(0.0323, grad_fn=<MseLossBackward0>)
# epoch:  559 loss:  tensor(0.0554, grad_fn=<MseLossBackward0>)
# epoch:  560 loss:  tensor(0.0989, grad_fn=<MseLossBackward0>)
# epoch:  561 loss:  tensor(0.1732, grad_fn=<MseLossBackward0>)
# epoch:  562 loss:  tensor(0.3195, grad_fn=<MseLossBackward0>)
# epoch:  563 loss:  tensor(0.5682, grad_fn=<MseLossBackward0>)
# epoch:  564 loss:  tensor(1.0921, grad_fn=<MseLossBackward0>)
# epoch:  565 loss:  tensor(1.9481, grad_fn=<MseLossBackward0>)
# epoch:  566 loss:  tensor(3.9251, grad_fn=<MseLossBackward0>)
# epoch:  567 loss:  tensor(6.6317, grad_fn=<MseLossBackward0>)
# epoch:  568 loss:  tensor(13.6290, grad_fn=<MseLossBackward0>)
# epoch:  569 loss:  tensor(17.9311, grad_fn=<MseLossBackward0>)
# epoch:  570 loss:  tensor(28.3235, grad_fn=<MseLossBackward0>)
# epoch:  571 loss:  tensor(13.9238, grad_fn=<MseLossBackward0>)
# epoch:  572 loss:  tensor(2.5389, grad_fn=<MseLossBackward0>)
# epoch:  573 loss:  tensor(2.0062, grad_fn=<MseLossBackward0>)
# epoch:  574 loss:  tensor(9.1568, grad_fn=<MseLossBackward0>)
# epoch:  575 loss:  tensor(10.0639, grad_fn=<MseLossBackward0>)
# epoch:  576 loss:  tensor(0.9590, grad_fn=<MseLossBackward0>)
# epoch:  577 loss:  tensor(4.3701, grad_fn=<MseLossBackward0>)
# epoch:  578 loss:  tensor(10.1490, grad_fn=<MseLossBackward0>)
# epoch:  579 loss:  tensor(1.5225, grad_fn=<MseLossBackward0>)
# epoch:  580 loss:  tensor(3.3860, grad_fn=<MseLossBackward0>)
# epoch:  581 loss:  tensor(8.3694, grad_fn=<MseLossBackward0>)
# epoch:  582 loss:  tensor(1.6019, grad_fn=<MseLossBackward0>)
# epoch:  583 loss:  tensor(3.9426, grad_fn=<MseLossBackward0>)
# epoch:  584 loss:  tensor(7.8125, grad_fn=<MseLossBackward0>)
# epoch:  585 loss:  tensor(1.8571, grad_fn=<MseLossBackward0>)
# epoch:  586 loss:  tensor(4.6216, grad_fn=<MseLossBackward0>)
# epoch:  587 loss:  tensor(7.4250, grad_fn=<MseLossBackward0>)
# epoch:  588 loss:  tensor(2.2035, grad_fn=<MseLossBackward0>)
# epoch:  589 loss:  tensor(4.7331, grad_fn=<MseLossBackward0>)
# epoch:  590 loss:  tensor(6.4602, grad_fn=<MseLossBackward0>)
# epoch:  591 loss:  tensor(1.1219, grad_fn=<MseLossBackward0>)
# epoch:  592 loss:  tensor(4.9624, grad_fn=<MseLossBackward0>)
# epoch:  593 loss:  tensor(3.5355, grad_fn=<MseLossBackward0>)
# epoch:  594 loss:  tensor(0.7085, grad_fn=<MseLossBackward0>)
# epoch:  595 loss:  tensor(4.3879, grad_fn=<MseLossBackward0>)
# epoch:  596 loss:  tensor(0.6989, grad_fn=<MseLossBackward0>)
# epoch:  597 loss:  tensor(2.3268, grad_fn=<MseLossBackward0>)
# epoch:  598 loss:  tensor(2.2553, grad_fn=<MseLossBackward0>)
# epoch:  599 loss:  tensor(0.9075, grad_fn=<MseLossBackward0>)
# epoch:  600 loss:  tensor(1.6992, grad_fn=<MseLossBackward0>)
# epoch:  601 loss:  tensor(1.2929, grad_fn=<MseLossBackward0>)
# epoch:  602 loss:  tensor(0.5321, grad_fn=<MseLossBackward0>)
# epoch:  603 loss:  tensor(1.3638, grad_fn=<MseLossBackward0>)
# epoch:  604 loss:  tensor(0.3747, grad_fn=<MseLossBackward0>)
# epoch:  605 loss:  tensor(0.8490, grad_fn=<MseLossBackward0>)
# epoch:  606 loss:  tensor(0.8995, grad_fn=<MseLossBackward0>)
# epoch:  607 loss:  tensor(0.2349, grad_fn=<MseLossBackward0>)
# epoch:  608 loss:  tensor(1.0797, grad_fn=<MseLossBackward0>)
# epoch:  609 loss:  tensor(0.2218, grad_fn=<MseLossBackward0>)
# epoch:  610 loss:  tensor(0.5692, grad_fn=<MseLossBackward0>)
# epoch:  611 loss:  tensor(0.4445, grad_fn=<MseLossBackward0>)
# epoch:  612 loss:  tensor(0.2670, grad_fn=<MseLossBackward0>)
# epoch:  613 loss:  tensor(0.3736, grad_fn=<MseLossBackward0>)
# epoch:  614 loss:  tensor(0.3386, grad_fn=<MseLossBackward0>)
# epoch:  615 loss:  tensor(0.1343, grad_fn=<MseLossBackward0>)
# epoch:  616 loss:  tensor(0.4353, grad_fn=<MseLossBackward0>)
# epoch:  617 loss:  tensor(0.0511, grad_fn=<MseLossBackward0>)
# epoch:  618 loss:  tensor(0.3102, grad_fn=<MseLossBackward0>)
# epoch:  619 loss:  tensor(0.1561, grad_fn=<MseLossBackward0>)
# epoch:  620 loss:  tensor(0.1246, grad_fn=<MseLossBackward0>)
# epoch:  621 loss:  tensor(0.2212, grad_fn=<MseLossBackward0>)
# epoch:  622 loss:  tensor(0.0833, grad_fn=<MseLossBackward0>)
# epoch:  623 loss:  tensor(0.1433, grad_fn=<MseLossBackward0>)
# epoch:  624 loss:  tensor(0.1356, grad_fn=<MseLossBackward0>)
# epoch:  625 loss:  tensor(0.0619, grad_fn=<MseLossBackward0>)
# epoch:  626 loss:  tensor(0.1230, grad_fn=<MseLossBackward0>)
# epoch:  627 loss:  tensor(0.0740, grad_fn=<MseLossBackward0>)
# epoch:  628 loss:  tensor(0.0528, grad_fn=<MseLossBackward0>)
# epoch:  629 loss:  tensor(0.1096, grad_fn=<MseLossBackward0>)
# epoch:  630 loss:  tensor(0.0165, grad_fn=<MseLossBackward0>)
# epoch:  631 loss:  tensor(0.0945, grad_fn=<MseLossBackward0>)
# epoch:  632 loss:  tensor(0.0373, grad_fn=<MseLossBackward0>)
# epoch:  633 loss:  tensor(0.0473, grad_fn=<MseLossBackward0>)
# epoch:  634 loss:  tensor(0.0525, grad_fn=<MseLossBackward0>)
# epoch:  635 loss:  tensor(0.0351, grad_fn=<MseLossBackward0>)
# epoch:  636 loss:  tensor(0.0310, grad_fn=<MseLossBackward0>)
# epoch:  637 loss:  tensor(0.0474, grad_fn=<MseLossBackward0>)
# epoch:  638 loss:  tensor(0.0120, grad_fn=<MseLossBackward0>)
# epoch:  639 loss:  tensor(0.0425, grad_fn=<MseLossBackward0>)
# epoch:  640 loss:  tensor(0.0193, grad_fn=<MseLossBackward0>)
# epoch:  641 loss:  tensor(0.0207, grad_fn=<MseLossBackward0>)
# epoch:  642 loss:  tensor(0.0294, grad_fn=<MseLossBackward0>)
# epoch:  643 loss:  tensor(0.0115, grad_fn=<MseLossBackward0>)
# epoch:  644 loss:  tensor(0.0224, grad_fn=<MseLossBackward0>)
# epoch:  645 loss:  tensor(0.0170, grad_fn=<MseLossBackward0>)
# epoch:  646 loss:  tensor(0.0122, grad_fn=<MseLossBackward0>)
# epoch:  647 loss:  tensor(0.0169, grad_fn=<MseLossBackward0>)
# epoch:  648 loss:  tensor(0.0134, grad_fn=<MseLossBackward0>)
# epoch:  649 loss:  tensor(0.0084, grad_fn=<MseLossBackward0>)
# epoch:  650 loss:  tensor(0.0171, grad_fn=<MseLossBackward0>)
# epoch:  651 loss:  tensor(0.0050, grad_fn=<MseLossBackward0>)
# epoch:  652 loss:  tensor(0.0126, grad_fn=<MseLossBackward0>)
# epoch:  653 loss:  tensor(0.0085, grad_fn=<MseLossBackward0>)
# epoch:  654 loss:  tensor(0.0071, grad_fn=<MseLossBackward0>)
# epoch:  655 loss:  tensor(0.0089, grad_fn=<MseLossBackward0>)
# epoch:  656 loss:  tensor(0.0071, grad_fn=<MseLossBackward0>)
# epoch:  657 loss:  tensor(0.0055, grad_fn=<MseLossBackward0>)
# epoch:  658 loss:  tensor(0.0080, grad_fn=<MseLossBackward0>)
# epoch:  659 loss:  tensor(0.0047, grad_fn=<MseLossBackward0>)
# epoch:  660 loss:  tensor(0.0054, grad_fn=<MseLossBackward0>)
# epoch:  661 loss:  tensor(0.0063, grad_fn=<MseLossBackward0>)
# epoch:  662 loss:  tensor(0.0032, grad_fn=<MseLossBackward0>)
# epoch:  663 loss:  tensor(0.0058, grad_fn=<MseLossBackward0>)
# epoch:  664 loss:  tensor(0.0038, grad_fn=<MseLossBackward0>)
# epoch:  665 loss:  tensor(0.0039, grad_fn=<MseLossBackward0>)
# epoch:  666 loss:  tensor(0.0041, grad_fn=<MseLossBackward0>)
# epoch:  667 loss:  tensor(0.0036, grad_fn=<MseLossBackward0>)
# epoch:  668 loss:  tensor(0.0030, grad_fn=<MseLossBackward0>)
# epoch:  669 loss:  tensor(0.0040, grad_fn=<MseLossBackward0>)
# epoch:  670 loss:  tensor(0.0025, grad_fn=<MseLossBackward0>)
# epoch:  671 loss:  tensor(0.0031, grad_fn=<MseLossBackward0>)
# epoch:  672 loss:  tensor(0.0030, grad_fn=<MseLossBackward0>)
# epoch:  673 loss:  tensor(0.0022, grad_fn=<MseLossBackward0>)
# epoch:  674 loss:  tensor(0.0028, grad_fn=<MseLossBackward0>)
# epoch:  675 loss:  tensor(0.0023, grad_fn=<MseLossBackward0>)
# epoch:  676 loss:  tensor(0.0022, grad_fn=<MseLossBackward0>)
# epoch:  677 loss:  tensor(0.0023, grad_fn=<MseLossBackward0>)
# epoch:  678 loss:  tensor(0.0021, grad_fn=<MseLossBackward0>)
# epoch:  679 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  680 loss:  tensor(0.0022, grad_fn=<MseLossBackward0>)
# epoch:  681 loss:  tensor(0.0017, grad_fn=<MseLossBackward0>)
# epoch:  682 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  683 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  684 loss:  tensor(0.0015, grad_fn=<MseLossBackward0>)
# epoch:  685 loss:  tensor(0.0016, grad_fn=<MseLossBackward0>)
# epoch:  686 loss:  tensor(0.0015, grad_fn=<MseLossBackward0>)
# epoch:  687 loss:  tensor(0.0014, grad_fn=<MseLossBackward0>)
# epoch:  688 loss:  tensor(0.0014, grad_fn=<MseLossBackward0>)
# epoch:  689 loss:  tensor(0.0014, grad_fn=<MseLossBackward0>)
# epoch:  690 loss:  tensor(0.0012, grad_fn=<MseLossBackward0>)
# epoch:  691 loss:  tensor(0.0013, grad_fn=<MseLossBackward0>)
# epoch:  692 loss:  tensor(0.0012, grad_fn=<MseLossBackward0>)
# epoch:  693 loss:  tensor(0.0011, grad_fn=<MseLossBackward0>)
# epoch:  694 loss:  tensor(0.0011, grad_fn=<MseLossBackward0>)
# epoch:  695 loss:  tensor(0.0010, grad_fn=<MseLossBackward0>)
# epoch:  696 loss:  tensor(0.0010, grad_fn=<MseLossBackward0>)
# epoch:  697 loss:  tensor(0.0010, grad_fn=<MseLossBackward0>)
# epoch:  698 loss:  tensor(0.0010, grad_fn=<MseLossBackward0>)
# epoch:  699 loss:  tensor(0.0009, grad_fn=<MseLossBackward0>)
# epoch:  700 loss:  tensor(0.0009, grad_fn=<MseLossBackward0>)
# epoch:  701 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  702 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  703 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  704 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  705 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  706 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  707 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  708 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  709 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  710 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  711 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  712 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  713 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  714 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  715 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  716 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  717 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  718 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  719 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  720 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  721 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  722 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  723 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  724 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  725 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  726 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  727 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  728 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  729 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  730 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  731 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  732 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  733 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  734 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  735 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  736 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  737 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  738 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  739 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  740 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  741 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  742 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  743 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  744 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  745 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  746 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  747 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  748 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  749 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  750 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  751 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  752 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  753 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  754 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  755 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  756 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  757 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  758 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  759 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  760 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  761 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  762 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  763 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# ...
# epoch:  1858 loss:  tensor(0.0124, grad_fn=<MseLossBackward0>)
# epoch:  1859 loss:  tensor(0.0140, grad_fn=<MseLossBackward0>)
# epoch:  1860 loss:  tensor(0.0063, grad_fn=<MseLossBackward0>)
# epoch:  1861 loss:  tensor(0.0062, grad_fn=<MseLossBackward0>)
# epoch:  1862 loss:  tensor(0.0148, grad_fn=<MseLossBackward0>)
# epoch:  1863 loss:  tensor(0.0068, grad_fn=<MseLossBackward0>)
# epoch:  1864 loss:  tensor(0.0017, grad_fn=<MseLossBackward0>)
# epoch:  1865 loss:  tensor(0.0089, grad_fn=<MseLossBackward0>)
# epoch:  1866 loss:  tensor(0.0071, grad_fn=<MseLossBackward0>)
# epoch:  1867 loss:  tensor(0.0035, grad_fn=<MseLossBackward0>)
# epoch:  1868 loss:  tensor(0.0044, grad_fn=<MseLossBackward0>)
# epoch:  1869 loss:  tensor(0.0033, grad_fn=<MseLossBackward0>)
# epoch:  1870 loss:  tensor(0.0049, grad_fn=<MseLossBackward0>)
# epoch:  1871 loss:  tensor(0.0044, grad_fn=<MseLossBackward0>)
# epoch:  1872 loss:  tensor(0.0009, grad_fn=<MseLossBackward0>)
# epoch:  1873 loss:  tensor(0.0028, grad_fn=<MseLossBackward0>)
# epoch:  1874 loss:  tensor(0.0044, grad_fn=<MseLossBackward0>)
# epoch:  1875 loss:  tensor(0.0015, grad_fn=<MseLossBackward0>)
# epoch:  1876 loss:  tensor(0.0014, grad_fn=<MseLossBackward0>)
# epoch:  1877 loss:  tensor(0.0025, grad_fn=<MseLossBackward0>)
# epoch:  1878 loss:  tensor(0.0018, grad_fn=<MseLossBackward0>)
# epoch:  1879 loss:  tensor(0.0019, grad_fn=<MseLossBackward0>)
# epoch:  1880 loss:  tensor(0.0012, grad_fn=<MseLossBackward0>)
# epoch:  1881 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  1882 loss:  tensor(0.0019, grad_fn=<MseLossBackward0>)
# epoch:  1883 loss:  tensor(0.0014, grad_fn=<MseLossBackward0>)
# epoch:  1884 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  1885 loss:  tensor(0.0010, grad_fn=<MseLossBackward0>)
# epoch:  1886 loss:  tensor(0.0012, grad_fn=<MseLossBackward0>)
# epoch:  1887 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  1888 loss:  tensor(0.0007, grad_fn=<MseLossBackward0>)
# epoch:  1889 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  1890 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  1891 loss:  tensor(0.0008, grad_fn=<MseLossBackward0>)
# epoch:  1892 loss:  tensor(0.0004, grad_fn=<MseLossBackward0>)
# epoch:  1893 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1894 loss:  tensor(0.0006, grad_fn=<MseLossBackward0>)
# epoch:  1895 loss:  tensor(0.0005, grad_fn=<MseLossBackward0>)
# epoch:  1896 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  1897 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  1898 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  1899 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  1900 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  1901 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1902 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1903 loss:  tensor(0.0003, grad_fn=<MseLossBackward0>)
# epoch:  1904 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1905 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1906 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1907 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1908 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1909 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1910 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1911 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1912 loss:  tensor(0.0002, grad_fn=<MseLossBackward0>)
# epoch:  1913 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1914 loss:  tensor(9.6395e-05, grad_fn=<MseLossBackward0>)
# epoch:  1915 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1916 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1917 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1918 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1919 loss:  tensor(8.6216e-05, grad_fn=<MseLossBackward0>)
# epoch:  1920 loss:  tensor(9.1664e-05, grad_fn=<MseLossBackward0>)
# epoch:  1921 loss:  tensor(0.0001, grad_fn=<MseLossBackward0>)
# epoch:  1922 loss:  tensor(8.2309e-05, grad_fn=<MseLossBackward0>)
# epoch:  1923 loss:  tensor(7.0706e-05, grad_fn=<MseLossBackward0>)
# epoch:  1924 loss:  tensor(8.2240e-05, grad_fn=<MseLossBackward0>)
# epoch:  1925 loss:  tensor(8.0045e-05, grad_fn=<MseLossBackward0>)
# epoch:  1926 loss:  tensor(7.1573e-05, grad_fn=<MseLossBackward0>)
# epoch:  1927 loss:  tensor(7.0255e-05, grad_fn=<MseLossBackward0>)
# epoch:  1928 loss:  tensor(6.3982e-05, grad_fn=<MseLossBackward0>)
# epoch:  1929 loss:  tensor(6.3910e-05, grad_fn=<MseLossBackward0>)
# epoch:  1930 loss:  tensor(6.8332e-05, grad_fn=<MseLossBackward0>)
# epoch:  1931 loss:  tensor(6.0821e-05, grad_fn=<MseLossBackward0>)
# epoch:  1932 loss:  tensor(5.3925e-05, grad_fn=<MseLossBackward0>)
# epoch:  1933 loss:  tensor(5.7441e-05, grad_fn=<MseLossBackward0>)
# epoch:  1934 loss:  tensor(5.7251e-05, grad_fn=<MseLossBackward0>)
# epoch:  1935 loss:  tensor(5.2969e-05, grad_fn=<MseLossBackward0>)
# epoch:  1936 loss:  tensor(5.1761e-05, grad_fn=<MseLossBackward0>)
# epoch:  1937 loss:  tensor(4.9054e-05, grad_fn=<MseLossBackward0>)
# epoch:  1938 loss:  tensor(4.7477e-05, grad_fn=<MseLossBackward0>)
# epoch:  1939 loss:  tensor(4.9003e-05, grad_fn=<MseLossBackward0>)
# epoch:  1940 loss:  tensor(4.6806e-05, grad_fn=<MseLossBackward0>)
# epoch:  1941 loss:  tensor(4.2755e-05, grad_fn=<MseLossBackward0>)
# epoch:  1942 loss:  tensor(4.2800e-05, grad_fn=<MseLossBackward0>)
# epoch:  1943 loss:  tensor(4.2956e-05, grad_fn=<MseLossBackward0>)
# epoch:  1944 loss:  tensor(4.1085e-05, grad_fn=<MseLossBackward0>)
# epoch:  1945 loss:  tensor(3.9902e-05, grad_fn=<MseLossBackward0>)
# epoch:  1946 loss:  tensor(3.8602e-05, grad_fn=<MseLossBackward0>)
# epoch:  1947 loss:  tensor(3.7096e-05, grad_fn=<MseLossBackward0>)
# epoch:  1948 loss:  tensor(3.7063e-05, grad_fn=<MseLossBackward0>)
# epoch:  1949 loss:  tensor(3.6609e-05, grad_fn=<MseLossBackward0>)
# epoch:  1950 loss:  tensor(3.4596e-05, grad_fn=<MseLossBackward0>)
# epoch:  1951 loss:  tensor(3.3570e-05, grad_fn=<MseLossBackward0>)
# epoch:  1952 loss:  tensor(3.3371e-05, grad_fn=<MseLossBackward0>)
# epoch:  1953 loss:  tensor(3.2542e-05, grad_fn=<MseLossBackward0>)
# epoch:  1954 loss:  tensor(3.1676e-05, grad_fn=<MseLossBackward0>)
# epoch:  1955 loss:  tensor(3.0956e-05, grad_fn=<MseLossBackward0>)
# epoch:  1956 loss:  tensor(2.9885e-05, grad_fn=<MseLossBackward0>)
# epoch:  1957 loss:  tensor(2.9265e-05, grad_fn=<MseLossBackward0>)
# epoch:  1958 loss:  tensor(2.9023e-05, grad_fn=<MseLossBackward0>)
# epoch:  1959 loss:  tensor(2.8216e-05, grad_fn=<MseLossBackward0>)
# epoch:  1960 loss:  tensor(2.7245e-05, grad_fn=<MseLossBackward0>)
# epoch:  1961 loss:  tensor(2.6738e-05, grad_fn=<MseLossBackward0>)
# epoch:  1962 loss:  tensor(2.6240e-05, grad_fn=<MseLossBackward0>)
# epoch:  1963 loss:  tensor(2.5628e-05, grad_fn=<MseLossBackward0>)
# epoch:  1964 loss:  tensor(2.5142e-05, grad_fn=<MseLossBackward0>)
# epoch:  1965 loss:  tensor(2.4496e-05, grad_fn=<MseLossBackward0>)
# epoch:  1966 loss:  tensor(2.3827e-05, grad_fn=<MseLossBackward0>)
# epoch:  1967 loss:  tensor(2.3417e-05, grad_fn=<MseLossBackward0>)
# epoch:  1968 loss:  tensor(2.3038e-05, grad_fn=<MseLossBackward0>)
# epoch:  1969 loss:  tensor(2.2458e-05, grad_fn=<MseLossBackward0>)
# epoch:  1970 loss:  tensor(2.1929e-05, grad_fn=<MseLossBackward0>)
# epoch:  1971 loss:  tensor(2.1500e-05, grad_fn=<MseLossBackward0>)
# epoch:  1972 loss:  tensor(2.1045e-05, grad_fn=<MseLossBackward0>)
# epoch:  1973 loss:  tensor(2.0638e-05, grad_fn=<MseLossBackward0>)
# epoch:  1974 loss:  tensor(2.0254e-05, grad_fn=<MseLossBackward0>)
# epoch:  1975 loss:  tensor(1.9781e-05, grad_fn=<MseLossBackward0>)
# epoch:  1976 loss:  tensor(1.9330e-05, grad_fn=<MseLossBackward0>)
# epoch:  1977 loss:  tensor(1.8980e-05, grad_fn=<MseLossBackward0>)
# epoch:  1978 loss:  tensor(1.8620e-05, grad_fn=<MseLossBackward0>)
# epoch:  1979 loss:  tensor(1.8226e-05, grad_fn=<MseLossBackward0>)
# epoch:  1980 loss:  tensor(1.7860e-05, grad_fn=<MseLossBackward0>)
# epoch:  1981 loss:  tensor(1.7503e-05, grad_fn=<MseLossBackward0>)
# epoch:  1982 loss:  tensor(1.7151e-05, grad_fn=<MseLossBackward0>)
# epoch:  1983 loss:  tensor(1.6834e-05, grad_fn=<MseLossBackward0>)
# epoch:  1984 loss:  tensor(1.6522e-05, grad_fn=<MseLossBackward0>)
# epoch:  1985 loss:  tensor(1.6183e-05, grad_fn=<MseLossBackward0>)
# epoch:  1986 loss:  tensor(1.5861e-05, grad_fn=<MseLossBackward0>)
# epoch:  1987 loss:  tensor(1.5571e-05, grad_fn=<MseLossBackward0>)
# epoch:  1988 loss:  tensor(1.5283e-05, grad_fn=<MseLossBackward0>)
# epoch:  1989 loss:  tensor(1.4999e-05, grad_fn=<MseLossBackward0>)
# epoch:  1990 loss:  tensor(1.4725e-05, grad_fn=<MseLossBackward0>)
# epoch:  1991 loss:  tensor(1.4442e-05, grad_fn=<MseLossBackward0>)
# epoch:  1992 loss:  tensor(1.4164e-05, grad_fn=<MseLossBackward0>)
# epoch:  1993 loss:  tensor(1.3908e-05, grad_fn=<MseLossBackward0>)
# epoch:  1994 loss:  tensor(1.3654e-05, grad_fn=<MseLossBackward0>)
# epoch:  1995 loss:  tensor(1.3403e-05, grad_fn=<MseLossBackward0>)
# epoch:  1996 loss:  tensor(1.3160e-05, grad_fn=<MseLossBackward0>)
# epoch:  1997 loss:  tensor(1.2922e-05, grad_fn=<MseLossBackward0>)
# epoch:  1998 loss:  tensor(1.2685e-05, grad_fn=<MseLossBackward0>)
# epoch:  1999 loss:  tensor(1.2460e-05, grad_fn=<MseLossBackward0>)
# epoch:  2000 loss:  tensor(1.2242e-05, grad_fn=<MseLossBackward0>)
# epoch:  2001 loss:  tensor(1.2023e-05, grad_fn=<MseLossBackward0>)
# epoch:  2002 loss:  tensor(1.1807e-05, grad_fn=<MseLossBackward0>)
# epoch:  2003 loss:  tensor(1.1602e-05, grad_fn=<MseLossBackward0>)
# epoch:  2004 loss:  tensor(1.1400e-05, grad_fn=<MseLossBackward0>)
# epoch:  2005 loss:  tensor(1.1199e-05, grad_fn=<MseLossBackward0>)
# epoch:  2006 loss:  tensor(1.1008e-05, grad_fn=<MseLossBackward0>)
# epoch:  2007 loss:  tensor(1.0818e-05, grad_fn=<MseLossBackward0>)
# epoch:  2008 loss:  tensor(1.0631e-05, grad_fn=<MseLossBackward0>)
# epoch:  2009 loss:  tensor(1.0450e-05, grad_fn=<MseLossBackward0>)
# epoch:  2010 loss:  tensor(1.0273e-05, grad_fn=<MseLossBackward0>)
# epoch:  2011 loss:  tensor(1.0098e-05, grad_fn=<MseLossBackward0>)
# epoch:  2012 loss:  tensor(9.9318e-06, grad_fn=<MseLossBackward0>)
# epoch:  2013 loss:  tensor(9.7661e-06, grad_fn=<MseLossBackward0>)
# epoch:  2014 loss:  tensor(9.6068e-06, grad_fn=<MseLossBackward0>)
# epoch:  2015 loss:  tensor(9.4468e-06, grad_fn=<MseLossBackward0>)
# epoch:  2016 loss:  tensor(9.2903e-06, grad_fn=<MseLossBackward0>)
# epoch:  2017 loss:  tensor(9.1414e-06, grad_fn=<MseLossBackward0>)
# epoch:  2018 loss:  tensor(8.9871e-06, grad_fn=<MseLossBackward0>)
# epoch:  2019 loss:  tensor(8.8382e-06, grad_fn=<MseLossBackward0>)
# epoch:  2020 loss:  tensor(8.6952e-06, grad_fn=<MseLossBackward0>)
# epoch:  2021 loss:  tensor(8.5547e-06, grad_fn=<MseLossBackward0>)
# epoch:  2022 loss:  tensor(8.4178e-06, grad_fn=<MseLossBackward0>)
# epoch:  2023 loss:  tensor(8.2831e-06, grad_fn=<MseLossBackward0>)
# epoch:  2024 loss:  tensor(8.1502e-06, grad_fn=<MseLossBackward0>)
# epoch:  2025 loss:  tensor(8.0191e-06, grad_fn=<MseLossBackward0>)
# epoch:  2026 loss:  tensor(7.8919e-06, grad_fn=<MseLossBackward0>)
# epoch:  2027 loss:  tensor(7.7665e-06, grad_fn=<MseLossBackward0>)
# epoch:  2028 loss:  tensor(7.6442e-06, grad_fn=<MseLossBackward0>)
# epoch:  2029 loss:  tensor(7.5239e-06, grad_fn=<MseLossBackward0>)
# epoch:  2030 loss:  tensor(7.4044e-06, grad_fn=<MseLossBackward0>)
# epoch:  2031 loss:  tensor(7.2889e-06, grad_fn=<MseLossBackward0>)
# epoch:  2032 loss:  tensor(7.1767e-06, grad_fn=<MseLossBackward0>)
# epoch:  2033 loss:  tensor(7.0630e-06, grad_fn=<MseLossBackward0>)
# epoch:  2034 loss:  tensor(6.9550e-06, grad_fn=<MseLossBackward0>)
# epoch:  2035 loss:  tensor(6.8471e-06, grad_fn=<MseLossBackward0>)
# epoch:  2036 loss:  tensor(6.7412e-06, grad_fn=<MseLossBackward0>)
# epoch:  2037 loss:  tensor(6.6382e-06, grad_fn=<MseLossBackward0>)
# epoch:  2038 loss:  tensor(6.5367e-06, grad_fn=<MseLossBackward0>)
# epoch:  2039 loss:  tensor(6.4374e-06, grad_fn=<MseLossBackward0>)
# epoch:  2040 loss:  tensor(6.3396e-06, grad_fn=<MseLossBackward0>)
# epoch:  2041 loss:  tensor(6.2439e-06, grad_fn=<MseLossBackward0>)
# epoch:  2042 loss:  tensor(6.1493e-06, grad_fn=<MseLossBackward0>)
# epoch:  2043 loss:  tensor(6.0571e-06, grad_fn=<MseLossBackward0>)
# epoch:  2044 loss:  tensor(5.9669e-06, grad_fn=<MseLossBackward0>)
# epoch:  2045 loss:  tensor(5.8777e-06, grad_fn=<MseLossBackward0>)
# epoch:  2046 loss:  tensor(5.7905e-06, grad_fn=<MseLossBackward0>)
# epoch:  2047 loss:  tensor(5.7036e-06, grad_fn=<MseLossBackward0>)
# epoch:  2048 loss:  tensor(5.6183e-06, grad_fn=<MseLossBackward0>)
# epoch:  2049 loss:  tensor(5.5373e-06, grad_fn=<MseLossBackward0>)
# epoch:  2050 loss:  tensor(5.4554e-06, grad_fn=<MseLossBackward0>)
# epoch:  2051 loss:  tensor(5.3763e-06, grad_fn=<MseLossBackward0>)
# epoch:  2052 loss:  tensor(5.2979e-06, grad_fn=<MseLossBackward0>)
# epoch:  2053 loss:  tensor(5.2206e-06, grad_fn=<MseLossBackward0>)
# epoch:  2054 loss:  tensor(5.1449e-06, grad_fn=<MseLossBackward0>)
# epoch:  2055 loss:  tensor(5.0700e-06, grad_fn=<MseLossBackward0>)
# epoch:  2056 loss:  tensor(4.9973e-06, grad_fn=<MseLossBackward0>)
# epoch:  2057 loss:  tensor(4.9253e-06, grad_fn=<MseLossBackward0>)
# epoch:  2058 loss:  tensor(4.8576e-06, grad_fn=<MseLossBackward0>)
# epoch:  2059 loss:  tensor(4.7896e-06, grad_fn=<MseLossBackward0>)
# epoch:  2060 loss:  tensor(4.7220e-06, grad_fn=<MseLossBackward0>)
# epoch:  2061 loss:  tensor(4.6552e-06, grad_fn=<MseLossBackward0>)
# epoch:  2062 loss:  tensor(4.5890e-06, grad_fn=<MseLossBackward0>)
# epoch:  2063 loss:  tensor(4.5237e-06, grad_fn=<MseLossBackward0>)
# epoch:  2064 loss:  tensor(4.4586e-06, grad_fn=<MseLossBackward0>)
# epoch:  2065 loss:  tensor(4.3974e-06, grad_fn=<MseLossBackward0>)
# epoch:  2066 loss:  tensor(4.3375e-06, grad_fn=<MseLossBackward0>)
# epoch:  2067 loss:  tensor(4.2775e-06, grad_fn=<MseLossBackward0>)
# epoch:  2068 loss:  tensor(4.2188e-06, grad_fn=<MseLossBackward0>)
# epoch:  2069 loss:  tensor(4.1600e-06, grad_fn=<MseLossBackward0>)
# epoch:  2070 loss:  tensor(4.1016e-06, grad_fn=<MseLossBackward0>)
# epoch:  2071 loss:  tensor(4.0443e-06, grad_fn=<MseLossBackward0>)
# epoch:  2072 loss:  tensor(3.9891e-06, grad_fn=<MseLossBackward0>)
# epoch:  2073 loss:  tensor(3.9343e-06, grad_fn=<MseLossBackward0>)
# epoch:  2074 loss:  tensor(3.8812e-06, grad_fn=<MseLossBackward0>)
# epoch:  2075 loss:  tensor(3.8290e-06, grad_fn=<MseLossBackward0>)
# epoch:  2076 loss:  tensor(3.7768e-06, grad_fn=<MseLossBackward0>)
# epoch:  2077 loss:  tensor(3.7250e-06, grad_fn=<MseLossBackward0>)
# epoch:  2078 loss:  tensor(3.6737e-06, grad_fn=<MseLossBackward0>)
# epoch:  2079 loss:  tensor(3.6257e-06, grad_fn=<MseLossBackward0>)
# epoch:  2080 loss:  tensor(3.5778e-06, grad_fn=<MseLossBackward0>)
# epoch:  2081 loss:  tensor(3.5320e-06, grad_fn=<MseLossBackward0>)
# epoch:  2082 loss:  tensor(3.4871e-06, grad_fn=<MseLossBackward0>)
# epoch:  2083 loss:  tensor(3.4405e-06, grad_fn=<MseLossBackward0>)
# epoch:  2084 loss:  tensor(3.3953e-06, grad_fn=<MseLossBackward0>)
# epoch:  2085 loss:  tensor(3.3508e-06, grad_fn=<MseLossBackward0>)
# epoch:  2086 loss:  tensor(3.3071e-06, grad_fn=<MseLossBackward0>)
# epoch:  2087 loss:  tensor(3.2648e-06, grad_fn=<MseLossBackward0>)
# epoch:  2088 loss:  tensor(3.2230e-06, grad_fn=<MseLossBackward0>)
# epoch:  2089 loss:  tensor(3.1811e-06, grad_fn=<MseLossBackward0>)
# epoch:  2090 loss:  tensor(3.1397e-06, grad_fn=<MseLossBackward0>)
# epoch:  2091 loss:  tensor(3.0989e-06, grad_fn=<MseLossBackward0>)
# epoch:  2092 loss:  tensor(3.0593e-06, grad_fn=<MseLossBackward0>)
# epoch:  2093 loss:  tensor(3.0217e-06, grad_fn=<MseLossBackward0>)
# epoch:  2094 loss:  tensor(2.9822e-06, grad_fn=<MseLossBackward0>)
# epoch:  2095 loss:  tensor(2.9440e-06, grad_fn=<MseLossBackward0>)
# epoch:  2096 loss:  tensor(2.9059e-06, grad_fn=<MseLossBackward0>)
# epoch:  2097 loss:  tensor(2.8690e-06, grad_fn=<MseLossBackward0>)
# epoch:  2098 loss:  tensor(2.8327e-06, grad_fn=<MseLossBackward0>)
# epoch:  2099 loss:  tensor(2.7959e-06, grad_fn=<MseLossBackward0>)

# %% [markdown]
# What just happened?  Well, if you open `extracredit.py`  you will find these lines:
#
# ```python
#     # Well, you might want to create a model a little better than this...
#     model = torch.nn.Sequential(torch.nn.Flatten(),torch.nn.Linear(in_features=8*8*15, out_features=1))
#
#     # ... and if you do, this initialization might not be relevant any more ...
#     model[1].weight.data = initialize_weights()
#     model[1].bias.data = torch.zeros(1)
#
#     # ... and you might want to put some code here to train your model:
#     trainset = ChessDataset(filename='extracredit_train.txt')
#     trainloader = torch.utils.data.DataLoader(trainset, batch_size=1000, shuffle=True)
#     for epoch in range(2000):
#         for x,y in trainloader:
#             pass # Replace this line with some code that actually does the training
#
#     # ... after which, you should save it as "model.pkl":
#     torch.save(model, 'model.pkl')
# ```
#
# The `torch.nn.Sequential` line has flattened the input board embedding, and then multiplied it by a matrix.  The function `initialize_weights()` initializes that matrix to be exactly equal to the weights used in the PyChess linear heuristic.  If you look closely at the training part of the code, you will see that it has done nothing at all; this part of the code is only here to show you how the ChessDataset and DataLoader can be used.  After the `pass`, you see that the model, initialized but not trained, has been saved to `model.pkl`.

# %% [markdown]
# ### IV.C. Leaderboard
#
# Now that you've saved `model.pkl`, you can score it using `extracredit_grade.py`:

# %%
# !python3 extracredit_grade.py
# Out:
# /Users/dongmingsbrick/Desktop/ece448/mp06/extracredit_embedding.py:107: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1670525473998/work/torch/csrc/utils/tensor_new.cpp:233.)
#   self.embeddings = torch.tensor(embeddings,dtype=DTYPE,device=DEVICE)
# {
#   "tests": [
#     {
#       "name": "train_winratio_or_eval_winratio_gt_0.5",
#       "score": 10,
#       "max_score": 10
#     }
#   ],
#   "visibility": "visible",
#   "execution_time": 0.48866987228393555,
#   "score": 10,
#   "leaderboard": [
#     {
#       "name": "winratio_evaluation",
#       "value": 0
#     },
#     {
#       "name": "winratio_validation",
#       "value": 0.171
#     },
#     {
#       "name": "winratio_train",
#       "value": 0.9135
#     },
#     {
#       "name": "Time",
#       "value": 0.48866987228393555
#     }
#   ]
# }

# %% [markdown]
# The `leaderboard` section shows three separate scores:
#
# - `winratio_train` is the fraction, of the 1000 boards in `extracredit_train.txt`, in which your neural net beat the PyChess heuristic.  Notice that it's currently 0.5; that's because the untrained model is exactly equal to the PyChess heuristic, so that they tied (and each received 0.5 points) on all of the 1000 games.
# - `winratio_development` is the same thing, but for the boards in `extracredit_validation.txt`.
# - `winratio_evaluation` is the same thing, but for the boards in `extracredit_evaluation.txt`.  Since you don't have that file, your score is set to 0.  In order to see your actual score for this file, you'll need to submit your `extracredit.py`  to the autograder.

# %% [markdown]
# ### IV.D. Extra Credit Grade
#
# Your extra credit grade is given by the variable `score` in the output from `extracredit_grade.py`.  It is calculated as
#
# ```python
#     score = 10*min(1, sum([ max(0, min(1, 4*(winratio[x]-0.5))) for x in ['train','evaluation'] ]))
# ```
#
# In other words, you get all 10 of the available points if your win ratio is better than 0.75 on either the training set (available to you) or the evaluation set (hidden).  Notice: this means that you can get full credit if you get a  win  ratio better than 75% on the training data, even if you get a really bad win ratio on the evaluation data.

# %% [markdown]
# ### IV.E. Submission Instructions
#
# Your file `extracredit.py` must create a pytorch `torch.nn.Module` object, and then save it in a file called `model.pkl`.
#
# Pre-trained models (of any interestingly large size) cannot be uploaded to Gradescope, so your model will have to be created, trained, and saved by the file `extracredit.py`.
#
# You are strongly encouraged to load `extracredit_train.txt` and/or `extracredit_validation.txt` in your `extracredit.py`  function.
#
# In order to allow you to train interesting neural nets, we've set up Gradescope to allow you up to 40 minutes of CPU time (on one CPU).  It is possible to get full points for this extra  credit assignment in three or four minutes of training, but some of you may want to experiment with bigger models.
#
# #### Warning: Hard to beat alpha-beta!
#
# The extra credit thresholds are set so that you can get all of the points if you do well enough on the training data, even if your result is massively overtrained and doesn't generalize well to validation or evaluation data.  That's because it's actually really hard to find a neural model that beats alpha-beta by any significant margin.  <a href="https://en.wikipedia.org/wiki/Deep_Blue_(chess_computer)">Deep Blue</a> did not use a neural network explicitly, though it had a number of parameters in its evaluation function that were trained using machine-learning-like techniques.

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## V. Grade your homework

# %% [markdown]
# Submit the main part of this assignment by uploading `submitted.py` to Gradescope. You can upload other files with it, but only `submitted.py` will be retained by the autograder.
#
# Submit the extra credit part of this assignment by uploading `extracredit.py` to Gradescope. You can upload other files with it, but only `extracredit.py` will be retained by the autograder.
