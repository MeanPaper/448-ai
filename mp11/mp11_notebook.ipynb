# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python pong.py --player random
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 209 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 390 frames, score 0, max score 0
# Completed 2 games, 4 rewards, 827 frames, score 1, max score 1
# Completed 3 games, 5 rewards, 1008 frames, score 0, max score 1
# Completed 4 games, 6 rewards, 1262 frames, score 0, max score 1
# Completed 5 games, 7 rewards, 1443 frames, score 0, max score 1
# ^C
# Traceback (most recent call last):
#   File "/Users/dongmingsbrick/Desktop/ece448/mp11/pong.py", line 270, in <module>
#     application.run()
#   File "/Users/dongmingsbrick/Desktop/ece448/mp11/pong.py", line 170, in run
#     self.display.update_display()
#   File "/Users/dongmingsbrick/Desktop/ece448/mp11/pong_display.py", line 65, in update_display
#     self.fps.tick(60)
# KeyboardInterrupt

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
print(q_learner.Q.shape)
# Out:
# <submitted.q_learner object at 0x7fbba3455a00>
# (10, 10, 2, 2, 10, 3)

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print(q_learner.nfirst)
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# 5
# Next action: -1
# Next action: 0
# Next action: 1
# Next action: -1
# Next action: -1

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: 0
# Next action: 0
# Next action: 1
# Next action: -1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 1
# Next action: -1
# Next action: 0
# Next action: None

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: 1
# Next action: 0
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_y/cc0848w54977tft7vp3xvzgc0000gn/T/ipykernel_35937/814191490.py in <module>
# ----> 1 importlib.reload(submitted)
#       2 q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
#       3 q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
#       4 print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
#       5 q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
#
# NameError: name 'importlib' is not defined

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.     0.     0.3125]
# Q[9,9,1,1,8] is now [0.         0.17046875 0.        ]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: 1
# N1[9,9,1,1,8] is now [0. 0. 1.]
# Q1[9,9,1,1,8] is now [0.3125 0.     0.    ]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [0. 0. 1.]
# Q2[9,9,1,1,8] is now [0.3125 0.     0.    ]

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: -1
# N1[9,9,1,1,8] is now [1. 0. 0.]
# Q1[9,9,1,1,8] is now [0.3125 0.     0.    ]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [1. 0. 0.]
# Q2[9,9,1,1,8] is now [0.3125 0.     0.    ]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.3125 0.     0.    ]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.     0.     0.3125]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 0
# An epsilon-first action: 1
# An epsilon-first action: -1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 1
# An epsilon-first action: -1
# An epsilon-first action: 0
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x7fb9788a6280>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 182 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 363 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 544 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 798 frames, score 0, max score 0
# Completed 4 games, 6 rewards, 1303 frames, score 1, max score 1
# Completed 5 games, 7 rewards, 1557 frames, score 0, max score 1
# Completed 6 games, 8 rewards, 1738 frames, score 0, max score 1
# Completed 7 games, 9 rewards, 1919 frames, score 0, max score 1
# Completed 8 games, 12 rewards, 2535 frames, score 2, max score 2
# Completed 9 games, 13 rewards, 2716 frames, score 0, max score 2
# Completed 10 games, 14 rewards, 2924 frames, score 0, max score 2
# Completed 11 games, 17 rewards, 3597 frames, score 2, max score 2
# Completed 12 games, 18 rewards, 3778 frames, score 0, max score 2
# Completed 13 games, 19 rewards, 3959 frames, score 0, max score 2
# Completed 14 games, 20 rewards, 4213 frames, score 0, max score 2
# Completed 15 games, 21 rewards, 4394 frames, score 0, max score 2
# Completed 16 games, 22 rewards, 4602 frames, score 0, max score 2
# Completed 17 games, 23 rewards, 4783 frames, score 0, max score 2
# Completed 18 games, 25 rewards, 5188 frames, score 1, max score 2
# Completed 19 games, 27 rewards, 5534 frames, score 1, max score 2
# Completed 20 games, 28 rewards, 5788 frames, score 0, max score 2
# Completed 21 games, 30 rewards, 6140 frames, score 1, max score 2
# Completed 22 games, 31 rewards, 6348 frames, score 0, max score 2
# Completed 23 games, 32 rewards, 6529 frames, score 0, max score 2
# Completed 24 games, 34 rewards, 7119 frames, score 1, max score 2
# Completed 25 games, 35 rewards, 7373 frames, score 0, max score 2
# Completed 26 games, 36 rewards, 7627 frames, score 0, max score 2
# Completed 27 games, 38 rewards, 8361 frames, score 1, max score 2
# Completed 28 games, 39 rewards, 8542 frames, score 0, max score 2
# Completed 29 games, 40 rewards, 8750 frames, score 0, max score 2
# Completed 30 games, 41 rewards, 8958 frames, score 0, max score 2
# Completed 31 games, 43 rewards, 9395 frames, score 1, max score 2
# Completed 32 games, 44 rewards, 9576 frames, score 0, max score 2
# Completed 33 games, 48 rewards, 10194 frames, score 3, max score 3
# Completed 34 games, 50 rewards, 10728 frames, score 1, max score 3
# Completed 35 games, 51 rewards, 10936 frames, score 0, max score 3
# Completed 36 games, 53 rewards, 11470 frames, score 1, max score 3
# Completed 37 games, 54 rewards, 11724 frames, score 0, max score 3
# Completed 38 games, 55 rewards, 11905 frames, score 0, max score 3
# Completed 39 games, 56 rewards, 12086 frames, score 0, max score 3
# Completed 40 games, 57 rewards, 12267 frames, score 0, max score 3
# Completed 41 games, 58 rewards, 12448 frames, score 0, max score 3
# Completed 42 games, 60 rewards, 13110 frames, score 1, max score 3
# Completed 43 games, 62 rewards, 13516 frames, score 1, max score 3
# Completed 44 games, 63 rewards, 13724 frames, score 0, max score 3
# Completed 45 games, 64 rewards, 13905 frames, score 0, max score 3
# Completed 46 games, 67 rewards, 14679 frames, score 2, max score 3
# Completed 47 games, 68 rewards, 14860 frames, score 0, max score 3
# Completed 48 games, 69 rewards, 15041 frames, score 0, max score 3
# Completed 49 games, 70 rewards, 15222 frames, score 0, max score 3
# Completed 50 games, 71 rewards, 15476 frames, score 0, max score 3
# Completed 51 games, 72 rewards, 15730 frames, score 0, max score 3
# Completed 52 games, 75 rewards, 16457 frames, score 2, max score 3
# Completed 53 games, 77 rewards, 16913 frames, score 1, max score 3
# Completed 54 games, 78 rewards, 17121 frames, score 0, max score 3
# Completed 55 games, 79 rewards, 17329 frames, score 0, max score 3
# Completed 56 games, 80 rewards, 17583 frames, score 0, max score 3
# Completed 57 games, 81 rewards, 17837 frames, score 0, max score 3
# Completed 58 games, 82 rewards, 18018 frames, score 0, max score 3
# Completed 59 games, 84 rewards, 18446 frames, score 1, max score 3
# Completed 60 games, 85 rewards, 18700 frames, score 0, max score 3
# Completed 61 games, 87 rewards, 19212 frames, score 1, max score 3
# Completed 62 games, 89 rewards, 19675 frames, score 1, max score 3
# Completed 63 games, 90 rewards, 19929 frames, score 0, max score 3
# Completed 64 games, 91 rewards, 20110 frames, score 0, max score 3
# Completed 65 games, 93 rewards, 20477 frames, score 1, max score 3
# Completed 66 games, 94 rewards, 20731 frames, score 0, max score 3
# Completed 67 games, 95 rewards, 20939 frames, score 0, max score 3
# Completed 68 games, 96 rewards, 21147 frames, score 0, max score 3
# Completed 69 games, 97 rewards, 21328 frames, score 0, max score 3
# Completed 70 games, 99 rewards, 21734 frames, score 1, max score 3
# Completed 71 games, 100 rewards, 21988 frames, score 0, max score 3
# Completed 72 games, 101 rewards, 22196 frames, score 0, max score 3
# Completed 73 games, 103 rewards, 22701 frames, score 1, max score 3
# Completed 74 games, 104 rewards, 22909 frames, score 0, max score 3
# Completed 75 games, 106 rewards, 23307 frames, score 1, max score 3
# Completed 76 games, 109 rewards, 23949 frames, score 2, max score 3
# Completed 77 games, 111 rewards, 24437 frames, score 1, max score 3
# Completed 78 games, 112 rewards, 24691 frames, score 0, max score 3
# Completed 79 games, 113 rewards, 24899 frames, score 0, max score 3
# Completed 80 games, 114 rewards, 25080 frames, score 0, max score 3
# Completed 81 games, 115 rewards, 25334 frames, score 0, max score 3
# Completed 82 games, 118 rewards, 25860 frames, score 2, max score 3
# Completed 83 games, 120 rewards, 26450 frames, score 1, max score 3
# Completed 84 games, 121 rewards, 26704 frames, score 0, max score 3
# Completed 85 games, 122 rewards, 26912 frames, score 0, max score 3
# Completed 86 games, 123 rewards, 27166 frames, score 0, max score 3
# Completed 87 games, 125 rewards, 27828 frames, score 1, max score 3
# Completed 88 games, 126 rewards, 28009 frames, score 0, max score 3
# Completed 89 games, 127 rewards, 28217 frames, score 0, max score 3
# Completed 90 games, 128 rewards, 28398 frames, score 0, max score 3
# Completed 91 games, 130 rewards, 28895 frames, score 1, max score 3
# Completed 92 games, 131 rewards, 29076 frames, score 0, max score 3
# Completed 93 games, 132 rewards, 29257 frames, score 0, max score 3
# Completed 94 games, 135 rewards, 30083 frames, score 2, max score 3
# Completed 95 games, 136 rewards, 30337 frames, score 0, max score 3
# Completed 96 games, 137 rewards, 30518 frames, score 0, max score 3
# Completed 97 games, 138 rewards, 30772 frames, score 0, max score 3
# Completed 98 games, 139 rewards, 30953 frames, score 0, max score 3
# Completed 99 games, 140 rewards, 31161 frames, score 0, max score 3
# Completed 100 games, 141 rewards, 31369 frames, score 0, max score 3
# Completed 101 games, 143 rewards, 31775 frames, score 1, max score 3
# Completed 102 games, 145 rewards, 32203 frames, score 1, max score 3
# Completed 103 games, 147 rewards, 32631 frames, score 1, max score 3
# Completed 104 games, 148 rewards, 32885 frames, score 0, max score 3
# Completed 105 games, 149 rewards, 33093 frames, score 0, max score 3
# Completed 106 games, 151 rewards, 33461 frames, score 1, max score 3
# Completed 107 games, 152 rewards, 33669 frames, score 0, max score 3
# Completed 108 games, 157 rewards, 35198 frames, score 4, max score 4
# Completed 109 games, 159 rewards, 35612 frames, score 1, max score 4
# Completed 110 games, 160 rewards, 35793 frames, score 0, max score 4
# Completed 111 games, 161 rewards, 35974 frames, score 0, max score 4
# Completed 112 games, 162 rewards, 36155 frames, score 0, max score 4
# Completed 113 games, 163 rewards, 36336 frames, score 0, max score 4
# Completed 114 games, 165 rewards, 36848 frames, score 1, max score 4
# Completed 115 games, 168 rewards, 37328 frames, score 2, max score 4
# Completed 116 games, 170 rewards, 37680 frames, score 1, max score 4
# Completed 117 games, 171 rewards, 37861 frames, score 0, max score 4
# Completed 118 games, 172 rewards, 38069 frames, score 0, max score 4
# Completed 119 games, 173 rewards, 38323 frames, score 0, max score 4
# Completed 120 games, 174 rewards, 38577 frames, score 0, max score 4
# Completed 121 games, 175 rewards, 38785 frames, score 0, max score 4
# Completed 122 games, 176 rewards, 38966 frames, score 0, max score 4
# Completed 123 games, 177 rewards, 39147 frames, score 0, max score 4
# Completed 124 games, 179 rewards, 39545 frames, score 1, max score 4
# Completed 125 games, 180 rewards, 39753 frames, score 0, max score 4
# Completed 126 games, 181 rewards, 39961 frames, score 0, max score 4
# Completed 127 games, 183 rewards, 40353 frames, score 1, max score 4
# Completed 128 games, 184 rewards, 40561 frames, score 0, max score 4
# Completed 129 games, 185 rewards, 40815 frames, score 0, max score 4
# Completed 130 games, 186 rewards, 40996 frames, score 0, max score 4
# Completed 131 games, 187 rewards, 41250 frames, score 0, max score 4
# Completed 132 games, 191 rewards, 42114 frames, score 3, max score 4
# Completed 133 games, 195 rewards, 42778 frames, score 3, max score 4
# Completed 134 games, 196 rewards, 43032 frames, score 0, max score 4
# Completed 135 games, 197 rewards, 43240 frames, score 0, max score 4
# Completed 136 games, 200 rewards, 43826 frames, score 2, max score 4
# Completed 137 games, 201 rewards, 44080 frames, score 0, max score 4
# Completed 138 games, 203 rewards, 44485 frames, score 1, max score 4
# Completed 139 games, 204 rewards, 44693 frames, score 0, max score 4
# Completed 140 games, 208 rewards, 45470 frames, score 3, max score 4
# Completed 141 games, 209 rewards, 45651 frames, score 0, max score 4
# Completed 142 games, 210 rewards, 45905 frames, score 0, max score 4
# Completed 143 games, 211 rewards, 46086 frames, score 0, max score 4
# Completed 144 games, 213 rewards, 46574 frames, score 1, max score 4
# Completed 145 games, 214 rewards, 46782 frames, score 0, max score 4
# Completed 146 games, 216 rewards, 47430 frames, score 1, max score 4
# Completed 147 games, 217 rewards, 47638 frames, score 0, max score 4
# Completed 148 games, 218 rewards, 47819 frames, score 0, max score 4
# Completed 149 games, 221 rewards, 48550 frames, score 2, max score 4
# Completed 150 games, 222 rewards, 48804 frames, score 0, max score 4
# Completed 151 games, 223 rewards, 49012 frames, score 0, max score 4
# Completed 152 games, 224 rewards, 49220 frames, score 0, max score 4
# Completed 153 games, 226 rewards, 49771 frames, score 1, max score 4
# Completed 154 games, 227 rewards, 49979 frames, score 0, max score 4
# Completed 155 games, 228 rewards, 50160 frames, score 0, max score 4
# Completed 156 games, 231 rewards, 50833 frames, score 2, max score 4
# Completed 157 games, 232 rewards, 51087 frames, score 0, max score 4
# Completed 158 games, 238 rewards, 52677 frames, score 5, max score 5
# Completed 159 games, 239 rewards, 52858 frames, score 0, max score 5
# Completed 160 games, 241 rewards, 53226 frames, score 1, max score 5
# Completed 161 games, 244 rewards, 54115 frames, score 2, max score 5
# Completed 162 games, 247 rewards, 54788 frames, score 2, max score 5
# Completed 163 games, 248 rewards, 55042 frames, score 0, max score 5
# Completed 164 games, 252 rewards, 56199 frames, score 3, max score 5
# Completed 165 games, 254 rewards, 56627 frames, score 1, max score 5
# Completed 166 games, 255 rewards, 56808 frames, score 0, max score 5
# Completed 167 games, 257 rewards, 57245 frames, score 1, max score 5
# Completed 168 games, 260 rewards, 57736 frames, score 2, max score 5
# Completed 169 games, 261 rewards, 57990 frames, score 0, max score 5
# Completed 170 games, 262 rewards, 58171 frames, score 0, max score 5
# Completed 171 games, 263 rewards, 58352 frames, score 0, max score 5
# Completed 172 games, 264 rewards, 58533 frames, score 0, max score 5
# Completed 173 games, 265 rewards, 58714 frames, score 0, max score 5
# Completed 174 games, 266 rewards, 58968 frames, score 0, max score 5
# Completed 175 games, 269 rewards, 59717 frames, score 2, max score 5
# Completed 176 games, 271 rewards, 60451 frames, score 1, max score 5
# Completed 177 games, 273 rewards, 60888 frames, score 1, max score 5
# Completed 178 games, 275 rewards, 61490 frames, score 1, max score 5
# Completed 179 games, 276 rewards, 61671 frames, score 0, max score 5
# Completed 180 games, 279 rewards, 62939 frames, score 2, max score 5
# Completed 181 games, 281 rewards, 63417 frames, score 1, max score 5
# Completed 182 games, 282 rewards, 63598 frames, score 0, max score 5
# Completed 183 games, 283 rewards, 63779 frames, score 0, max score 5
# Completed 184 games, 284 rewards, 63960 frames, score 0, max score 5
# Completed 185 games, 285 rewards, 64141 frames, score 0, max score 5
# Completed 186 games, 286 rewards, 64322 frames, score 0, max score 5
# Completed 187 games, 288 rewards, 64865 frames, score 1, max score 5
# Completed 188 games, 289 rewards, 65119 frames, score 0, max score 5
# Completed 189 games, 291 rewards, 65695 frames, score 1, max score 5
# Completed 190 games, 292 rewards, 65949 frames, score 0, max score 5
# Completed 191 games, 295 rewards, 66480 frames, score 2, max score 5
# Completed 192 games, 300 rewards, 69759 frames, score 4, max score 5
# Completed 193 games, 302 rewards, 70310 frames, score 1, max score 5
# Completed 194 games, 304 rewards, 70798 frames, score 1, max score 5
# Completed 195 games, 306 rewards, 71258 frames, score 1, max score 5
# Completed 196 games, 307 rewards, 71439 frames, score 0, max score 5
# Completed 197 games, 308 rewards, 71647 frames, score 0, max score 5
# Completed 198 games, 309 rewards, 71901 frames, score 0, max score 5
# Completed 199 games, 310 rewards, 72082 frames, score 0, max score 5
# Completed 200 games, 311 rewards, 72336 frames, score 0, max score 5
# Completed 201 games, 312 rewards, 72590 frames, score 0, max score 5
# Completed 202 games, 317 rewards, 73739 frames, score 4, max score 5
# Completed 203 games, 319 rewards, 74122 frames, score 1, max score 5
# Completed 204 games, 321 rewards, 74536 frames, score 1, max score 5
# Completed 205 games, 322 rewards, 74790 frames, score 0, max score 5
# Completed 206 games, 323 rewards, 75044 frames, score 0, max score 5
# Completed 207 games, 326 rewards, 75579 frames, score 2, max score 5
# Completed 208 games, 327 rewards, 75760 frames, score 0, max score 5
# Completed 209 games, 329 rewards, 76350 frames, score 1, max score 5
# Completed 210 games, 331 rewards, 76847 frames, score 1, max score 5
# Completed 211 games, 334 rewards, 77417 frames, score 2, max score 5
# Completed 212 games, 335 rewards, 77625 frames, score 0, max score 5
# Completed 213 games, 336 rewards, 77806 frames, score 0, max score 5
# Completed 214 games, 341 rewards, 79761 frames, score 4, max score 5
# Completed 215 games, 342 rewards, 79969 frames, score 0, max score 5
# Completed 216 games, 343 rewards, 80177 frames, score 0, max score 5
# Completed 217 games, 344 rewards, 80431 frames, score 0, max score 5
# Completed 218 games, 348 rewards, 81212 frames, score 3, max score 5
# Completed 219 games, 349 rewards, 81420 frames, score 0, max score 5
# Completed 220 games, 352 rewards, 82129 frames, score 2, max score 5
# Completed 221 games, 354 rewards, 82791 frames, score 1, max score 5
# Completed 222 games, 355 rewards, 82972 frames, score 0, max score 5
# Completed 223 games, 357 rewards, 83892 frames, score 1, max score 5
# Completed 224 games, 358 rewards, 84100 frames, score 0, max score 5
# Completed 225 games, 360 rewards, 84506 frames, score 1, max score 5
# Completed 226 games, 363 rewards, 85057 frames, score 2, max score 5
# Completed 227 games, 369 rewards, 85996 frames, score 5, max score 5
# Completed 228 games, 371 rewards, 86508 frames, score 1, max score 5
# Completed 229 games, 372 rewards, 86762 frames, score 0, max score 5
# Completed 230 games, 374 rewards, 87267 frames, score 1, max score 5
# Completed 231 games, 375 rewards, 87521 frames, score 0, max score 5
# Completed 232 games, 376 rewards, 87775 frames, score 0, max score 5
# Completed 233 games, 377 rewards, 88029 frames, score 0, max score 5
# Completed 234 games, 382 rewards, 89440 frames, score 4, max score 5
# Completed 235 games, 383 rewards, 89694 frames, score 0, max score 5
# Completed 236 games, 385 rewards, 90035 frames, score 1, max score 5
# Completed 237 games, 386 rewards, 90289 frames, score 0, max score 5
# Completed 238 games, 388 rewards, 90891 frames, score 1, max score 5
# Completed 239 games, 389 rewards, 91072 frames, score 0, max score 5
# Completed 240 games, 390 rewards, 91253 frames, score 0, max score 5
# Completed 241 games, 391 rewards, 91434 frames, score 0, max score 5
# Completed 242 games, 392 rewards, 91615 frames, score 0, max score 5
# Completed 243 games, 394 rewards, 92205 frames, score 1, max score 5
# Completed 244 games, 395 rewards, 92459 frames, score 0, max score 5
# Completed 245 games, 400 rewards, 93293 frames, score 4, max score 5
# Completed 246 games, 402 rewards, 93827 frames, score 1, max score 5
# Completed 247 games, 407 rewards, 94727 frames, score 4, max score 5
# Completed 248 games, 408 rewards, 94981 frames, score 0, max score 5
# Completed 249 games, 410 rewards, 95583 frames, score 1, max score 5
# Completed 250 games, 411 rewards, 95837 frames, score 0, max score 5
# Completed 251 games, 412 rewards, 96018 frames, score 0, max score 5
# Completed 252 games, 413 rewards, 96272 frames, score 0, max score 5
# Completed 253 games, 416 rewards, 97647 frames, score 2, max score 5
# Completed 254 games, 419 rewards, 99181 frames, score 2, max score 5
# Completed 255 games, 420 rewards, 99362 frames, score 0, max score 5
# Completed 256 games, 421 rewards, 99616 frames, score 0, max score 5
# Completed 257 games, 422 rewards, 99870 frames, score 0, max score 5
# Completed 258 games, 423 rewards, 100051 frames, score 0, max score 5
# Completed 259 games, 424 rewards, 100259 frames, score 0, max score 5
# Completed 260 games, 426 rewards, 100642 frames, score 1, max score 5
# Completed 261 games, 427 rewards, 100850 frames, score 0, max score 5
# Completed 262 games, 429 rewards, 101401 frames, score 1, max score 5
# Completed 263 games, 430 rewards, 101582 frames, score 0, max score 5
# Completed 264 games, 431 rewards, 101836 frames, score 0, max score 5
# Completed 265 games, 432 rewards, 102044 frames, score 0, max score 5
# Completed 266 games, 433 rewards, 102252 frames, score 0, max score 5
# Completed 267 games, 434 rewards, 102460 frames, score 0, max score 5
# Completed 268 games, 436 rewards, 103194 frames, score 1, max score 5
# Completed 269 games, 438 rewards, 103856 frames, score 1, max score 5
# Completed 270 games, 439 rewards, 104110 frames, score 0, max score 5
# Completed 271 games, 442 rewards, 104674 frames, score 2, max score 5
# Completed 272 games, 444 rewards, 105088 frames, score 1, max score 5
# Completed 273 games, 447 rewards, 105750 frames, score 2, max score 5
# Completed 274 games, 449 rewards, 106213 frames, score 1, max score 5
# Completed 275 games, 450 rewards, 106394 frames, score 0, max score 5
# Completed 276 games, 451 rewards, 106602 frames, score 0, max score 5
# Completed 277 games, 452 rewards, 106856 frames, score 0, max score 5
# Completed 278 games, 453 rewards, 107064 frames, score 0, max score 5
# Completed 279 games, 454 rewards, 107272 frames, score 0, max score 5
# Completed 280 games, 455 rewards, 107480 frames, score 0, max score 5
# Completed 281 games, 456 rewards, 107734 frames, score 0, max score 5
# Completed 282 games, 457 rewards, 107988 frames, score 0, max score 5
# Completed 283 games, 458 rewards, 108169 frames, score 0, max score 5
# Completed 284 games, 462 rewards, 109080 frames, score 3, max score 5
# Completed 285 games, 467 rewards, 109948 frames, score 4, max score 5
# Completed 286 games, 473 rewards, 111532 frames, score 5, max score 5
# Completed 287 games, 476 rewards, 112356 frames, score 2, max score 5
# Completed 288 games, 477 rewards, 112537 frames, score 0, max score 5
# Completed 289 games, 479 rewards, 113037 frames, score 1, max score 5
# Completed 290 games, 480 rewards, 113218 frames, score 0, max score 5
# Completed 291 games, 482 rewards, 113769 frames, score 1, max score 5
# Completed 292 games, 484 rewards, 114313 frames, score 1, max score 5
# Completed 293 games, 485 rewards, 114567 frames, score 0, max score 5
# Completed 294 games, 487 rewards, 115183 frames, score 1, max score 5
# Completed 295 games, 488 rewards, 115437 frames, score 0, max score 5
# Completed 296 games, 489 rewards, 115618 frames, score 0, max score 5
# Completed 297 games, 490 rewards, 115872 frames, score 0, max score 5
# Completed 298 games, 491 rewards, 116080 frames, score 0, max score 5
# Completed 299 games, 494 rewards, 116965 frames, score 2, max score 5
# Completed 300 games, 495 rewards, 117219 frames, score 0, max score 5
# Completed 301 games, 496 rewards, 117473 frames, score 0, max score 5
# Completed 302 games, 497 rewards, 117681 frames, score 0, max score 5
# Completed 303 games, 499 rewards, 118343 frames, score 1, max score 5
# Completed 304 games, 500 rewards, 118597 frames, score 0, max score 5
# The number of games played was 306
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  2.2141201203966046

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  2.2141201203966046

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 6 rewards, 1257 frames, score 5, max score 265
# Completed 1 games, 18 rewards, 4783 frames, score 11, max score 265
# Completed 2 games, 22 rewards, 5638 frames, score 3, max score 265
# Completed 3 games, 26 rewards, 6419 frames, score 3, max score 265
# Completed 4 games, 36 rewards, 8022 frames, score 9, max score 265
# Completed 5 games, 40 rewards, 8830 frames, score 3, max score 265
# Completed 6 games, 44 rewards, 9600 frames, score 3, max score 265
# Completed 7 games, 47 rewards, 10281 frames, score 2, max score 265
# Completed 8 games, 49 rewards, 10718 frames, score 1, max score 265
# Completed 9 games, 55 rewards, 11736 frames, score 5, max score 265
# Completed 10 games, 56 rewards, 11990 frames, score 0, max score 265
# Completed 11 games, 78 rewards, 16144 frames, score 21, max score 265
# Completed 12 games, 86 rewards, 17566 frames, score 7, max score 265
# Completed 13 games, 95 rewards, 19400 frames, score 8, max score 265
# Completed 14 games, 98 rewards, 19926 frames, score 2, max score 265
# Completed 15 games, 128 rewards, 26962 frames, score 29, max score 265
# Completed 16 games, 135 rewards, 28102 frames, score 6, max score 265
# Completed 17 games, 146 rewards, 29782 frames, score 10, max score 265
# Completed 18 games, 156 rewards, 31425 frames, score 9, max score 265
# Completed 19 games, 161 rewards, 32374 frames, score 4, max score 265
# Completed 20 games, 164 rewards, 32920 frames, score 2, max score 265
# Completed 21 games, 168 rewards, 33858 frames, score 3, max score 265
# Completed 22 games, 176 rewards, 37057 frames, score 7, max score 265
# Completed 23 games, 179 rewards, 37788 frames, score 2, max score 265
# Completed 24 games, 188 rewards, 39251 frames, score 8, max score 265
# Completed 25 games, 193 rewards, 40272 frames, score 4, max score 265
# Completed 26 games, 199 rewards, 41493 frames, score 5, max score 265
# Completed 27 games, 201 rewards, 42083 frames, score 1, max score 265
# Completed 28 games, 210 rewards, 45084 frames, score 8, max score 265
# Completed 29 games, 216 rewards, 47726 frames, score 5, max score 265
# Completed 30 games, 222 rewards, 49485 frames, score 5, max score 265
# Completed 31 games, 229 rewards, 50603 frames, score 6, max score 265
# Completed 32 games, 247 rewards, 55952 frames, score 17, max score 265
# Completed 33 games, 251 rewards, 56761 frames, score 3, max score 265
# Completed 34 games, 260 rewards, 58677 frames, score 8, max score 265
# Completed 35 games, 272 rewards, 60831 frames, score 11, max score 265
# Completed 36 games, 273 rewards, 61012 frames, score 0, max score 265
# Completed 37 games, 277 rewards, 62048 frames, score 3, max score 265
# Completed 38 games, 289 rewards, 63836 frames, score 11, max score 265
# Completed 39 games, 300 rewards, 65609 frames, score 10, max score 265
# Completed 40 games, 302 rewards, 66211 frames, score 1, max score 265
# Completed 41 games, 312 rewards, 68400 frames, score 9, max score 265
# Completed 42 games, 320 rewards, 70066 frames, score 7, max score 265
# Completed 43 games, 323 rewards, 70753 frames, score 2, max score 265
# Completed 44 games, 325 rewards, 71105 frames, score 1, max score 265
# Completed 45 games, 330 rewards, 72172 frames, score 4, max score 265
# Completed 46 games, 332 rewards, 72635 frames, score 1, max score 265
# Completed 47 games, 345 rewards, 75610 frames, score 12, max score 265
# Completed 48 games, 354 rewards, 77371 frames, score 8, max score 265
# Completed 49 games, 359 rewards, 78225 frames, score 4, max score 265
# Completed 50 games, 370 rewards, 81171 frames, score 10, max score 265
# Completed 51 games, 382 rewards, 83953 frames, score 11, max score 265
# Completed 52 games, 395 rewards, 90565 frames, score 12, max score 265
# Completed 53 games, 406 rewards, 93094 frames, score 10, max score 265
# Completed 54 games, 409 rewards, 94628 frames, score 2, max score 265
# Completed 55 games, 415 rewards, 95860 frames, score 5, max score 265
# Completed 56 games, 420 rewards, 96582 frames, score 4, max score 265
# Completed 57 games, 433 rewards, 99187 frames, score 12, max score 265
# Completed 58 games, 446 rewards, 106340 frames, score 12, max score 265
# Completed 59 games, 447 rewards, 106548 frames, score 0, max score 265
# Completed 60 games, 448 rewards, 106802 frames, score 0, max score 265
# Completed 61 games, 457 rewards, 108600 frames, score 8, max score 265
# Completed 62 games, 462 rewards, 109585 frames, score 4, max score 265
# Completed 63 games, 489 rewards, 114177 frames, score 26, max score 265
# Completed 64 games, 495 rewards, 115973 frames, score 5, max score 265
# Completed 65 games, 505 rewards, 118556 frames, score 9, max score 265
# Completed 66 games, 508 rewards, 119144 frames, score 2, max score 265
# Completed 67 games, 514 rewards, 120460 frames, score 5, max score 265
# Completed 68 games, 516 rewards, 121011 frames, score 1, max score 265
# Completed 69 games, 526 rewards, 122762 frames, score 9, max score 265
# Completed 70 games, 542 rewards, 126106 frames, score 15, max score 265
# Completed 71 games, 545 rewards, 126779 frames, score 2, max score 265
# Completed 72 games, 550 rewards, 127644 frames, score 4, max score 265
# Completed 73 games, 558 rewards, 129141 frames, score 7, max score 265
# Completed 74 games, 564 rewards, 130185 frames, score 5, max score 265
# Completed 75 games, 570 rewards, 131168 frames, score 5, max score 265
# Completed 76 games, 583 rewards, 133240 frames, score 12, max score 265
# Completed 77 games, 585 rewards, 133607 frames, score 1, max score 265
# Completed 78 games, 626 rewards, 147787 frames, score 40, max score 265
# Completed 79 games, 634 rewards, 149014 frames, score 7, max score 265
# Completed 80 games, 636 rewards, 149419 frames, score 1, max score 265
# Completed 81 games, 645 rewards, 150965 frames, score 8, max score 265
# Completed 82 games, 659 rewards, 153308 frames, score 13, max score 265
# Completed 83 games, 674 rewards, 157753 frames, score 14, max score 265
# Completed 84 games, 733 rewards, 177440 frames, score 58, max score 265
# Completed 85 games, 741 rewards, 180152 frames, score 7, max score 265
# Completed 86 games, 755 rewards, 182631 frames, score 13, max score 265
# Completed 87 games, 761 rewards, 183666 frames, score 5, max score 265
# Completed 88 games, 780 rewards, 187032 frames, score 18, max score 265
# Completed 89 games, 782 rewards, 187437 frames, score 1, max score 265
# Completed 90 games, 783 rewards, 187691 frames, score 0, max score 265
# Completed 91 games, 787 rewards, 188448 frames, score 3, max score 265
# Completed 92 games, 789 rewards, 188885 frames, score 1, max score 265
# Completed 93 games, 813 rewards, 192428 frames, score 23, max score 265
# Completed 94 games, 830 rewards, 195952 frames, score 16, max score 265
# Completed 95 games, 835 rewards, 196838 frames, score 4, max score 265
# Completed 96 games, 846 rewards, 199708 frames, score 10, max score 265
# Completed 97 games, 867 rewards, 206540 frames, score 20, max score 265
# Completed 98 games, 899 rewards, 217650 frames, score 31, max score 265
# Completed 99 games, 901 rewards, 218184 frames, score 1, max score 265
# Completed 100 games, 909 rewards, 219553 frames, score 7, max score 265
# Completed 101 games, 923 rewards, 222335 frames, score 13, max score 265
# Completed 102 games, 929 rewards, 225549 frames, score 5, max score 265
# Completed 103 games, 940 rewards, 227789 frames, score 10, max score 265
# Completed 104 games, 941 rewards, 227997 frames, score 0, max score 265
# Completed 105 games, 966 rewards, 232087 frames, score 24, max score 265
# Completed 106 games, 971 rewards, 234154 frames, score 4, max score 265
# Completed 107 games, 1000 rewards, 240219 frames, score 28, max score 265
# Completed 108 games, 1016 rewards, 247011 frames, score 15, max score 265
# Completed 109 games, 1024 rewards, 250763 frames, score 7, max score 265
# Completed 110 games, 1047 rewards, 255823 frames, score 22, max score 265
# Completed 111 games, 1050 rewards, 256762 frames, score 2, max score 265
# Completed 112 games, 1062 rewards, 259507 frames, score 11, max score 265
# Completed 113 games, 1069 rewards, 260886 frames, score 6, max score 265
# Completed 114 games, 1091 rewards, 266047 frames, score 21, max score 265
# Completed 115 games, 1121 rewards, 277919 frames, score 29, max score 265
# Completed 116 games, 1139 rewards, 281937 frames, score 17, max score 265
# Completed 117 games, 1141 rewards, 282365 frames, score 1, max score 265
# Completed 118 games, 1166 rewards, 286534 frames, score 24, max score 265
# Completed 119 games, 1183 rewards, 289358 frames, score 16, max score 265
# Completed 120 games, 1188 rewards, 290678 frames, score 4, max score 265
# Completed 121 games, 1190 rewards, 291045 frames, score 1, max score 265
# Completed 122 games, 1199 rewards, 292699 frames, score 8, max score 265
# Completed 123 games, 1201 rewards, 293196 frames, score 1, max score 265
# Completed 124 games, 1207 rewards, 294333 frames, score 5, max score 265
# Completed 125 games, 1224 rewards, 298284 frames, score 16, max score 265
# Completed 126 games, 1244 rewards, 305541 frames, score 19, max score 265
# Completed 127 games, 1252 rewards, 307269 frames, score 7, max score 265
# Completed 128 games, 1264 rewards, 310467 frames, score 11, max score 265
# Completed 129 games, 1272 rewards, 316684 frames, score 7, max score 265
# Completed 130 games, 1324 rewards, 330877 frames, score 51, max score 265
# Completed 131 games, 1332 rewards, 332572 frames, score 7, max score 265
# Completed 132 games, 1338 rewards, 333972 frames, score 5, max score 265
# Completed 133 games, 1364 rewards, 343305 frames, score 25, max score 265
# Completed 134 games, 1377 rewards, 345749 frames, score 12, max score 265
# Completed 135 games, 1382 rewards, 347981 frames, score 4, max score 265
# Completed 136 games, 1390 rewards, 349228 frames, score 7, max score 265
# Completed 137 games, 1399 rewards, 350805 frames, score 8, max score 265
# Completed 138 games, 1415 rewards, 356281 frames, score 15, max score 265
# Completed 139 games, 1430 rewards, 360660 frames, score 14, max score 265
# Completed 140 games, 1451 rewards, 363807 frames, score 20, max score 265
# Completed 141 games, 1475 rewards, 367393 frames, score 23, max score 265
# Completed 142 games, 1484 rewards, 369080 frames, score 8, max score 265
# Completed 143 games, 1508 rewards, 373618 frames, score 23, max score 265
# Completed 144 games, 1537 rewards, 382957 frames, score 28, max score 265
# Completed 145 games, 1545 rewards, 385027 frames, score 7, max score 265
# Completed 146 games, 1554 rewards, 387205 frames, score 8, max score 265
# Completed 147 games, 1557 rewards, 387713 frames, score 2, max score 265
# Completed 148 games, 1587 rewards, 397866 frames, score 29, max score 265
# Completed 149 games, 1590 rewards, 398830 frames, score 2, max score 265
# Completed 150 games, 1599 rewards, 400819 frames, score 8, max score 265
# Completed 151 games, 1602 rewards, 401721 frames, score 2, max score 265
# Completed 152 games, 1608 rewards, 403218 frames, score 5, max score 265
# Completed 153 games, 1634 rewards, 411446 frames, score 25, max score 265
# Completed 154 games, 1647 rewards, 414231 frames, score 12, max score 265
# Completed 155 games, 1652 rewards, 415958 frames, score 4, max score 265
# Completed 156 games, 1659 rewards, 417077 frames, score 6, max score 265
# Completed 157 games, 1664 rewards, 418174 frames, score 4, max score 265
# Completed 158 games, 1695 rewards, 429928 frames, score 30, max score 265
# Completed 159 games, 1702 rewards, 431064 frames, score 6, max score 265
# Completed 160 games, 1706 rewards, 432026 frames, score 3, max score 265
# Completed 161 games, 1712 rewards, 432936 frames, score 5, max score 265
# Completed 162 games, 1719 rewards, 434008 frames, score 6, max score 265
# Completed 163 games, 1722 rewards, 434832 frames, score 2, max score 265
# Completed 164 games, 1727 rewards, 435965 frames, score 4, max score 265
# Completed 165 games, 1734 rewards, 439092 frames, score 6, max score 265
# Completed 166 games, 1755 rewards, 443067 frames, score 20, max score 265
# Completed 167 games, 1762 rewards, 444961 frames, score 6, max score 265
# Completed 168 games, 1770 rewards, 446334 frames, score 7, max score 265
# Completed 169 games, 1775 rewards, 447198 frames, score 4, max score 265
# Completed 170 games, 1790 rewards, 450021 frames, score 14, max score 265
# Completed 171 games, 1798 rewards, 451335 frames, score 7, max score 265
# Completed 172 games, 1810 rewards, 453533 frames, score 11, max score 265
# Completed 173 games, 1822 rewards, 456609 frames, score 11, max score 265
# Completed 174 games, 1826 rewards, 458007 frames, score 3, max score 265
# Completed 175 games, 1849 rewards, 462680 frames, score 22, max score 265
# Completed 176 games, 1857 rewards, 464069 frames, score 7, max score 265
# Completed 177 games, 1868 rewards, 466311 frames, score 10, max score 265
# Completed 178 games, 1873 rewards, 467312 frames, score 4, max score 265
# Completed 179 games, 1912 rewards, 477082 frames, score 38, max score 265
# Completed 180 games, 1920 rewards, 478274 frames, score 7, max score 265
# Completed 181 games, 1923 rewards, 478895 frames, score 2, max score 265
# Completed 182 games, 1930 rewards, 480106 frames, score 6, max score 265
# Completed 183 games, 1935 rewards, 480974 frames, score 4, max score 265
# Completed 184 games, 1941 rewards, 481883 frames, score 5, max score 265
# Completed 185 games, 1942 rewards, 482064 frames, score 0, max score 265
# Completed 186 games, 1951 rewards, 483727 frames, score 8, max score 265
# Completed 187 games, 1962 rewards, 485523 frames, score 10, max score 265
# Completed 188 games, 1975 rewards, 487593 frames, score 12, max score 265
# Completed 189 games, 1988 rewards, 489690 frames, score 12, max score 265
# Completed 190 games, 2015 rewards, 497029 frames, score 26, max score 265
# Completed 191 games, 2037 rewards, 506073 frames, score 21, max score 265
# Completed 192 games, 2046 rewards, 508130 frames, score 8, max score 265
# Completed 193 games, 2049 rewards, 508636 frames, score 2, max score 265
# Completed 194 games, 2060 rewards, 510932 frames, score 10, max score 265
# Completed 195 games, 2084 rewards, 514634 frames, score 23, max score 265
# Completed 196 games, 2091 rewards, 515872 frames, score 6, max score 265
# Completed 197 games, 2103 rewards, 518528 frames, score 11, max score 265
# Completed 198 games, 2114 rewards, 521321 frames, score 10, max score 265
# Completed 199 games, 2125 rewards, 525165 frames, score 10, max score 265
# Completed 200 games, 2157 rewards, 530126 frames, score 31, max score 265
# Completed 201 games, 2173 rewards, 537188 frames, score 15, max score 265
# Completed 202 games, 2176 rewards, 537742 frames, score 2, max score 265
# Completed 203 games, 2181 rewards, 539067 frames, score 4, max score 265
# Completed 204 games, 2185 rewards, 539922 frames, score 3, max score 265
# Completed 205 games, 2194 rewards, 541264 frames, score 8, max score 265
# Completed 206 games, 2214 rewards, 544491 frames, score 19, max score 265
# Completed 207 games, 2258 rewards, 555623 frames, score 43, max score 265
# Completed 208 games, 2270 rewards, 559114 frames, score 11, max score 265
# Completed 209 games, 2283 rewards, 561555 frames, score 12, max score 265
# Completed 210 games, 2298 rewards, 564335 frames, score 14, max score 265
# Completed 211 games, 2337 rewards, 574788 frames, score 38, max score 265
# Completed 212 games, 2341 rewards, 575556 frames, score 3, max score 265
# Completed 213 games, 2362 rewards, 578979 frames, score 20, max score 265
# Completed 214 games, 2365 rewards, 579493 frames, score 2, max score 265
# Completed 215 games, 2390 rewards, 588611 frames, score 24, max score 265
# Completed 216 games, 2397 rewards, 589786 frames, score 6, max score 265
# Completed 217 games, 2431 rewards, 599471 frames, score 33, max score 265
# Completed 218 games, 2437 rewards, 600554 frames, score 5, max score 265
# Completed 219 games, 2460 rewards, 604442 frames, score 22, max score 265
# Completed 220 games, 2482 rewards, 607833 frames, score 21, max score 265
# Completed 221 games, 2490 rewards, 609049 frames, score 7, max score 265
# Completed 222 games, 2521 rewards, 614447 frames, score 30, max score 265
# Completed 223 games, 2541 rewards, 617808 frames, score 19, max score 265
# Completed 224 games, 2552 rewards, 619950 frames, score 10, max score 265
# Completed 225 games, 2556 rewards, 620792 frames, score 3, max score 265
# Completed 226 games, 2574 rewards, 626445 frames, score 17, max score 265
# Completed 227 games, 2597 rewards, 630011 frames, score 22, max score 265
# Completed 228 games, 2612 rewards, 633174 frames, score 14, max score 265
# Completed 229 games, 2620 rewards, 634375 frames, score 7, max score 265
# Completed 230 games, 2630 rewards, 636364 frames, score 9, max score 265
# Completed 231 games, 2634 rewards, 637115 frames, score 3, max score 265
# Completed 232 games, 2648 rewards, 639526 frames, score 13, max score 265
# Completed 233 games, 2712 rewards, 667816 frames, score 63, max score 265
# Completed 234 games, 2749 rewards, 673511 frames, score 36, max score 265
# Completed 235 games, 2774 rewards, 677620 frames, score 24, max score 265
# Completed 236 games, 2808 rewards, 684990 frames, score 33, max score 265
# Completed 237 games, 2820 rewards, 688362 frames, score 11, max score 265
# Completed 238 games, 2826 rewards, 689542 frames, score 5, max score 265
# Completed 239 games, 2855 rewards, 700013 frames, score 28, max score 265
# Completed 240 games, 2862 rewards, 701597 frames, score 6, max score 265
# Completed 241 games, 2877 rewards, 703969 frames, score 14, max score 265
# Completed 242 games, 2912 rewards, 709399 frames, score 34, max score 265
# Completed 243 games, 2943 rewards, 714181 frames, score 30, max score 265
# Completed 244 games, 2955 rewards, 716286 frames, score 11, max score 265
# Completed 245 games, 2995 rewards, 722299 frames, score 39, max score 265
# Completed 246 games, 3014 rewards, 725094 frames, score 18, max score 265
# Completed 247 games, 3030 rewards, 729121 frames, score 15, max score 265
# Completed 248 games, 3038 rewards, 731296 frames, score 7, max score 265
# Completed 249 games, 3041 rewards, 731969 frames, score 2, max score 265
# Completed 250 games, 3048 rewards, 733557 frames, score 6, max score 265
# Completed 251 games, 3056 rewards, 734836 frames, score 7, max score 265
# Completed 252 games, 3110 rewards, 751693 frames, score 53, max score 265
# Completed 253 games, 3132 rewards, 755632 frames, score 21, max score 265
# Completed 254 games, 3146 rewards, 758949 frames, score 13, max score 265
# Completed 255 games, 3170 rewards, 762822 frames, score 23, max score 265
# Completed 256 games, 3190 rewards, 768292 frames, score 19, max score 265
# Completed 257 games, 3212 rewards, 771348 frames, score 21, max score 265
# Completed 258 games, 3255 rewards, 783174 frames, score 42, max score 265
# Completed 259 games, 3262 rewards, 784217 frames, score 6, max score 265
# Completed 260 games, 3284 rewards, 787811 frames, score 21, max score 265
# Completed 261 games, 3382 rewards, 818332 frames, score 97, max score 265
# Completed 262 games, 3388 rewards, 819664 frames, score 5, max score 265
# Completed 263 games, 3429 rewards, 829661 frames, score 40, max score 265
# Completed 264 games, 3440 rewards, 833404 frames, score 10, max score 265
# Completed 265 games, 3455 rewards, 835884 frames, score 14, max score 265
# Completed 266 games, 3462 rewards, 838501 frames, score 6, max score 265
# Completed 267 games, 3467 rewards, 839509 frames, score 4, max score 265
# Completed 268 games, 3503 rewards, 851221 frames, score 35, max score 265
# Completed 269 games, 3517 rewards, 855529 frames, score 13, max score 265
# Completed 270 games, 3543 rewards, 863578 frames, score 25, max score 265
# Completed 271 games, 3555 rewards, 868100 frames, score 11, max score 265
# Completed 272 games, 3576 rewards, 872138 frames, score 20, max score 265
# Completed 273 games, 3587 rewards, 875394 frames, score 10, max score 265
# Completed 274 games, 3595 rewards, 877255 frames, score 7, max score 265
# Completed 275 games, 3614 rewards, 883143 frames, score 18, max score 265
# Completed 276 games, 3657 rewards, 889882 frames, score 42, max score 265
# Completed 277 games, 3678 rewards, 893386 frames, score 20, max score 265
# Completed 278 games, 3698 rewards, 899561 frames, score 19, max score 265
# Completed 279 games, 3722 rewards, 906694 frames, score 23, max score 265
# Completed 280 games, 3753 rewards, 912549 frames, score 30, max score 265
# Completed 281 games, 3782 rewards, 916941 frames, score 28, max score 265
# Completed 282 games, 3818 rewards, 926076 frames, score 35, max score 265
# Completed 283 games, 3826 rewards, 927384 frames, score 7, max score 265
# Completed 284 games, 3840 rewards, 930800 frames, score 13, max score 265
# Completed 285 games, 3855 rewards, 933395 frames, score 14, max score 265
# Completed 286 games, 3862 rewards, 935290 frames, score 6, max score 265
# Completed 287 games, 3889 rewards, 947898 frames, score 26, max score 265
# Completed 288 games, 3897 rewards, 949379 frames, score 7, max score 265
# Completed 289 games, 3910 rewards, 952121 frames, score 12, max score 265
# Completed 290 games, 3918 rewards, 953742 frames, score 7, max score 265
# Completed 291 games, 3947 rewards, 958447 frames, score 28, max score 265
# Completed 292 games, 3952 rewards, 959262 frames, score 4, max score 265
# Completed 293 games, 3981 rewards, 964148 frames, score 28, max score 265
# Completed 294 games, 3991 rewards, 965928 frames, score 9, max score 265
# Completed 295 games, 4010 rewards, 968799 frames, score 18, max score 265
# Completed 296 games, 4020 rewards, 970301 frames, score 9, max score 265
# Completed 297 games, 4054 rewards, 975357 frames, score 33, max score 265
# Completed 298 games, 4072 rewards, 979050 frames, score 17, max score 265
# Completed 299 games, 4116 rewards, 987423 frames, score 43, max score 265
# Completed 300 games, 4183 rewards, 1002317 frames, score 66, max score 265
# Completed 301 games, 4209 rewards, 1006247 frames, score 25, max score 265
# Completed 302 games, 4225 rewards, 1008801 frames, score 15, max score 265
# Completed 303 games, 4266 rewards, 1015200 frames, score 40, max score 265
# Completed 304 games, 4300 rewards, 1020766 frames, score 33, max score 265
# Completed 305 games, 4356 rewards, 1034852 frames, score 55, max score 265
# Completed 306 games, 4376 rewards, 1038958 frames, score 19, max score 265
# Completed 307 games, 4388 rewards, 1041286 frames, score 11, max score 265
# Completed 308 games, 4430 rewards, 1052372 frames, score 41, max score 265
# Completed 309 games, 4445 rewards, 1054809 frames, score 14, max score 265
# Completed 310 games, 4484 rewards, 1070787 frames, score 38, max score 265
# Completed 311 games, 4532 rewards, 1078266 frames, score 47, max score 265
# Completed 312 games, 4548 rewards, 1080667 frames, score 15, max score 265
# Completed 313 games, 4564 rewards, 1084832 frames, score 15, max score 265
# Completed 314 games, 4581 rewards, 1088080 frames, score 16, max score 265
# Completed 315 games, 4620 rewards, 1094623 frames, score 38, max score 265
# Completed 316 games, 4628 rewards, 1096056 frames, score 7, max score 265
# Completed 317 games, 4650 rewards, 1100585 frames, score 21, max score 265
# Completed 318 games, 4686 rewards, 1110289 frames, score 35, max score 265
# Completed 319 games, 4695 rewards, 1112043 frames, score 8, max score 265
# Completed 320 games, 4709 rewards, 1114315 frames, score 13, max score 265
# Completed 321 games, 4717 rewards, 1116170 frames, score 7, max score 265
# Completed 322 games, 4802 rewards, 1132771 frames, score 84, max score 265
# Completed 323 games, 4835 rewards, 1139611 frames, score 32, max score 265
# Completed 324 games, 4873 rewards, 1145826 frames, score 37, max score 265
# Completed 325 games, 4894 rewards, 1151237 frames, score 20, max score 265
# Completed 326 games, 5010 rewards, 1178437 frames, score 115, max score 265
# Completed 327 games, 5140 rewards, 1198699 frames, score 129, max score 265
# Completed 328 games, 5293 rewards, 1234054 frames, score 152, max score 265
# Completed 329 games, 5532 rewards, 1285168 frames, score 238, max score 265
# Completed 330 games, 5614 rewards, 1299567 frames, score 81, max score 265
# Completed 331 games, 5660 rewards, 1306394 frames, score 45, max score 265
# Completed 332 games, 5811 rewards, 1329374 frames, score 150, max score 265
# Completed 333 games, 5931 rewards, 1358591 frames, score 119, max score 265
# Completed 334 games, 5934 rewards, 1359082 frames, score 2, max score 265
# Completed 335 games, 6107 rewards, 1386506 frames, score 172, max score 265
# Completed 336 games, 6150 rewards, 1393616 frames, score 42, max score 265
# Completed 337 games, 6163 rewards, 1395642 frames, score 12, max score 265
# Completed 338 games, 6179 rewards, 1398637 frames, score 15, max score 265
# Completed 339 games, 6195 rewards, 1402533 frames, score 15, max score 265
# Completed 340 games, 6206 rewards, 1404781 frames, score 10, max score 265
# Completed 341 games, 6262 rewards, 1413346 frames, score 55, max score 265
# Completed 342 games, 6402 rewards, 1441525 frames, score 139, max score 265
# Completed 343 games, 6410 rewards, 1443337 frames, score 7, max score 265
# Completed 344 games, 6508 rewards, 1457726 frames, score 97, max score 265
# Completed 345 games, 6521 rewards, 1459672 frames, score 12, max score 265
# Completed 346 games, 6837 rewards, 1514639 frames, score 315, max score 315
# Completed 347 games, 6951 rewards, 1535611 frames, score 113, max score 315
# Completed 348 games, 7233 rewards, 1590417 frames, score 281, max score 315
# Completed 349 games, 7279 rewards, 1600578 frames, score 45, max score 315
# Completed 350 games, 7300 rewards, 1605212 frames, score 20, max score 315
# Completed 351 games, 7350 rewards, 1615458 frames, score 49, max score 315
# Completed 352 games, 7420 rewards, 1629799 frames, score 69, max score 315
# Completed 353 games, 7445 rewards, 1633759 frames, score 24, max score 315
# Completed 354 games, 7452 rewards, 1634934 frames, score 6, max score 315
# Completed 355 games, 7541 rewards, 1649183 frames, score 88, max score 315
# Completed 356 games, 7611 rewards, 1662255 frames, score 69, max score 315
# Completed 357 games, 7619 rewards, 1663554 frames, score 7, max score 315
# Completed 358 games, 8020 rewards, 1726515 frames, score 400, max score 400
# Completed 359 games, 8039 rewards, 1732826 frames, score 18, max score 400
# Completed 360 games, 8053 rewards, 1735626 frames, score 13, max score 400
# Completed 361 games, 8080 rewards, 1741405 frames, score 26, max score 400
# Completed 362 games, 8147 rewards, 1752008 frames, score 66, max score 400
# Completed 363 games, 8333 rewards, 1786780 frames, score 185, max score 400
# Completed 364 games, 8398 rewards, 1796501 frames, score 64, max score 400
# Completed 365 games, 8404 rewards, 1797817 frames, score 5, max score 400
# Completed 366 games, 8978 rewards, 1897822 frames, score 573, max score 573
# Completed 367 games, 9025 rewards, 1906150 frames, score 46, max score 573
# Completed 368 games, 9049 rewards, 1912282 frames, score 23, max score 573
# Completed 369 games, 9098 rewards, 1922486 frames, score 48, max score 573
# Completed 370 games, 9250 rewards, 1949993 frames, score 151, max score 573
# Completed 371 games, 9269 rewards, 1958273 frames, score 18, max score 573
# Completed 372 games, 9284 rewards, 1960891 frames, score 14, max score 573
# Completed 373 games, 9412 rewards, 1980484 frames, score 127, max score 573
# Completed 374 games, 9438 rewards, 1984691 frames, score 25, max score 573
# Completed 375 games, 9593 rewards, 2011722 frames, score 154, max score 573
# Completed 376 games, 9634 rewards, 2020463 frames, score 40, max score 573
# Completed 377 games, 9637 rewards, 2021027 frames, score 2, max score 573
# Completed 378 games, 9825 rewards, 2052983 frames, score 187, max score 573
# Completed 379 games, 9869 rewards, 2064442 frames, score 43, max score 573
# Completed 380 games, 9893 rewards, 2068010 frames, score 23, max score 573
# Completed 381 games, 9917 rewards, 2074142 frames, score 23, max score 573
# Completed 382 games, 9930 rewards, 2076530 frames, score 12, max score 573
# Completed 383 games, 10000 rewards, 2088079 frames, score 69, max score 573
# Completed 384 games, 10101 rewards, 2107329 frames, score 100, max score 573
# Completed 385 games, 10123 rewards, 2110815 frames, score 21, max score 573
# Completed 386 games, 10131 rewards, 2112470 frames, score 7, max score 573
# Completed 387 games, 10229 rewards, 2129982 frames, score 97, max score 573
# Completed 388 games, 10274 rewards, 2137144 frames, score 44, max score 573
# Completed 389 games, 10367 rewards, 2153319 frames, score 92, max score 573
# Completed 390 games, 10386 rewards, 2158240 frames, score 18, max score 573
# Completed 391 games, 10452 rewards, 2169807 frames, score 65, max score 573
# Completed 392 games, 10720 rewards, 2216163 frames, score 267, max score 573
# Completed 393 games, 10766 rewards, 2223827 frames, score 45, max score 573
# Completed 394 games, 10831 rewards, 2234320 frames, score 64, max score 573
# Completed 395 games, 10963 rewards, 2254219 frames, score 131, max score 573
# Completed 396 games, 11039 rewards, 2265520 frames, score 75, max score 573
# Completed 397 games, 11056 rewards, 2272285 frames, score 16, max score 573
# Completed 398 games, 11104 rewards, 2286749 frames, score 47, max score 573
# Completed 399 games, 11146 rewards, 2294873 frames, score 41, max score 573
# Completed 400 games, 11152 rewards, 2296474 frames, score 5, max score 573
# Completed 401 games, 11192 rewards, 2302470 frames, score 39, max score 573
# Completed 402 games, 11205 rewards, 2306956 frames, score 12, max score 573
# Completed 403 games, 11227 rewards, 2311592 frames, score 21, max score 573
# Completed 404 games, 11233 rewards, 2312670 frames, score 5, max score 573
# Completed 405 games, 11246 rewards, 2317396 frames, score 12, max score 573
# Completed 406 games, 11250 rewards, 2318090 frames, score 3, max score 573
# Completed 407 games, 11288 rewards, 2324524 frames, score 37, max score 573
# Completed 408 games, 11311 rewards, 2329819 frames, score 22, max score 573
# Completed 409 games, 11356 rewards, 2337579 frames, score 44, max score 573
# Completed 410 games, 11444 rewards, 2351419 frames, score 87, max score 573
# Completed 411 games, 11578 rewards, 2377664 frames, score 133, max score 573
# Completed 412 games, 11630 rewards, 2386617 frames, score 51, max score 573
# Completed 413 games, 11678 rewards, 2394189 frames, score 47, max score 573
# Completed 414 games, 11784 rewards, 2410873 frames, score 105, max score 573
# Completed 415 games, 11866 rewards, 2426084 frames, score 81, max score 573
# Completed 416 games, 11902 rewards, 2432334 frames, score 35, max score 573
# Completed 417 games, 11935 rewards, 2440046 frames, score 32, max score 573
# Completed 418 games, 12028 rewards, 2455914 frames, score 92, max score 573
# Completed 419 games, 12036 rewards, 2457167 frames, score 7, max score 573
# Completed 420 games, 12050 rewards, 2460641 frames, score 13, max score 573
# Completed 421 games, 12057 rewards, 2462239 frames, score 6, max score 573
# Completed 422 games, 12497 rewards, 2532824 frames, score 439, max score 573
# Completed 423 games, 12524 rewards, 2539961 frames, score 26, max score 573
# Completed 424 games, 12552 rewards, 2545277 frames, score 27, max score 573
# Completed 425 games, 12722 rewards, 2573957 frames, score 169, max score 573
# Completed 426 games, 12762 rewards, 2580223 frames, score 39, max score 573
# Completed 427 games, 12769 rewards, 2582123 frames, score 6, max score 573
# Completed 428 games, 12779 rewards, 2584083 frames, score 9, max score 573
# Completed 429 games, 12828 rewards, 2593112 frames, score 48, max score 573
# Completed 430 games, 12980 rewards, 2621426 frames, score 151, max score 573
# Completed 431 games, 13057 rewards, 2634680 frames, score 76, max score 573
# Completed 432 games, 13079 rewards, 2638055 frames, score 21, max score 573
# Completed 433 games, 13105 rewards, 2642603 frames, score 25, max score 573
# Completed 434 games, 13115 rewards, 2644308 frames, score 9, max score 573
# Completed 435 games, 13168 rewards, 2652432 frames, score 52, max score 573
# Completed 436 games, 13261 rewards, 2667340 frames, score 92, max score 573
# Completed 437 games, 13349 rewards, 2685261 frames, score 87, max score 573
# Completed 438 games, 13378 rewards, 2689870 frames, score 28, max score 573
# Completed 439 games, 13385 rewards, 2691544 frames, score 6, max score 573
# Completed 440 games, 13437 rewards, 2699842 frames, score 51, max score 573
# Completed 441 games, 13521 rewards, 2717225 frames, score 83, max score 573
# Completed 442 games, 13545 rewards, 2733762 frames, score 23, max score 573
# Completed 443 games, 13549 rewards, 2734429 frames, score 3, max score 573
# Completed 444 games, 13653 rewards, 2751770 frames, score 103, max score 573
# Completed 445 games, 13694 rewards, 2758889 frames, score 40, max score 573
# Completed 446 games, 13718 rewards, 2763242 frames, score 23, max score 573
# Completed 447 games, 13734 rewards, 2766202 frames, score 15, max score 573
# Completed 448 games, 13789 rewards, 2774992 frames, score 54, max score 573
# Completed 449 games, 13823 rewards, 2783671 frames, score 33, max score 573
# Completed 450 games, 13917 rewards, 2798462 frames, score 93, max score 573
# Completed 451 games, 13929 rewards, 2800708 frames, score 11, max score 573
# Completed 452 games, 13971 rewards, 2811992 frames, score 41, max score 573
# Completed 453 games, 14010 rewards, 2817852 frames, score 38, max score 573
# Completed 454 games, 14043 rewards, 2825836 frames, score 32, max score 573
# Completed 455 games, 14054 rewards, 2830150 frames, score 10, max score 573
# Completed 456 games, 14124 rewards, 2841228 frames, score 69, max score 573
# Completed 457 games, 14189 rewards, 2851225 frames, score 64, max score 573
# Completed 458 games, 14198 rewards, 2852852 frames, score 8, max score 573
# Completed 459 games, 14236 rewards, 2859258 frames, score 37, max score 573
# Completed 460 games, 14248 rewards, 2862029 frames, score 11, max score 573
# Completed 461 games, 14519 rewards, 2905117 frames, score 270, max score 573
# Completed 462 games, 14582 rewards, 2915337 frames, score 62, max score 573
# Completed 463 games, 14615 rewards, 2929089 frames, score 32, max score 573
# Completed 464 games, 14655 rewards, 2935653 frames, score 39, max score 573
# Completed 465 games, 14697 rewards, 2942219 frames, score 41, max score 573
# Completed 466 games, 14757 rewards, 2961192 frames, score 59, max score 573
# Completed 467 games, 14774 rewards, 2963852 frames, score 16, max score 573
# Completed 468 games, 14805 rewards, 2969220 frames, score 30, max score 573
# Completed 469 games, 14821 rewards, 2971872 frames, score 15, max score 573
# Completed 470 games, 14856 rewards, 2978205 frames, score 34, max score 573
# Completed 471 games, 14880 rewards, 2981988 frames, score 23, max score 573
# Completed 472 games, 15084 rewards, 3022279 frames, score 203, max score 573
# Completed 473 games, 15097 rewards, 3024496 frames, score 12, max score 573
# Completed 474 games, 15145 rewards, 3032383 frames, score 47, max score 573
# Completed 475 games, 15165 rewards, 3035673 frames, score 19, max score 573
# Completed 476 games, 15173 rewards, 3037933 frames, score 7, max score 573
# Completed 477 games, 15193 rewards, 3041449 frames, score 19, max score 573
# Completed 478 games, 15221 rewards, 3046090 frames, score 27, max score 573
# Completed 479 games, 15271 rewards, 3054100 frames, score 49, max score 573
# Completed 480 games, 15276 rewards, 3055332 frames, score 4, max score 573
# Completed 481 games, 15300 rewards, 3060019 frames, score 23, max score 573
# Completed 482 games, 15357 rewards, 3070067 frames, score 56, max score 573
# Completed 483 games, 15369 rewards, 3071853 frames, score 11, max score 573
# Completed 484 games, 15454 rewards, 3094581 frames, score 84, max score 573
# Completed 485 games, 15547 rewards, 3108688 frames, score 92, max score 573
# Completed 486 games, 15609 rewards, 3118039 frames, score 61, max score 573
# Completed 487 games, 15791 rewards, 3147722 frames, score 181, max score 573
# Completed 488 games, 15853 rewards, 3162868 frames, score 61, max score 573
# Completed 489 games, 15868 rewards, 3165346 frames, score 14, max score 573
# Completed 490 games, 15986 rewards, 3184815 frames, score 117, max score 573
# Completed 491 games, 16001 rewards, 3187230 frames, score 14, max score 573
# Completed 492 games, 16152 rewards, 3210292 frames, score 150, max score 573
# Completed 493 games, 16160 rewards, 3212269 frames, score 7, max score 573
# Completed 494 games, 16181 rewards, 3215392 frames, score 20, max score 573
# Completed 495 games, 16259 rewards, 3227401 frames, score 77, max score 573
# Completed 496 games, 16270 rewards, 3229299 frames, score 10, max score 573
# Completed 497 games, 16324 rewards, 3237128 frames, score 53, max score 573
# Completed 498 games, 16346 rewards, 3240749 frames, score 21, max score 573
# Completed 499 games, 16360 rewards, 3243481 frames, score 13, max score 573
# Completed 500 games, 16400 rewards, 3249865 frames, score 39, max score 573
# Completed 501 games, 16537 rewards, 3274362 frames, score 136, max score 573
# Completed 502 games, 16580 rewards, 3282625 frames, score 42, max score 573
# Completed 503 games, 16581 rewards, 3282879 frames, score 0, max score 573
# Completed 504 games, 16610 rewards, 3294075 frames, score 28, max score 573
# Completed 505 games, 16646 rewards, 3301037 frames, score 35, max score 573
# Completed 506 games, 16664 rewards, 3303830 frames, score 17, max score 573
# Completed 507 games, 16734 rewards, 3314451 frames, score 69, max score 573
# Completed 508 games, 16752 rewards, 3317791 frames, score 17, max score 573
# Completed 509 games, 16768 rewards, 3323396 frames, score 15, max score 573
# Completed 510 games, 16862 rewards, 3338148 frames, score 93, max score 573
# Completed 511 games, 16942 rewards, 3350912 frames, score 79, max score 573
# Completed 512 games, 17018 rewards, 3367604 frames, score 75, max score 573
# Completed 513 games, 17050 rewards, 3373080 frames, score 31, max score 573
# Completed 514 games, 17081 rewards, 3378746 frames, score 30, max score 573
# Completed 515 games, 17093 rewards, 3380773 frames, score 11, max score 573
# Completed 516 games, 17125 rewards, 3386674 frames, score 31, max score 573
# Completed 517 games, 17132 rewards, 3388078 frames, score 6, max score 573
# Completed 518 games, 17152 rewards, 3391741 frames, score 19, max score 573
# Completed 519 games, 17160 rewards, 3394674 frames, score 7, max score 573
# Completed 520 games, 17169 rewards, 3396298 frames, score 8, max score 573
# Completed 521 games, 17170 rewards, 3396552 frames, score 0, max score 573
# Completed 522 games, 17175 rewards, 3397459 frames, score 4, max score 573
# Completed 523 games, 17192 rewards, 3400111 frames, score 16, max score 573
# Completed 524 games, 17245 rewards, 3412879 frames, score 52, max score 573
# Completed 525 games, 17268 rewards, 3420984 frames, score 22, max score 573
# Completed 526 games, 17273 rewards, 3422900 frames, score 4, max score 573
# Completed 527 games, 17280 rewards, 3423963 frames, score 6, max score 573
# Completed 528 games, 17283 rewards, 3424517 frames, score 2, max score 573
# Completed 529 games, 17306 rewards, 3427938 frames, score 22, max score 573
# Completed 530 games, 17328 rewards, 3434136 frames, score 21, max score 573
# Completed 531 games, 17339 rewards, 3436008 frames, score 10, max score 573
# Completed 532 games, 17362 rewards, 3439980 frames, score 22, max score 573
# Completed 533 games, 17368 rewards, 3445050 frames, score 5, max score 573
# Completed 534 games, 17382 rewards, 3447880 frames, score 13, max score 573
# Completed 535 games, 17388 rewards, 3448977 frames, score 5, max score 573
# Completed 536 games, 17435 rewards, 3457366 frames, score 46, max score 573
# Completed 537 games, 17439 rewards, 3458035 frames, score 3, max score 573
# Completed 538 games, 17461 rewards, 3465462 frames, score 21, max score 573
# Completed 539 games, 17465 rewards, 3466178 frames, score 3, max score 573
# Completed 540 games, 17495 rewards, 3471316 frames, score 29, max score 573
# Completed 541 games, 17501 rewards, 3472529 frames, score 5, max score 573
# Completed 542 games, 17514 rewards, 3474545 frames, score 12, max score 573
# Completed 543 games, 17524 rewards, 3478782 frames, score 9, max score 573
# Completed 544 games, 17528 rewards, 3479529 frames, score 3, max score 573
# Completed 545 games, 17537 rewards, 3481818 frames, score 8, max score 573
# Completed 546 games, 17548 rewards, 3484196 frames, score 10, max score 573
# Completed 547 games, 17570 rewards, 3488753 frames, score 21, max score 573
# Completed 548 games, 17573 rewards, 3489531 frames, score 2, max score 573
# Completed 549 games, 17820 rewards, 3525835 frames, score 246, max score 573
# Completed 550 games, 17827 rewards, 3527585 frames, score 6, max score 573
# Completed 551 games, 17842 rewards, 3536272 frames, score 14, max score 573
# Completed 552 games, 17872 rewards, 3542604 frames, score 29, max score 573
# Completed 553 games, 17921 rewards, 3550569 frames, score 48, max score 573
# Completed 554 games, 17935 rewards, 3552837 frames, score 13, max score 573
# Completed 555 games, 17944 rewards, 3555870 frames, score 8, max score 573
# Completed 556 games, 17954 rewards, 3557685 frames, score 9, max score 573
# Completed 557 games, 18084 rewards, 3577264 frames, score 129, max score 573
# Completed 558 games, 18096 rewards, 3579127 frames, score 11, max score 573
# Completed 559 games, 18131 rewards, 3591607 frames, score 34, max score 573
# Completed 560 games, 18166 rewards, 3597603 frames, score 34, max score 573
# Completed 561 games, 18209 rewards, 3604777 frames, score 42, max score 573
# Completed 562 games, 18214 rewards, 3605627 frames, score 4, max score 573
# Completed 563 games, 18218 rewards, 3606310 frames, score 3, max score 573
# Completed 564 games, 18250 rewards, 3612681 frames, score 31, max score 573
# Completed 565 games, 18252 rewards, 3613144 frames, score 1, max score 573
# Completed 566 games, 18267 rewards, 3616016 frames, score 14, max score 573
# Completed 567 games, 18330 rewards, 3631194 frames, score 62, max score 573
# Completed 568 games, 18336 rewards, 3632637 frames, score 5, max score 573
# Completed 569 games, 18345 rewards, 3634604 frames, score 8, max score 573
# Completed 570 games, 18360 rewards, 3637300 frames, score 14, max score 573
# Completed 571 games, 18385 rewards, 3641889 frames, score 24, max score 573
# Completed 572 games, 18393 rewards, 3643207 frames, score 7, max score 573
# Completed 573 games, 18406 rewards, 3647277 frames, score 12, max score 573
# Completed 574 games, 18410 rewards, 3648021 frames, score 3, max score 573
# Completed 575 games, 18415 rewards, 3649353 frames, score 4, max score 573
# Completed 576 games, 18424 rewards, 3651320 frames, score 8, max score 573
# Completed 577 games, 18442 rewards, 3654050 frames, score 17, max score 573
# Completed 578 games, 18458 rewards, 3656845 frames, score 15, max score 573
# Completed 579 games, 18475 rewards, 3662215 frames, score 16, max score 573
# Completed 580 games, 18479 rewards, 3665067 frames, score 3, max score 573
# Completed 581 games, 18494 rewards, 3667369 frames, score 14, max score 573
# Completed 582 games, 18534 rewards, 3674390 frames, score 39, max score 573
# Completed 583 games, 18557 rewards, 3678911 frames, score 22, max score 573
# Completed 584 games, 18563 rewards, 3679986 frames, score 5, max score 573
# Completed 585 games, 18577 rewards, 3683191 frames, score 13, max score 573
# Completed 586 games, 18580 rewards, 3683890 frames, score 2, max score 573
# Completed 587 games, 18604 rewards, 3687589 frames, score 23, max score 573
# Completed 588 games, 18606 rewards, 3688508 frames, score 1, max score 573
# Completed 589 games, 18630 rewards, 3692992 frames, score 23, max score 573
# Completed 590 games, 18632 rewards, 3693543 frames, score 1, max score 573
# Completed 591 games, 18647 rewards, 3696058 frames, score 14, max score 573
# Completed 592 games, 18652 rewards, 3696933 frames, score 4, max score 573
# Completed 593 games, 18662 rewards, 3698851 frames, score 9, max score 573
# Completed 594 games, 18664 rewards, 3699513 frames, score 1, max score 573
# Completed 595 games, 18669 rewards, 3700347 frames, score 4, max score 573
# Completed 596 games, 18682 rewards, 3702518 frames, score 12, max score 573
# Completed 597 games, 18692 rewards, 3704514 frames, score 9, max score 573
# Completed 598 games, 18731 rewards, 3713662 frames, score 38, max score 573
# Completed 599 games, 18744 rewards, 3715813 frames, score 12, max score 573
# Completed 600 games, 18794 rewards, 3725518 frames, score 49, max score 573
# Completed 601 games, 18818 rewards, 3729793 frames, score 23, max score 573
# Completed 602 games, 18843 rewards, 3733860 frames, score 24, max score 573
# Completed 603 games, 18853 rewards, 3735572 frames, score 9, max score 573
# Completed 604 games, 18855 rewards, 3735964 frames, score 1, max score 573
# Completed 605 games, 18858 rewards, 3736656 frames, score 2, max score 573
# Completed 606 games, 18897 rewards, 3743675 frames, score 38, max score 573
# Completed 607 games, 18922 rewards, 3747380 frames, score 24, max score 573
# Completed 608 games, 18928 rewards, 3748512 frames, score 5, max score 573
# Completed 609 games, 18946 rewards, 3751339 frames, score 17, max score 573
# Completed 610 games, 18948 rewards, 3751941 frames, score 1, max score 573
# Completed 611 games, 18964 rewards, 3754464 frames, score 15, max score 573
# Completed 612 games, 18986 rewards, 3766201 frames, score 21, max score 573
# Completed 613 games, 19013 rewards, 3772670 frames, score 26, max score 573
# Completed 614 games, 19018 rewards, 3773601 frames, score 4, max score 573
# Completed 615 games, 19028 rewards, 3775853 frames, score 9, max score 573
# Completed 616 games, 19048 rewards, 3779315 frames, score 19, max score 573
# Completed 617 games, 19053 rewards, 3780309 frames, score 4, max score 573
# Completed 618 games, 19068 rewards, 3782970 frames, score 14, max score 573
# Completed 619 games, 19079 rewards, 3784869 frames, score 10, max score 573
# Completed 620 games, 19085 rewards, 3786070 frames, score 5, max score 573
# Completed 621 games, 19106 rewards, 3791521 frames, score 20, max score 573
# Completed 622 games, 19115 rewards, 3793141 frames, score 8, max score 573
# Completed 623 games, 19120 rewards, 3793948 frames, score 4, max score 573
# Completed 624 games, 19130 rewards, 3795604 frames, score 9, max score 573
# Completed 625 games, 19191 rewards, 3806743 frames, score 60, max score 573
# Completed 626 games, 19207 rewards, 3809598 frames, score 15, max score 573
# Completed 627 games, 19223 rewards, 3818560 frames, score 15, max score 573
# Completed 628 games, 19246 rewards, 3822555 frames, score 22, max score 573
# Completed 629 games, 19255 rewards, 3824138 frames, score 8, max score 573
# Completed 630 games, 19282 rewards, 3828487 frames, score 26, max score 573
# Completed 631 games, 19307 rewards, 3833309 frames, score 24, max score 573
# Completed 632 games, 19335 rewards, 3838545 frames, score 27, max score 573
# Completed 633 games, 19345 rewards, 3840420 frames, score 9, max score 573
# Completed 634 games, 19357 rewards, 3842377 frames, score 11, max score 573
# Completed 635 games, 19365 rewards, 3844203 frames, score 7, max score 573
# Completed 636 games, 19374 rewards, 3845678 frames, score 8, max score 573
# Completed 637 games, 19401 rewards, 3849754 frames, score 26, max score 573
# Completed 638 games, 19420 rewards, 3852711 frames, score 18, max score 573
# Completed 639 games, 19452 rewards, 3858935 frames, score 31, max score 573
# Completed 640 games, 19462 rewards, 3860446 frames, score 9, max score 573
# Completed 641 games, 19471 rewards, 3862084 frames, score 8, max score 573
# Completed 642 games, 19503 rewards, 3867139 frames, score 31, max score 573
# Completed 643 games, 19521 rewards, 3869914 frames, score 17, max score 573
# Completed 644 games, 19540 rewards, 3882175 frames, score 18, max score 573
# Completed 645 games, 19554 rewards, 3884247 frames, score 13, max score 573
# Completed 646 games, 19630 rewards, 3908180 frames, score 75, max score 573
# ...
# Completed 4799 games, 139129 rewards, 28839126 frames, score 98, max score 846
# Completed 4800 games, 139315 rewards, 28867371 frames, score 185, max score 846
# Completed 4801 games, 139752 rewards, 28945819 frames, score 436, max score 846
# Completed 4802 games, 139776 rewards, 28949995 frames, score 23, max score 846
# Completed 4803 games, 139784 rewards, 28951201 frames, score 7, max score 846
# Completed 4804 games, 139844 rewards, 28966257 frames, score 59, max score 846
# Completed 4805 games, 139869 rewards, 28970669 frames, score 24, max score 846
# Completed 4806 games, 139977 rewards, 28991113 frames, score 107, max score 846
# Completed 4807 games, 140093 rewards, 29016358 frames, score 115, max score 846
# Completed 4808 games, 140429 rewards, 29068533 frames, score 335, max score 846
# Completed 4809 games, 140439 rewards, 29070523 frames, score 9, max score 846
# Completed 4810 games, 140466 rewards, 29075991 frames, score 26, max score 846
# Completed 4811 games, 140499 rewards, 29081857 frames, score 32, max score 846
# Completed 4812 games, 140604 rewards, 29110988 frames, score 104, max score 846
# Completed 4813 games, 140644 rewards, 29117512 frames, score 39, max score 846
# Completed 4814 games, 140646 rewards, 29118174 frames, score 1, max score 846
# Completed 4815 games, 140650 rewards, 29119389 frames, score 3, max score 846
# Completed 4816 games, 140654 rewards, 29120105 frames, score 3, max score 846
# Completed 4817 games, 140672 rewards, 29123287 frames, score 17, max score 846
# Completed 4818 games, 140689 rewards, 29126568 frames, score 16, max score 846
# Completed 4819 games, 140943 rewards, 29166407 frames, score 253, max score 846
# Completed 4820 games, 141216 rewards, 29215673 frames, score 272, max score 846
# Completed 4821 games, 141290 rewards, 29231878 frames, score 73, max score 846
# Completed 4822 games, 141701 rewards, 29311090 frames, score 410, max score 846
# Completed 4823 games, 141843 rewards, 29332944 frames, score 141, max score 846
# Completed 4824 games, 141951 rewards, 29349811 frames, score 107, max score 846
# Completed 4825 games, 142402 rewards, 29423416 frames, score 450, max score 846
# Completed 4826 games, 142446 rewards, 29430560 frames, score 43, max score 846
# Completed 4827 games, 142482 rewards, 29436385 frames, score 35, max score 846
# Completed 4828 games, 142488 rewards, 29438621 frames, score 5, max score 846
# Completed 4829 games, 142612 rewards, 29457795 frames, score 123, max score 846
# Completed 4830 games, 142644 rewards, 29463058 frames, score 31, max score 846
# Completed 4831 games, 142683 rewards, 29469328 frames, score 38, max score 846
# Completed 4832 games, 142737 rewards, 29479748 frames, score 53, max score 846
# Completed 4833 games, 142782 rewards, 29490346 frames, score 44, max score 846
# Completed 4834 games, 142960 rewards, 29517909 frames, score 177, max score 846
# Completed 4835 games, 143014 rewards, 29529344 frames, score 53, max score 846
# Completed 4836 games, 143064 rewards, 29537650 frames, score 49, max score 846
# Completed 4837 games, 143132 rewards, 29547985 frames, score 67, max score 846
# Completed 4838 games, 143173 rewards, 29554189 frames, score 40, max score 846
# Completed 4839 games, 143321 rewards, 29578131 frames, score 147, max score 846
# Completed 4840 games, 143354 rewards, 29583203 frames, score 32, max score 846
# Completed 4841 games, 143398 rewards, 29590302 frames, score 43, max score 846
# Completed 4842 games, 143460 rewards, 29600174 frames, score 61, max score 846
# Completed 4843 games, 143628 rewards, 29625377 frames, score 167, max score 846
# Completed 4844 games, 143637 rewards, 29626780 frames, score 8, max score 846
# Completed 4845 games, 143645 rewards, 29630372 frames, score 7, max score 846
# Completed 4846 games, 143818 rewards, 29657847 frames, score 172, max score 846
# Completed 4847 games, 143862 rewards, 29666021 frames, score 43, max score 846
# Completed 4848 games, 143904 rewards, 29673709 frames, score 41, max score 846
# Completed 4849 games, 143920 rewards, 29676443 frames, score 15, max score 846
# Completed 4850 games, 144048 rewards, 29703139 frames, score 127, max score 846
# Completed 4851 games, 144208 rewards, 29727420 frames, score 159, max score 846
# Completed 4852 games, 144295 rewards, 29741973 frames, score 86, max score 846
# Completed 4853 games, 144539 rewards, 29784382 frames, score 243, max score 846
# Completed 4854 games, 144576 rewards, 29790150 frames, score 36, max score 846
# Completed 4855 games, 144601 rewards, 29797144 frames, score 24, max score 846
# Completed 4856 games, 144603 rewards, 29797607 frames, score 1, max score 846
# Completed 4857 games, 144615 rewards, 29801482 frames, score 11, max score 846
# Completed 4858 games, 144627 rewards, 29803711 frames, score 11, max score 846
# Completed 4859 games, 144632 rewards, 29806001 frames, score 4, max score 846
# Completed 4860 games, 144658 rewards, 29809837 frames, score 25, max score 846
# Completed 4861 games, 144726 rewards, 29830709 frames, score 67, max score 846
# Completed 4862 games, 144773 rewards, 29839644 frames, score 46, max score 846
# Completed 4863 games, 144872 rewards, 29864672 frames, score 98, max score 846
# Completed 4864 games, 144970 rewards, 29889037 frames, score 97, max score 846
# Completed 4865 games, 145041 rewards, 29903828 frames, score 70, max score 846
# Completed 4866 games, 145084 rewards, 29912719 frames, score 42, max score 846
# Completed 4867 games, 145145 rewards, 29923373 frames, score 60, max score 846
# Completed 4868 games, 145160 rewards, 29931478 frames, score 14, max score 846
# Completed 4869 games, 145174 rewards, 29936937 frames, score 13, max score 846
# Completed 4870 games, 145181 rewards, 29938549 frames, score 6, max score 846
# Completed 4871 games, 145191 rewards, 29940356 frames, score 9, max score 846
# Completed 4872 games, 145200 rewards, 29942341 frames, score 8, max score 846
# Completed 4873 games, 145210 rewards, 29943913 frames, score 9, max score 846
# Completed 4874 games, 145225 rewards, 29946381 frames, score 14, max score 846
# Completed 4875 games, 145295 rewards, 29958443 frames, score 69, max score 846
# Completed 4876 games, 145469 rewards, 29998083 frames, score 173, max score 846
# Completed 4877 games, 145532 rewards, 30009051 frames, score 62, max score 846
# Completed 4878 games, 145544 rewards, 30011224 frames, score 11, max score 846
# Completed 4879 games, 145570 rewards, 30015743 frames, score 25, max score 846
# Completed 4880 games, 145620 rewards, 30024152 frames, score 49, max score 846
# Completed 4881 games, 145702 rewards, 30038382 frames, score 81, max score 846
# Completed 4882 games, 145722 rewards, 30044986 frames, score 19, max score 846
# Completed 4883 games, 145745 rewards, 30050017 frames, score 22, max score 846
# Completed 4884 games, 145855 rewards, 30067325 frames, score 109, max score 846
# Completed 4885 games, 145866 rewards, 30074243 frames, score 10, max score 846
# Completed 4886 games, 145915 rewards, 30081881 frames, score 48, max score 846
# Completed 4887 games, 145929 rewards, 30087483 frames, score 13, max score 846
# Completed 4888 games, 145961 rewards, 30097354 frames, score 31, max score 846
# Completed 4889 games, 146020 rewards, 30106583 frames, score 58, max score 846
# Completed 4890 games, 146032 rewards, 30108757 frames, score 11, max score 846
# Completed 4891 games, 146071 rewards, 30114827 frames, score 38, max score 846
# Completed 4892 games, 146088 rewards, 30118382 frames, score 16, max score 846
# Completed 4893 games, 146132 rewards, 30128949 frames, score 43, max score 846
# Completed 4894 games, 146134 rewards, 30129461 frames, score 1, max score 846
# Completed 4895 games, 146148 rewards, 30131961 frames, score 13, max score 846
# Completed 4896 games, 146194 rewards, 30143703 frames, score 45, max score 846
# Completed 4897 games, 146203 rewards, 30145607 frames, score 8, max score 846
# Completed 4898 games, 146215 rewards, 30148594 frames, score 11, max score 846
# Completed 4899 games, 146219 rewards, 30149431 frames, score 3, max score 846
# Completed 4900 games, 146230 rewards, 30151188 frames, score 10, max score 846
# Completed 4901 games, 146247 rewards, 30154853 frames, score 16, max score 846
# Completed 4902 games, 146250 rewards, 30155454 frames, score 2, max score 846
# Completed 4903 games, 146258 rewards, 30156963 frames, score 7, max score 846
# Completed 4904 games, 146288 rewards, 30161813 frames, score 29, max score 846
# Completed 4905 games, 146323 rewards, 30167939 frames, score 34, max score 846
# Completed 4906 games, 146327 rewards, 30168608 frames, score 3, max score 846
# Completed 4907 games, 146343 rewards, 30170974 frames, score 15, max score 846
# Completed 4908 games, 146365 rewards, 30174383 frames, score 21, max score 846
# Completed 4909 games, 146374 rewards, 30175770 frames, score 8, max score 846
# Completed 4910 games, 146383 rewards, 30177185 frames, score 8, max score 846
# Completed 4911 games, 146401 rewards, 30180920 frames, score 17, max score 846
# Completed 4912 games, 146407 rewards, 30181982 frames, score 5, max score 846
# Completed 4913 games, 146413 rewards, 30183337 frames, score 5, max score 846
# Completed 4914 games, 146415 rewards, 30183849 frames, score 1, max score 846
# Completed 4915 games, 146426 rewards, 30187738 frames, score 10, max score 846
# Completed 4916 games, 146455 rewards, 30192692 frames, score 28, max score 846
# Completed 4917 games, 146473 rewards, 30195871 frames, score 17, max score 846
# Completed 4918 games, 146484 rewards, 30198137 frames, score 10, max score 846
# Completed 4919 games, 146533 rewards, 30205753 frames, score 48, max score 846
# Completed 4920 games, 146555 rewards, 30210581 frames, score 21, max score 846
# Completed 4921 games, 146565 rewards, 30212248 frames, score 9, max score 846
# Completed 4922 games, 146575 rewards, 30214582 frames, score 9, max score 846
# Completed 4923 games, 146580 rewards, 30215355 frames, score 4, max score 846
# Completed 4924 games, 146582 rewards, 30215945 frames, score 1, max score 846
# Completed 4925 games, 146591 rewards, 30218085 frames, score 8, max score 846
# Completed 4926 games, 146597 rewards, 30219336 frames, score 5, max score 846
# Completed 4927 games, 146616 rewards, 30226613 frames, score 18, max score 846
# Completed 4928 games, 146655 rewards, 30232934 frames, score 38, max score 846
# Completed 4929 games, 146665 rewards, 30234414 frames, score 9, max score 846
# Completed 4930 games, 146687 rewards, 30246756 frames, score 21, max score 846
# Completed 4931 games, 146731 rewards, 30253980 frames, score 43, max score 846
# Completed 4932 games, 146769 rewards, 30264983 frames, score 37, max score 846
# Completed 4933 games, 146773 rewards, 30265820 frames, score 3, max score 846
# Completed 4934 games, 146779 rewards, 30266809 frames, score 5, max score 846
# Completed 4935 games, 146782 rewards, 30267495 frames, score 2, max score 846
# Completed 4936 games, 146788 rewards, 30268787 frames, score 5, max score 846
# Completed 4937 games, 146798 rewards, 30270409 frames, score 9, max score 846
# Completed 4938 games, 146826 rewards, 30275361 frames, score 27, max score 846
# Completed 4939 games, 146850 rewards, 30282808 frames, score 23, max score 846
# Completed 4940 games, 146895 rewards, 30290535 frames, score 44, max score 846
# Completed 4941 games, 146903 rewards, 30292287 frames, score 7, max score 846
# Completed 4942 games, 146908 rewards, 30295243 frames, score 4, max score 846
# Completed 4943 games, 146911 rewards, 30296219 frames, score 2, max score 846
# Completed 4944 games, 146929 rewards, 30301956 frames, score 17, max score 846
# Completed 4945 games, 146945 rewards, 30305334 frames, score 15, max score 846
# Completed 4946 games, 146947 rewards, 30305797 frames, score 1, max score 846
# Completed 4947 games, 146956 rewards, 30307357 frames, score 8, max score 846
# Completed 4948 games, 146967 rewards, 30309028 frames, score 10, max score 846
# Completed 4949 games, 146975 rewards, 30313812 frames, score 7, max score 846
# Completed 4950 games, 146985 rewards, 30315462 frames, score 9, max score 846
# Completed 4951 games, 147001 rewards, 30317822 frames, score 15, max score 846
# Completed 4952 games, 147005 rewards, 30318537 frames, score 3, max score 846
# Completed 4953 games, 147012 rewards, 30320215 frames, score 6, max score 846
# Completed 4954 games, 147013 rewards, 30320469 frames, score 0, max score 846
# Completed 4955 games, 147016 rewards, 30321156 frames, score 2, max score 846
# Completed 4956 games, 147037 rewards, 30324832 frames, score 20, max score 846
# Completed 4957 games, 147050 rewards, 30327911 frames, score 12, max score 846
# Completed 4958 games, 147057 rewards, 30330275 frames, score 6, max score 846
# Completed 4959 games, 147069 rewards, 30335582 frames, score 11, max score 846
# Completed 4960 games, 147074 rewards, 30336590 frames, score 4, max score 846
# Completed 4961 games, 147121 rewards, 30353468 frames, score 46, max score 846
# Completed 4962 games, 147125 rewards, 30354662 frames, score 3, max score 846
# Completed 4963 games, 147141 rewards, 30357579 frames, score 15, max score 846
# Completed 4964 games, 147165 rewards, 30361035 frames, score 23, max score 846
# Completed 4965 games, 147178 rewards, 30363969 frames, score 12, max score 846
# Completed 4966 games, 147186 rewards, 30365490 frames, score 7, max score 846
# Completed 4967 games, 147195 rewards, 30367338 frames, score 8, max score 846
# Completed 4968 games, 147201 rewards, 30369169 frames, score 5, max score 846
# Completed 4969 games, 147234 rewards, 30374418 frames, score 32, max score 846
# Completed 4970 games, 147238 rewards, 30375057 frames, score 3, max score 846
# Completed 4971 games, 147264 rewards, 30379171 frames, score 25, max score 846
# Completed 4972 games, 147275 rewards, 30381265 frames, score 10, max score 846
# Completed 4973 games, 147366 rewards, 30395702 frames, score 90, max score 846
# Completed 4974 games, 147395 rewards, 30402774 frames, score 28, max score 846
# Completed 4975 games, 147542 rewards, 30428233 frames, score 146, max score 846
# Completed 4976 games, 147591 rewards, 30436070 frames, score 48, max score 846
# Completed 4977 games, 147600 rewards, 30438045 frames, score 8, max score 846
# Completed 4978 games, 147631 rewards, 30444382 frames, score 30, max score 846
# Completed 4979 games, 147640 rewards, 30445993 frames, score 8, max score 846
# Completed 4980 games, 147731 rewards, 30476376 frames, score 90, max score 846
# Completed 4981 games, 147746 rewards, 30478880 frames, score 14, max score 846
# Completed 4982 games, 147782 rewards, 30484252 frames, score 35, max score 846
# Completed 4983 games, 147838 rewards, 30493394 frames, score 55, max score 846
# Completed 4984 games, 147854 rewards, 30496287 frames, score 15, max score 846
# Completed 4985 games, 147860 rewards, 30497578 frames, score 5, max score 846
# Completed 4986 games, 147904 rewards, 30513317 frames, score 43, max score 846
# Completed 4987 games, 147924 rewards, 30516517 frames, score 19, max score 846
# Completed 4988 games, 147963 rewards, 30523925 frames, score 38, max score 846
# Completed 4989 games, 148026 rewards, 30533745 frames, score 62, max score 846
# Completed 4990 games, 148138 rewards, 30553539 frames, score 111, max score 846
# Completed 4991 games, 148172 rewards, 30560315 frames, score 33, max score 846
# Completed 4992 games, 148176 rewards, 30561267 frames, score 3, max score 846
# Completed 4993 games, 148244 rewards, 30571383 frames, score 67, max score 846
# Completed 4994 games, 148261 rewards, 30577127 frames, score 16, max score 846
# Completed 4995 games, 148400 rewards, 30598225 frames, score 138, max score 846
# Completed 4996 games, 148472 rewards, 30609304 frames, score 71, max score 846
# Completed 4997 games, 148564 rewards, 30623890 frames, score 91, max score 846
# Completed 4998 games, 148898 rewards, 30681400 frames, score 333, max score 846
# Completed 4999 games, 149096 rewards, 30716344 frames, score 197, max score 846
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# .....Completed 0 games, 30 rewards, 8125 frames, score 29, max score 29
# Completed 1 games, 48 rewards, 10886 frames, score 17, max score 29
# Completed 2 games, 64 rewards, 16802 frames, score 15, max score 29
# Completed 3 games, 71 rewards, 21221 frames, score 6, max score 29
# Completed 4 games, 86 rewards, 25431 frames, score 14, max score 29
# Completed 5 games, 89 rewards, 26294 frames, score 2, max score 29
# Completed 6 games, 99 rewards, 29810 frames, score 9, max score 29
# Completed 7 games, 119 rewards, 33539 frames, score 19, max score 29
# Completed 8 games, 131 rewards, 37423 frames, score 11, max score 29
# Completed 9 games, 133 rewards, 38157 frames, score 1, max score 29
# .
# ----------------------------------------------------------------------
# Ran 6 tests in 1.187s
#
# OK

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
